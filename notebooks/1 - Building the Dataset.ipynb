# %% [markdown]
# ### Getting the First Page

# %%
import requests

# %%
# bulk mode cuts out extraneous data, max per page is 1000
first_page_request = "https://www.speedrun.com/api/v1/games?_bulk=yes&max=1000"

first_page = requests.get(first_page_request)

# %%
first_page.json()
# Out:
# {'data': [{'id': 'o1y32j26',
#    'names': {'international': ' Bike Unchained 2', 'japanese': None},
#    'abbreviation': '_bike_unchained_2',
#    'weblink': 'https://www.speedrun.com/_bike_unchained_2'},
#   {'id': 'y65rm041',
#    'names': {'international': " BIRDIE WING -Golf Girls' Story-",
#     'japanese': None},
#    'abbreviation': '_birdie_wing_golf_girls_story',
#    'weblink': 'https://www.speedrun.com/_birdie_wing_golf_girls_story'},
#   {'id': 'kdkqz3xd',
#    'names': {'international': ' DYNAMITE BOMB!! ', 'japanese': None},
#    'abbreviation': '_DYNAMITE_BOMB_',
#    'weblink': 'https://www.speedrun.com/_DYNAMITE_BOMB_'},
#   {'id': '3698qwld',
#    'names': {'international': ' Great Dungeon In The Sky ', 'japanese': None},
#    'abbreviation': '_great_dungeon_in_the_sky_',
#    'weblink': 'https://www.speedrun.com/_great_dungeon_in_the_sky_'},
#   {'id': 'ldej48j1',
#    'names': {'international': ' House of Da Vinci 2', 'japanese': None},
#    'abbreviation': 'the_house_of_da_vinci_2',
#    'weblink': 'https://www.speedrun.com/the_house_of_da_vinci_2'},
#   {'id': '76r3p3q6',
#    'names': {'international': ' Interference: Dead Air', 'japanese': None},
#    'abbreviation': '_interference_dead_air',
#    'weblink': 'https://www.speedrun.com/_interference_dead_air'},
#   {'id': 'j1lqerz6',
#    'names': {'international': ' LIDAR.EXE', 'japanese': None},
#    'abbreviation': 'lidar_exe',
#    'weblink': 'https://www.speedrun.com/lidar_exe'},
#   {'id': 'o6gn9981',
#    'names': {'international': ' Metal Tales: Fury of the Guitar Gods',
#     'japanese': None},
#    'abbreviation': '_metal_tales_fury_of_the_guitar_gods',
#    'weblink': 'https://www.speedrun.com/_metal_tales_fury_of_the_guitar_gods'},
#   {'id': 'pdv92zk1',
#    'names': {'international': ' Sakura X Clash - Last Millenial Spring -',
#     'japanese': None},
#    'abbreviation': '_Sakura_X_Clash__Last_Millenial_Spring_',
#    'weblink': 'https://www.speedrun.com/_Sakura_X_Clash__Last_Millenial_Spring_'},
#   {'id': 'yd4k9pg6',
#    'names': {'international': ' Shutokou Battle Gaiden - Super Technic Challenge',
#     'japanese': None},
#    'abbreviation': 'sbg_stc',
#    'weblink': 'https://www.speedrun.com/sbg_stc'},
#   {'id': 'o6gnmp81',
#    'names': {'international': ' Sōkyūgurentai/Terra Diver (Arcade)',
#     'japanese': None},
#    'abbreviation': '_sokyugurentaiterra_diver_arcade',
#    'weblink': 'https://www.speedrun.com/_sokyugurentaiterra_diver_arcade'},
#   {'id': 'o1yjg0r1',
#    'names': {'international': ' Space Opera: Wyvern Wings', 'japanese': None},
#    'abbreviation': '_space_opera_wyvern_wings',
#    'weblink': 'https://www.speedrun.com/_space_opera_wyvern_wings'},
#   {'id': '268wqg96',
#    'names': {'international': ' Stories of Nibel: Tale of Ura',
#     'japanese': None},
#    'abbreviation': '_stories_of_nibel_tale_of_ura',
#    'weblink': 'https://www.speedrun.com/_stories_of_nibel_tale_of_ura'},
#   {'id': 'j1n47nw6',
#    'names': {'international': ' Ultimate Board Game Collection 12 Classics from Around The World',
#     'japanese': None},
#    'abbreviation': 'Ultimate_Board_Game_Collection_12_Classics_from_Around_The_World',
#    'weblink': 'https://www.speedrun.com/Ultimate_Board_Game_Collection_12_Classics_from_Around_The_World'},
#   {'id': '76r43ge1',
#    'names': {'international': ' Wing of Darkness', 'japanese': None},
#    'abbreviation': '_Wing_of_Darkness',
#    'weblink': 'https://www.speedrun.com/_Wing_of_Darkness'},
#   {'id': 'k6qqkx6g',
#    'names': {'international': '! Fishy !', 'japanese': None},
#    'abbreviation': 'fishy',
#    'weblink': 'https://www.speedrun.com/fishy'},
#   {'id': '268w4876',
#    'names': {'international': '! Wild Russia !', 'japanese': None},
#    'abbreviation': '1287250',
#    'weblink': 'https://www.speedrun.com/1287250'},
#   {'id': '3dx2pk41',
#    'names': {'international': '!findseed the map', 'japanese': None},
#    'abbreviation': 'findseed',
#    'weblink': 'https://www.speedrun.com/findseed'},
#   {'id': 'j1n83r91',
#    'names': {'international': '"Happy" Platformer', 'japanese': None},
#    'abbreviation': 'happy_platformer',
#    'weblink': 'https://www.speedrun.com/happy_platformer'},
#   {'id': 'y655yj46',
#    'names': {'international': '#21: The World', 'japanese': None},
#    'abbreviation': '_the_world',
#    'weblink': 'https://www.speedrun.com/_the_world'},
#   {'id': 'ldej49n1',
#    'names': {'international': '#compass', 'japanese': None},
#    'abbreviation': 'compass',
#    'weblink': 'https://www.speedrun.com/compass'},
#   {'id': '3dxk5051',
#    'names': {'international': '#FUNTIME', 'japanese': None},
#    'abbreviation': 'funtime',
#    'weblink': 'https://www.speedrun.com/funtime'},
#   {'id': 'j1n8eol1',
#    'names': {'international': '#SaveDiscord', 'japanese': None},
#    'abbreviation': 'discord',
#    'weblink': 'https://www.speedrun.com/discord'},
#   {'id': '46wxo91r',
#    'names': {'international': '&meow; (Meow)', 'japanese': None},
#    'abbreviation': 'meow',
#    'weblink': 'https://www.speedrun.com/meow'},
#   {'id': 'pdvp7kdw',
#    'names': {'international': "'Allo 'Allo! Cartoon Fun!", 'japanese': None},
#    'abbreviation': 'allo_allo_cartoon_fun',
#    'weblink': 'https://www.speedrun.com/allo_allo_cartoon_fun'},
#   {'id': 'm1mx54x6',
#    'names': {'international': "'n Verlore Verstand", 'japanese': None},
#    'abbreviation': 'nvv',
#    'weblink': 'https://www.speedrun.com/nvv'},
#   {'id': 'm1m8opd2',
#    'names': {'international': "'Splosion Man", 'japanese': None},
#    'abbreviation': 'splosion_man',
#    'weblink': 'https://www.speedrun.com/splosion_man'},
#   {'id': 'j1n8ell1',
#    'names': {'international': '(ben) bonk the ball', 'japanese': None},
#    'abbreviation': 'ben_bonk_the_ball',
#    'weblink': 'https://www.speedrun.com/ben_bonk_the_ball'},
#   {'id': '268wqw56',
#    'names': {'international': "(Deltarune Chapter 3) - Mike's Big Showdown",
#     'japanese': None},
#    'abbreviation': 'mikes_big_showdown',
#    'weblink': 'https://www.speedrun.com/mikes_big_showdown'},
#   {'id': 'lde3q7x6',
#    'names': {'international': '(Mario) The Music Box -ARC-', 'japanese': None},
#    'abbreviation': 'mtmba',
#    'weblink': 'https://www.speedrun.com/mtmba'},
#   {'id': '76r335l6',
#    'names': {'international': '(Mario) The Music Box Remastered',
#     'japanese': None},
#    'abbreviation': 'mtmbr',
#    'weblink': 'https://www.speedrun.com/mtmbr'},
#   {'id': '3dxkwry1',
#    'names': {'international': '(Scratch) Undieable Appel', 'japanese': None},
#    'abbreviation': 'Die_No_Appel_Scratch',
#    'weblink': 'https://www.speedrun.com/Die_No_Appel_Scratch'},
#   {'id': 'pd0nwj21',
#    'names': {'international': '(square)', 'japanese': None},
#    'abbreviation': 'square',
#    'weblink': 'https://www.speedrun.com/square'},
#   {'id': '9d3yzw6l',
#    'names': {'international': '(The) Final Fantasy Legend',
#     'japanese': '魔界塔士 Sa・Ga'},
#    'abbreviation': 'the_final_fantasy_legend',
#    'weblink': 'https://www.speedrun.com/the_final_fantasy_legend'},
#   {'id': 'y6552w06',
#    'names': {'international': '*NEW* SCUFFED BHOP SIMULATION 2026 GOTY EDITION',
#     'japanese': None},
#    'abbreviation': 'new_scuffed_bhop_simulation_2026_goty_edition',
#    'weblink': 'https://www.speedrun.com/new_scuffed_bhop_simulation_2026_goty_edition'},
#   {'id': 'v1pxx376',
#    'names': {'international': '*NEW* SCUFFED EPIC BHOP SIMULATOR 2023 (POG CHAMP)',
#     'japanese': None},
#    'abbreviation': 'new_scuffed_epic_bhop_simulator_2023_pog_champ',
#    'weblink': 'https://www.speedrun.com/new_scuffed_epic_bhop_simulator_2023_pog_champ'},
#   {'id': '268wv896',
#    'names': {'international': '- Pixel Sheep -', 'japanese': None},
#    'abbreviation': 'pixel_sheep',
#    'weblink': 'https://www.speedrun.com/pixel_sheep'},
#   {'id': 'm1zyjpx6',
#    'names': {'international': '-256', 'japanese': None},
#    'abbreviation': '256',
#    'weblink': 'https://www.speedrun.com/256'},
#   {'id': '46w3n071',
#    'names': {'international': '-SPROUT-', 'japanese': None},
#    'abbreviation': '-sprout-',
#    'weblink': 'https://www.speedrun.com/-sprout-'},
#   {'id': 'y655rn36',
#    'names': {'international': '...Iru!', 'japanese': None},
#    'abbreviation': 'iru',
#    'weblink': 'https://www.speedrun.com/iru'},
#   {'id': 'm1m8r3d2',
#    'names': {'international': '..and the mooncats', 'japanese': None},
#    'abbreviation': '.and_the_mooncats',
#    'weblink': 'https://www.speedrun.com/.and_the_mooncats'},
#   {'id': 'o6gnx591',
#    'names': {'international': '.cat Milk', 'japanese': None},
#    'abbreviation': 'cat_milk',
#    'weblink': 'https://www.speedrun.com/cat_milk'},
#   {'id': 'y65e0e6e',
#    'names': {'international': '.flow', 'japanese': None},
#    'abbreviation': 'dotflow',
#    'weblink': 'https://www.speedrun.com/dotflow'},
#   {'id': 'nd2ekj5d',
#    'names': {'international': '.hack//G.U. Last Recode', 'japanese': None},
#    'abbreviation': 'guhd',
#    'weblink': 'https://www.speedrun.com/guhd'},
#   {'id': 'pd0y226e',
#    'names': {'international': '.hack//G.U. Volume 1: Rebirth',
#     'japanese': None},
#    'abbreviation': '.hack_g.u._volume_1_rebirth',
#    'weblink': 'https://www.speedrun.com/.hack_g.u._volume_1_rebirth'},
#   {'id': 'kdk7ye1m',
#    'names': {'international': '.hack//G.U. Volume 2: Reminisce',
#     'japanese': None},
#    'abbreviation': '.hack_g.u._volume_2_reminisce',
#    'weblink': 'https://www.speedrun.com/.hack_g.u._volume_2_reminisce'},
#   {'id': 'o1ygzr1q',
#    'names': {'international': '.hack//G.U. Volume 3: Redemption',
#     'japanese': None},
#    'abbreviation': '.hack_g.u._volume_3_redemption',
#    'weblink': 'https://www.speedrun.com/.hack_g.u._volume_3_redemption'},
#   {'id': 'k6qrzm1g',
#    'names': {'international': '.hack//Infection', 'japanese': '.hack//感染拡大'},
#    'abbreviation': '.hackinfection',
#    'weblink': 'https://www.speedrun.com/.hackinfection'},
#   {'id': '369k2gdl',
#    'names': {'international': '.hack//Mutation', 'japanese': '.hack//悪性変異'},
#    'abbreviation': '.hackmutation',
#    'weblink': 'https://www.speedrun.com/.hackmutation'},
#   {'id': 'y65p30de',
#    'names': {'international': '.hack//Outbreak', 'japanese': None},
#    'abbreviation': '.hackoutbreak',
#    'weblink': 'https://www.speedrun.com/.hackoutbreak'},
#   {'id': 'w6j2ye1j',
#    'names': {'international': '.hack//Quarantine', 'japanese': None},
#    'abbreviation': '.hackquarantine',
#    'weblink': 'https://www.speedrun.com/.hackquarantine'},
#   {'id': 'pdvnrv6w',
#    'names': {'international': '.kkrieger', 'japanese': None},
#    'abbreviation': 'kkrieger',
#    'weblink': 'https://www.speedrun.com/kkrieger'},
#   {'id': 'pdv2e8v6',
#    'names': {'international': '.S', 'japanese': None},
#    'abbreviation': 's_torcado',
#    'weblink': 'https://www.speedrun.com/s_torcado'},
#   {'id': 'v1pxvxm6',
#    'names': {'international': '//N.P.P.D. RUSH//- The milk of Ultraviolet',
#     'japanese': None},
#    'abbreviation': 'nppdrush',
#    'weblink': 'https://www.speedrun.com/nppdrush'},
#   {'id': 'nd28v03d',
#    'names': {'international': '0 Degrees', 'japanese': None},
#    'abbreviation': '0_degrees',
#    'weblink': 'https://www.speedrun.com/0_degrees'},
#   {'id': 'nd2g9v10',
#    'names': {'international': '007 Legends', 'japanese': None},
#    'abbreviation': '007_legends',
#    'weblink': 'https://www.speedrun.com/007_legends'},
#   {'id': 'o1y93e46',
#    'names': {'international': '007 Racing', 'japanese': None},
#    'abbreviation': '007_racing',
#    'weblink': 'https://www.speedrun.com/007_racing'},
#   {'id': 'y65r071e',
#    'names': {'international': '007: Agent Under Fire', 'japanese': None},
#    'abbreviation': 'auf',
#    'weblink': 'https://www.speedrun.com/auf'},
#   {'id': 'o1yql4dq',
#    'names': {'international': '007: From Russia With Love', 'japanese': None},
#    'abbreviation': '007frwl',
#    'weblink': 'https://www.speedrun.com/007frwl'},
#   {'id': '268j3kdp',
#    'names': {'international': '007: NightFire (GBA)', 'japanese': None},
#    'abbreviation': '007nf_gba',
#    'weblink': 'https://www.speedrun.com/007nf_gba'},
#   {'id': 'j1llvev1',
#    'names': {'international': '007: Nightfire Category Extensions',
#     'japanese': None},
#    'abbreviation': '007nfca',
#    'weblink': 'https://www.speedrun.com/007nfca'},
#   {'id': 'nd272v10',
#    'names': {'international': '007: The World is Not Enough',
#     'japanese': None},
#    'abbreviation': 'twine',
#    'weblink': 'https://www.speedrun.com/twine'},
#   {'id': 'v1p5rpd8',
#    'names': {'international': '007: The World is Not Enough (PS1)',
#     'japanese': None},
#    'abbreviation': 'twineps1',
#    'weblink': 'https://www.speedrun.com/twineps1'},
#   {'id': 'o6gl8y8d',
#    'names': {'international': '03.04', 'japanese': None},
#    'abbreviation': '03.04',
#    'weblink': 'https://www.speedrun.com/03.04'},
#   {'id': 'y65pv8de',
#    'names': {'international': '0error0', 'japanese': None},
#    'abbreviation': '0error0',
#    'weblink': 'https://www.speedrun.com/0error0'},
#   {'id': 'j1n80491',
#    'names': {'international': '0h n0', 'japanese': None},
#    'abbreviation': '0h_n0',
#    'weblink': 'https://www.speedrun.com/0h_n0'},
#   {'id': '46w22k96',
#    'names': {'international': '0R8 Demo', 'japanese': None},
#    'abbreviation': '0r8_demo',
#    'weblink': 'https://www.speedrun.com/0r8_demo'},
#   {'id': '76r3z4q6',
#    'names': {'international': '1 Bit Survivor', 'japanese': None},
#    'abbreviation': '1bs',
#    'weblink': 'https://www.speedrun.com/1bs'},
#   {'id': 'yd4knwg6',
#    'names': {'international': '1 on 1 Government', 'japanese': None},
#    'abbreviation': '1_on_1_government',
#    'weblink': 'https://www.speedrun.com/1_on_1_government'},
#   {'id': 'o1y9np26',
#    'names': {'international': '1 Screen Platformer', 'japanese': None},
#    'abbreviation': '1sp',
#    'weblink': 'https://www.speedrun.com/1sp'},
#   {'id': 'pdvv39dw',
#    'names': {'international': '1 vs 100', 'japanese': None},
#    'abbreviation': '1_vs_100',
#    'weblink': 'https://www.speedrun.com/1_vs_100'},
#   {'id': '4d72l367',
#    'names': {'international': '1-2-Switch', 'japanese': None},
#    'abbreviation': '1-2-switch',
#    'weblink': 'https://www.speedrun.com/1-2-switch'},
#   {'id': 'yd4oqp51',
#    'names': {'international': '10 Beautiful Postcards', 'japanese': None},
#    'abbreviation': 'tenpostcards',
#    'weblink': 'https://www.speedrun.com/tenpostcards'},
#   {'id': '46w332l1',
#    'names': {'international': '10 Gnomes 10: Seashore', 'japanese': None},
#    'abbreviation': '10_gnomes_10_2008',
#    'weblink': 'https://www.speedrun.com/10_gnomes_10_2008'},
#   {'id': 'o6glln8d',
#    'names': {'international': '10 Gnomes 11: the Remains', 'japanese': None},
#    'abbreviation': '10_gnomes_11',
#    'weblink': 'https://www.speedrun.com/10_gnomes_11'},
#   {'id': '76rxx3v6',
#    'names': {'international': '10 Gnomes 12: the Tank', 'japanese': None},
#    'abbreviation': '10_gnomes_12',
#    'weblink': 'https://www.speedrun.com/10_gnomes_12'},
#   {'id': 'k6q44wmd',
#    'names': {'international': '10 Gnomes 1: the Rooftops', 'japanese': None},
#    'abbreviation': '10_gnomes_1',
#    'weblink': 'https://www.speedrun.com/10_gnomes_1'},
#   {'id': 'j1nee8e1',
#    'names': {'international': '10 Gnomes 2: Walk in the Park',
#     'japanese': None},
#    'abbreviation': '10_gnomes_2',
#    'weblink': 'https://www.speedrun.com/10_gnomes_2'},
#   {'id': 'lde33jj6',
#    'names': {'international': '10 Gnomes 3: Early Spring Garden',
#     'japanese': None},
#    'abbreviation': '10_gnomes_3',
#    'weblink': 'https://www.speedrun.com/10_gnomes_3'},
#   {'id': '268eew96',
#    'names': {'international': '10 Gnomes 4: Foggy Flat', 'japanese': None},
#    'abbreviation': '10_gnomes_4',
#    'weblink': 'https://www.speedrun.com/10_gnomes_4'},
#   {'id': '9doww8k1',
#    'names': {'international': '10 Gnomes 5: the Shipyard', 'japanese': None},
#    'abbreviation': '10_gnomes_5',
#    'weblink': 'https://www.speedrun.com/10_gnomes_5'},
#   {'id': 'm1mxxn36',
#    'names': {'international': '10 Gnomes 6: the Hall', 'japanese': None},
#    'abbreviation': '10_gnomes_6',
#    'weblink': 'https://www.speedrun.com/10_gnomes_6'},
#   {'id': 'yd4ookg1',
#    'names': {'international': '10 Gnomes 7: the Solitude', 'japanese': None},
#    'abbreviation': '10_gnomes_7',
#    'weblink': 'https://www.speedrun.com/10_gnomes_7'},
#   {'id': '3dx22k51',
#    'names': {'international': '10 Gnomes 8: Water Forge', 'japanese': None},
#    'abbreviation': '10_gnomes_8',
#    'weblink': 'https://www.speedrun.com/10_gnomes_8'},
#   {'id': 'v1pooxz6',
#    'names': {'international': '10 Gnomes 9: Chemistry', 'japanese': None},
#    'abbreviation': '10_gnomes_9_chemistry',
#    'weblink': 'https://www.speedrun.com/10_gnomes_9_chemistry'},
#   {'id': 'j1lllqj1',
#    'names': {'international': '10 Gnomes in Bologna', 'japanese': None},
#    'abbreviation': '10_gnomes_in_b',
#    'weblink': 'https://www.speedrun.com/10_gnomes_in_b'},
#   {'id': 'pdvzz2k6',
#    'names': {'international': '10 Gnomes in Dubrovnik', 'japanese': None},
#    'abbreviation': '10_gnomes_in_d',
#    'weblink': 'https://www.speedrun.com/10_gnomes_in_d'},
#   {'id': 'pd0wwq31',
#    'names': {'international': '10 Gnomes in Liege', 'japanese': None},
#    'abbreviation': '10_gnomes_in_l',
#    'weblink': 'https://www.speedrun.com/10_gnomes_in_l'},
#   {'id': '9d3r9p0d',
#    'names': {'international': '10 Gnomes in Malmo', 'japanese': None},
#    'abbreviation': '10_gnomes_in_malmo',
#    'weblink': 'https://www.speedrun.com/10_gnomes_in_malmo'},
#   {'id': 'nd2ee8qd',
#    'names': {'international': '10 Gnomes in Montaigut-le-Blanc',
#     'japanese': None},
#    'abbreviation': '10_gnomes_in_m',
#    'weblink': 'https://www.speedrun.com/10_gnomes_in_m'},
#   {'id': '36983w8d',
#    'names': {'international': '10 Gnomes in New York', 'japanese': None},
#    'abbreviation': '10_gnomes_in_new_york',
#    'weblink': 'https://www.speedrun.com/10_gnomes_in_new_york'},
#   {'id': 'j1ne2ml1',
#    'names': {'international': '10 Gnomes in Oristano', 'japanese': None},
#    'abbreviation': '10_gnomes_in_oristano',
#    'weblink': 'https://www.speedrun.com/10_gnomes_in_oristano'},
#   {'id': 'k6q4krxd',
#    'names': {'international': '10 Gnomes in Paris', 'japanese': None},
#    'abbreviation': '10_gnomes_in_paris',
#    'weblink': 'https://www.speedrun.com/10_gnomes_in_paris'},
#   {'id': '369pp831',
#    'names': {'international': '10 Gnomes in Porto Petro', 'japanese': None},
#    'abbreviation': '10_gnomes_in_p',
#    'weblink': 'https://www.speedrun.com/10_gnomes_in_p'},
#   {'id': '4d799nr1',
#    'names': {'international': '10 Gnomes in Pothia', 'japanese': None},
#    'abbreviation': '10_gnomes_in_pothia',
#    'weblink': 'https://www.speedrun.com/10_gnomes_in_pothia'},
#   {'id': '9d3rr80d',
#    'names': {'international': '10 Gnomes in Trstenik', 'japanese': None},
#    'abbreviation': '10_gnomes_in_t',
#    'weblink': 'https://www.speedrun.com/10_gnomes_in_t'},
#   {'id': 'm1zjjk06',
#    'names': {'international': '10 Gnomes in Venice', 'japanese': None},
#    'abbreviation': '10_gnomes_in_v',
#    'weblink': 'https://www.speedrun.com/10_gnomes_in_v'},
#   {'id': '4d7n55r6',
#    'names': {'international': '10 Minutes 1 Hour 2 Hours', 'japanese': None},
#    'abbreviation': '10_minutes_1_hour_2_hours',
#    'weblink': 'https://www.speedrun.com/10_minutes_1_hour_2_hours'},
#   {'id': 'm1zm2m60',
#    'names': {'international': '10 Second Ninja', 'japanese': None},
#    'abbreviation': '10sn',
#    'weblink': 'https://www.speedrun.com/10sn'},
#   {'id': 'm1mkwpd2',
#    'names': {'international': '10 Second Ninja X', 'japanese': None},
#    'abbreviation': '10snx',
#    'weblink': 'https://www.speedrun.com/10snx'},
#   {'id': 'pdvz9v46',
#    'names': {'international': '10 Second Run Returns', 'japanese': None},
#    'abbreviation': '10srr',
#    'weblink': 'https://www.speedrun.com/10srr'},
#   {'id': 'j1llv941',
#    'names': {'international': '10 Second Shuriken', 'japanese': None},
#    'abbreviation': '10_second_shuriken',
#    'weblink': 'https://www.speedrun.com/10_second_shuriken'},
#   {'id': '46w27y36',
#    'names': {'international': '10 second to win', 'japanese': None},
#    'abbreviation': '10_seconds_to_win',
#    'weblink': 'https://www.speedrun.com/10_seconds_to_win'},
#   {'id': 'v1pxrm86',
#    'names': {'international': '10 Seconds', 'japanese': None},
#    'abbreviation': '10_seconds',
#    'weblink': 'https://www.speedrun.com/10_seconds'},
#   {'id': '3dxkexy1',
#    'names': {'international': '10 Seconds or less', 'japanese': None},
#    'abbreviation': '10s_or_less',
#    'weblink': 'https://www.speedrun.com/10s_or_less'},
#   {'id': 'ldejx3l1',
#    'names': {'international': '10-Pin Bowling', 'japanese': None},
#    'abbreviation': '10pinbowling',
#    'weblink': 'https://www.speedrun.com/10pinbowling'},
#   {'id': 'm1m0wx62',
#    'names': {'international': '10-Yard Fight', 'japanese': '10ヤードファイト'},
#    'abbreviation': '10-yard_fight',
#    'weblink': 'https://www.speedrun.com/10-yard_fight'},
#   {'id': 'o6gkzx51',
#    'names': {'international': '100 Hidden Aliens', 'japanese': None},
#    'abbreviation': '100_hidden_aliens',
#    'weblink': 'https://www.speedrun.com/100_hidden_aliens'},
#   {'id': 'w6j7wp76',
#    'names': {'international': '100 Hidden Birds', 'japanese': None},
#    'abbreviation': '100_hidden_birds',
#    'weblink': 'https://www.speedrun.com/100_hidden_birds'},
#   {'id': 'ldejo9n1',
#    'names': {'international': '100 hidden cats', 'japanese': None},
#    'abbreviation': '100_hidden_cats',
#    'weblink': 'https://www.speedrun.com/100_hidden_cats'},
#   {'id': '9d3woew1',
#    'names': {'international': '100 Hidden Cats 2', 'japanese': None},
#    'abbreviation': '100_hidden_cats_2',
#    'weblink': 'https://www.speedrun.com/100_hidden_cats_2'},
#   {'id': 'nd27kne1',
#    'names': {'international': '100 Hidden Cupcakes', 'japanese': None},
#    'abbreviation': '100_hidden_cupcakes',
#    'weblink': 'https://www.speedrun.com/100_hidden_cupcakes'},
#   {'id': 'j1ln4oe6',
#    'names': {'international': '100 Hidden Cups', 'japanese': None},
#    'abbreviation': '100_hidden_cups',
#    'weblink': 'https://www.speedrun.com/100_hidden_cups'},
#   {'id': 'y65rmo01',
#    'names': {'international': '100 Hidden Fish', 'japanese': None},
#    'abbreviation': '100_hidden_fish',
#    'weblink': 'https://www.speedrun.com/100_hidden_fish'},
#   {'id': 'v1px3y76',
#    'names': {'international': '100 Hidden Frogs', 'japanese': None},
#    'abbreviation': '100_hidden_frogs',
#    'weblink': 'https://www.speedrun.com/100_hidden_frogs'},
#   {'id': 'o1y325r6',
#    'names': {'international': '100 Hidden Gnomes', 'japanese': None},
#    'abbreviation': '100_hidden_gnomes',
#    'weblink': 'https://www.speedrun.com/100_hidden_gnomes'},
#   {'id': '76r4wgq1',
#    'names': {'international': '100 Hidden Hares', 'japanese': None},
#    'abbreviation': '100_hidden_hares',
#    'weblink': 'https://www.speedrun.com/100_hidden_hares'},
#   {'id': 'pdv93041',
#    'names': {'international': '100 Hidden Mice', 'japanese': None},
#    'abbreviation': '100_hidden_mice',
#    'weblink': 'https://www.speedrun.com/100_hidden_mice'},
#   {'id': 'j1n8gme1',
#    'names': {'international': '100 hidden rams', 'japanese': None},
#    'abbreviation': '100_hidden_rams',
#    'weblink': 'https://www.speedrun.com/100_hidden_rams'},
#   {'id': '369wzgld',
#    'names': {'international': '100 Hidden Turtles', 'japanese': None},
#    'abbreviation': '100_hidden_turtles',
#    'weblink': 'https://www.speedrun.com/100_hidden_turtles'},
#   {'id': '268w2v96',
#    'names': {'international': '100 Meters Race', 'japanese': None},
#    'abbreviation': '100_meters_race',
#    'weblink': 'https://www.speedrun.com/100_meters_race'},
#   {'id': 'lde33q56',
#    'names': {'international': '100 Rooms of Enemies', 'japanese': None},
#    'abbreviation': '100rooms',
#    'weblink': 'https://www.speedrun.com/100rooms'},
#   {'id': '9dowmo31',
#    'names': {'international': '100 Rooms of Kuso', 'japanese': None},
#    'abbreviation': '100_rooms_of_kuso',
#    'weblink': 'https://www.speedrun.com/100_rooms_of_kuso'},
#   {'id': '369plr21',
#    'names': {'international': '100 vacas', 'japanese': None},
#    'abbreviation': '100_vacas',
#    'weblink': 'https://www.speedrun.com/100_vacas'},
#   {'id': 'j1n8evl1',
#    'names': {'international': '100% Complete', 'japanese': None},
#    'abbreviation': '100_complete',
#    'weblink': 'https://www.speedrun.com/100_complete'},
#   {'id': 'j1n2gw1p',
#    'names': {'international': '100% Orange Juice!',
#     'japanese': '100%おれんじじゅ～すっ！'},
#    'abbreviation': '100oj',
#    'weblink': 'https://www.speedrun.com/100oj'},
#   {'id': 'o6ge0n12',
#    'names': {'international': '1000 Amps', 'japanese': None},
#    'abbreviation': '1000_amps',
#    'weblink': 'https://www.speedrun.com/1000_amps'},
#   {'id': 'm1mk8xd2',
#    'names': {'international': '1000 Coins', 'japanese': None},
#    'abbreviation': '1000',
#    'weblink': 'https://www.speedrun.com/1000'},
#   {'id': 'j1llmjj1',
#    'names': {'international': '1000 Days to Escape', 'japanese': None},
#    'abbreviation': '1000_days_to_escape',
#    'weblink': 'https://www.speedrun.com/1000_days_to_escape'},
#   {'id': '9do4vm6p',
#    'names': {'international': '10000000', 'japanese': None},
#    'abbreviation': '10000000',
#    'weblink': 'https://www.speedrun.com/10000000'},
#   {'id': 'yd4o5w1e',
#    'names': {'international': '1001 Spikes', 'japanese': None},
#    'abbreviation': '1001_spikes',
#    'weblink': 'https://www.speedrun.com/1001_spikes'},
#   {'id': 'm1zk3721',
#    'names': {'international': '100m Race', 'japanese': None},
#    'abbreviation': 'race',
#    'weblink': 'https://www.speedrun.com/race'},
#   {'id': 'o1y989r6',
#    'names': {'international': '100th Anniversary of the Crossword Puzzle',
#     'japanese': None},
#    'abbreviation': '100th_anniversary_of_the_crossword_puzzle',
#    'weblink': 'https://www.speedrun.com/100th_anniversary_of_the_crossword_puzzle'},
#   {'id': '268eko56',
#    'names': {'international': '101 Dalmatians: Escape from DeVil Manor',
#     'japanese': None},
#    'abbreviation': '101_dalmatians_escape_from_devil_manor',
#    'weblink': 'https://www.speedrun.com/101_dalmatians_escape_from_devil_manor'},
#   {'id': 'v1pxz2m6',
#    'names': {'international': '101-in-1 Explosive Megamix (DS)',
#     'japanese': None},
#    'abbreviation': '101in1_explosive_megamix_ds',
#    'weblink': 'https://www.speedrun.com/101in1_explosive_megamix_ds'},
#   {'id': 'm1mnlokd',
#    'names': {'international': '101-in-1 Games', 'japanese': None},
#    'abbreviation': '101in1games',
#    'weblink': 'https://www.speedrun.com/101in1games'},
#   {'id': '76r37p56',
#    'names': {'international': '101-in-1 Games 2: Evolution ',
#     'japanese': None},
#    'abbreviation': '101in12',
#    'weblink': 'https://www.speedrun.com/101in12'},
#   {'id': '268w8r76',
#    'names': {'international': '101-in-1 Games Anthology', 'japanese': None},
#    'abbreviation': '101in1ant',
#    'weblink': 'https://www.speedrun.com/101in1ant'},
#   {'id': 'pdvlzo1w',
#    'names': {'international': '1010!', 'japanese': None},
#    'abbreviation': '1010',
#    'weblink': 'https://www.speedrun.com/1010'},
#   {'id': 'w6jlpned',
#    'names': {'international': '1066', 'japanese': None},
#    'abbreviation': '1066',
#    'weblink': 'https://www.speedrun.com/1066'},
#   {'id': '9dowvo1p',
#    'names': {'international': '1080° Avalanche',
#     'japanese': 'テン・エイティ シルバーストーム'},
#    'abbreviation': '1080avalanche',
#    'weblink': 'https://www.speedrun.com/1080avalanche'},
#   {'id': '268ery6p',
#    'names': {'international': '1080° Snowboarding',
#     'japanese': 'テン・エイティ スノーボーディング'},
#    'abbreviation': '1080snowboarding',
#    'weblink': 'https://www.speedrun.com/1080snowboarding'},
#   {'id': 'o6gn0vx1',
#    'names': {'international': '10mg :)', 'japanese': None},
#    'abbreviation': '10mgsmileyface',
#    'weblink': 'https://www.speedrun.com/10mgsmileyface'},
#   {'id': 'j1llgoe1',
#    'names': {'international': '10S', 'japanese': None},
#    'abbreviation': '10s',
#    'weblink': 'https://www.speedrun.com/10s'},
#   {'id': 'k6q47god',
#    'names': {'international': '10th Anniversary Map', 'japanese': None},
#    'abbreviation': 'mcm_10am',
#    'weblink': 'https://www.speedrun.com/mcm_10am'},
#   {'id': 'pdvze346',
#    'names': {'international': '10^2 (Minecraft Map)', 'japanese': None},
#    'abbreviation': '10_squared_series',
#    'weblink': 'https://www.speedrun.com/10_squared_series'},
#   {'id': '4d79m331',
#    'names': {'international': '112 Operator', 'japanese': None},
#    'abbreviation': '112_operator',
#    'weblink': 'https://www.speedrun.com/112_operator'},
#   {'id': '3dx2xk41',
#    'names': {'international': '1187: Episode One', 'japanese': None},
#    'abbreviation': '1187ep1',
#    'weblink': 'https://www.speedrun.com/1187ep1'},
#   {'id': '3dxwxg1y',
#    'names': {'international': '12 is Better Than 6', 'japanese': None},
#    'abbreviation': '12_is_better_than_6',
#    'weblink': 'https://www.speedrun.com/12_is_better_than_6'},
#   {'id': 'nd297r60',
#    'names': {'international': '12 Labours of Hercules', 'japanese': None},
#    'abbreviation': '12loh1',
#    'weblink': 'https://www.speedrun.com/12loh1'},
#   {'id': 'ldevql13',
#    'names': {'international': '12 Labours of Hercules II: The Cretan Bull',
#     'japanese': None},
#    'abbreviation': '12loh2',
#    'weblink': 'https://www.speedrun.com/12loh2'},
#   {'id': '268g4ydp',
#    'names': {'international': '12 Labours of Hercules III: Girl Power',
#     'japanese': None},
#    'abbreviation': '12loh3',
#    'weblink': 'https://www.speedrun.com/12loh3'},
#   {'id': '9dom5o6p',
#    'names': {'international': '12 Labours of Hercules IV: Mother Nature',
#     'japanese': None},
#    'abbreviation': '12loh4',
#    'weblink': 'https://www.speedrun.com/12loh4'},
#   {'id': 'pdv27mk6',
#    'names': {'international': "12 Labours of Hercules IX: A Hero's Moonwalk",
#     'japanese': None},
#    'abbreviation': '12_labours_of_hercules_ix_a_heros_moonwalk',
#    'weblink': 'https://www.speedrun.com/12_labours_of_hercules_ix_a_heros_moonwalk'},
#   {'id': 'm1m85xd2',
#    'names': {'international': '12 Labours of Hercules V: Kids of Hellas',
#     'japanese': None},
#    'abbreviation': '12loh5',
#    'weblink': 'https://www.speedrun.com/12loh5'},
#   {'id': 'yd44pkde',
#    'names': {'international': '12 Labours of Hercules VI: Race for Olympus',
#     'japanese': None},
#    'abbreviation': '12loh6',
#    'weblink': 'https://www.speedrun.com/12loh6'},
#   {'id': 'nd283xqd',
#    'names': {'international': '12 Labours of Hercules VII: Fleecing The Fleece',
#     'japanese': None},
#    'abbreviation': '12_labours_of_hercules_vii_fleecing_the_fleece',
#    'weblink': 'https://www.speedrun.com/12_labours_of_hercules_vii_fleecing_the_fleece'},
#   {'id': '3698433d',
#    'names': {'international': '12 Labours of Hercules VIII: How I Met Megara',
#     'japanese': None},
#    'abbreviation': '12_labours_of_hercules_viii_how_i_met_megara',
#    'weblink': 'https://www.speedrun.com/12_labours_of_hercules_viii_how_i_met_megara'},
#   {'id': 'ldejmnn1',
#    'names': {'international': '12 Labours of Hercules X: Greed For Speed',
#     'japanese': None},
#    'abbreviation': '12_labours_of_hercules_x_greed_for_speed',
#    'weblink': 'https://www.speedrun.com/12_labours_of_hercules_x_greed_for_speed'},
#   {'id': 'm1zk35z1',
#    'names': {'international': '12 Labours of Hercules XI: Painted Adventure',
#     'japanese': None},
#    'abbreviation': '12_labours_of_hercules_xi_painted_adventure_',
#    'weblink': 'https://www.speedrun.com/12_labours_of_hercules_xi_painted_adventure_'},
#   {'id': '9d38qp01',
#    'names': {'international': '12 Labours of Hercules XII: Timeless Adventure',
#     'japanese': None},
#    'abbreviation': '12_labours_of_hercules_xii_timeless_adventure',
#    'weblink': 'https://www.speedrun.com/12_labours_of_hercules_xii_timeless_adventure'},
#   {'id': '9do8plk1',
#    'names': {'international': '12 Labours of Hercules XIII: Wonder-ful Builder',
#     'japanese': None},
#    'abbreviation': '12_labours_of_hercules_xiii_wonder_ful_builder',
#    'weblink': 'https://www.speedrun.com/12_labours_of_hercules_xiii_wonder_ful_builder'},
#   {'id': '268wjyk6',
#    'names': {'international': '12 Labours of Hercules XIV: Message in a Bottle',
#     'japanese': None},
#    'abbreviation': '12_labours_of_hercules_xiv_message_in_a_bottle',
#    'weblink': 'https://www.speedrun.com/12_labours_of_hercules_xiv_message_in_a_bottle'},
#   {'id': 'pd0nwyw1',
#    'names': {'international': '12 Labours of Hercules XV: Little Big Adventure',
#     'japanese': None},
#    'abbreviation': '12_Labours_of_Hercules_XV_Little_Big_Adventure',
#    'weblink': 'https://www.speedrun.com/12_Labours_of_Hercules_XV_Little_Big_Adventure'},
#   {'id': '46w2e4n6',
#    'names': {'international': '12 locks and keys', 'japanese': None},
#    'abbreviation': '_12',
#    'weblink': 'https://www.speedrun.com/_12'},
#   {'id': 'y655k5e6',
#    'names': {'international': '12 LOCKS: Plasticine room', 'japanese': None},
#    'abbreviation': '12_rooms_plasticine_room',
#    'weblink': 'https://www.speedrun.com/12_rooms_plasticine_room'},
#   {'id': 'ldej5wn1',
#    'names': {'international': '12 Sai Honto no kimochi', 'japanese': None},
#    'abbreviation': '12_sai_honto_no_kimochi',
#    'weblink': 'https://www.speedrun.com/12_sai_honto_no_kimochi'},
#   {'id': 'y655jy86',
#    'names': {'international': '12 Sai Koi Suru Diary', 'japanese': None},
#    'abbreviation': '12_sai_koi_suru_diary',
#    'weblink': 'https://www.speedrun.com/12_sai_koi_suru_diary'},
#   {'id': 'o6gn5rn1',
#    'names': {'international': '12 Sai Torokeru Puzzle Futari no Harmony',
#     'japanese': None},
#    'abbreviation': '12_sai_torokeru_puzzle_futari_no_harmony',
#    'weblink': 'https://www.speedrun.com/12_sai_torokeru_puzzle_futari_no_harmony'},
#   {'id': 'nd28qlvd',
#    'names': {'international': '123 Slaughter Me Street 2', 'japanese': None},
#    'abbreviation': '123_slaughter_me_street_2',
#    'weblink': 'https://www.speedrun.com/123_slaughter_me_street_2'},
#   {'id': 'w6jg7e76',
#    'names': {'international': '123 Slaughter Me Street Super Retro ',
#     'japanese': None},
#    'abbreviation': '123_Slaughter_Me_Street_Super_Retro_',
#    'weblink': 'https://www.speedrun.com/123_Slaughter_Me_Street_Super_Retro_'},
#   {'id': 'j1n8lqw1',
#    'names': {'international': '13 Days After Survival', 'japanese': None},
#    'abbreviation': '13_days_after_survival',
#    'weblink': 'https://www.speedrun.com/13_days_after_survival'},
#   {'id': 'j1n8rex1',
#    'names': {'international': '13 Days In Hell', 'japanese': None},
#    'abbreviation': '13_days_in_hell',
#    'weblink': 'https://www.speedrun.com/13_days_in_hell'},
#   {'id': 'yd4o0551',
#    'names': {'international': '13 Gates', 'japanese': None},
#    'abbreviation': '13g',
#    'weblink': 'https://www.speedrun.com/13g'},
#   {'id': 'ldej8n51',
#    'names': {'international': '13 More Days In Hell', 'japanese': None},
#    'abbreviation': '13_more_days_in_hell',
#    'weblink': 'https://www.speedrun.com/13_more_days_in_hell'},
#   {'id': 'j1llk3e1',
#    'names': {'international': '13 Sentinels: Aegis Rim', 'japanese': None},
#    'abbreviation': '13_sentinels_aegis_rim',
#    'weblink': 'https://www.speedrun.com/13_sentinels_aegis_rim'},
#   {'id': 'nd2vx510',
#    'names': {'international': '14 Locks', 'japanese': None},
#    'abbreviation': '14locks',
#    'weblink': 'https://www.speedrun.com/14locks'},
#   {'id': 'kdkqm8qd',
#    'names': {'international': '14 Minesweeper Variants', 'japanese': None},
#    'abbreviation': '14_Minesweeper_Variants',
#    'weblink': 'https://www.speedrun.com/14_Minesweeper_Variants'},
#   {'id': '9d3r70dl',
#    'names': {'international': '140', 'japanese': None},
#    'abbreviation': '140',
#    'weblink': 'https://www.speedrun.com/140'},
#   {'id': '3dx03ydy',
#    'names': {'international': '15 Seconds', 'japanese': None},
#    'abbreviation': 'mcm_15s',
#    'weblink': 'https://www.speedrun.com/mcm_15s'},
#   {'id': '76r43lq1',
#    'names': {'international': '150 Level IQ Escape Room', 'japanese': None},
#    'abbreviation': '150_Level_IQ_Escape_Room',
#    'weblink': 'https://www.speedrun.com/150_Level_IQ_Escape_Room'},
#   {'id': '4d794jn1',
#    'names': {'international': '150,000 B.C.', 'japanese': None},
#    'abbreviation': '150000_b.c.',
#    'weblink': 'https://www.speedrun.com/150000_b.c.'},
#   {'id': '46w250q6',
#    'names': {'international': '16 Greens', 'japanese': None},
#    'abbreviation': '16_greens',
#    'weblink': 'https://www.speedrun.com/16_greens'},
#   {'id': 'o1y90ov6',
#    'names': {'international': '16t', 'japanese': None},
#    'abbreviation': '16t',
#    'weblink': 'https://www.speedrun.com/16t'},
#   {'id': '268e9776',
#    'names': {'international': '18 Wheeler: American Pro Trucker',
#     'japanese': None},
#    'abbreviation': '18_wheeler_american_pro_trucker',
#    'weblink': 'https://www.speedrun.com/18_wheeler_american_pro_trucker'},
#   {'id': '76r3x8l6',
#    'names': {'international': '18 Wheels of Steel: Pedal to the Metal',
#     'japanese': None},
#    'abbreviation': '18_wheels_of_steel_pedal_to_the_metal',
#    'weblink': 'https://www.speedrun.com/18_wheels_of_steel_pedal_to_the_metal'},
#   {'id': 'm1mnml4d',
#    'names': {'international': '180', 'japanese': None},
#    'abbreviation': '180',
#    'weblink': 'https://www.speedrun.com/180'},
#   {'id': 'm1mx9536',
#    'names': {'international': '187 Ride or Die', 'japanese': None},
#    'abbreviation': '187_ride_or_die',
#    'weblink': 'https://www.speedrun.com/187_ride_or_die'},
#   {'id': '4d7nw536',
#    'names': {'international': '1916 - Der Unbekannte Krieg', 'japanese': None},
#    'abbreviation': '1916_der_unbekannte_krieg',
#    'weblink': 'https://www.speedrun.com/1916_der_unbekannte_krieg'},
#   {'id': 'o6gl3vod',
#    'names': {'international': '1917 - The Alien Invasion DX',
#     'japanese': None},
#    'abbreviation': '1917_-_the_alien_invasion_dx',
#    'weblink': 'https://www.speedrun.com/1917_-_the_alien_invasion_dx'},
#   {'id': 'v1pogy76',
#    'names': {'international': '1941: Counter Attack', 'japanese': None},
#    'abbreviation': '1941_counter_attack',
#    'weblink': 'https://www.speedrun.com/1941_counter_attack'},
#   {'id': 'w6j5zx1j',
#    'names': {'international': '1942', 'japanese': None},
#    'abbreviation': '1942',
#    'weblink': 'https://www.speedrun.com/1942'},
#   {'id': '369pkx31',
#    'names': {'international': '1942: First Strike', 'japanese': None},
#    'abbreviation': '1942_first_strike',
#    'weblink': 'https://www.speedrun.com/1942_first_strike'},
#   {'id': '76rxm0v6',
#    'names': {'international': '1942: Joint Strike', 'japanese': None},
#    'abbreviation': '1942_joint_strike',
#    'weblink': 'https://www.speedrun.com/1942_joint_strike'},
#   {'id': '76rxj056',
#    'names': {'international': '1943 Kai: Midway Kaisen', 'japanese': None},
#    'abbreviation': '1943_kai_midway_kaisen',
#    'weblink': 'https://www.speedrun.com/1943_kai_midway_kaisen'},
#   {'id': 'yd49zp1e',
#    'names': {'international': '1943: The Battle of Midway', 'japanese': None},
#    'abbreviation': '1943_the_battle_of_midway',
#    'weblink': 'https://www.speedrun.com/1943_the_battle_of_midway'},
#   {'id': 'v1pxmv46',
#    'names': {'international': '1943: The Battle of Midway Mark II',
#     'japanese': None},
#    'abbreviation': '1943_the_battle_of_midway_mark_ii',
#    'weblink': 'https://www.speedrun.com/1943_the_battle_of_midway_mark_ii'},
#   {'id': '3dx2pwp1',
#    'names': {'international': '1944: The Loop Master', 'japanese': None},
#    'abbreviation': '1944_the_loop_master_',
#    'weblink': 'https://www.speedrun.com/1944_the_loop_master_'},
#   {'id': 'kdkm9yg1',
#    'names': {'international': '1945 Air force', 'japanese': None},
#    'abbreviation': '1945',
#    'weblink': 'https://www.speedrun.com/1945'},
#   {'id': '268wlek6',
#    'names': {'international': '1945k III', 'japanese': None},
#    'abbreviation': '1945k_iii',
#    'weblink': 'https://www.speedrun.com/1945k_iii'},
#   {'id': '76rx0kv6',
#    'names': {'international': '194X: 3D Dogfight', 'japanese': None},
#    'abbreviation': '194x_3d_dogfight',
#    'weblink': 'https://www.speedrun.com/194x_3d_dogfight'},
#   {'id': '9d3rj3ed',
#    'names': {'international': '1954: Alcatraz', 'japanese': None},
#    'abbreviation': '1954_alcatraz',
#    'weblink': 'https://www.speedrun.com/1954_alcatraz'},
#   {'id': '3dxk8qv1',
#    'names': {'international': '1979 Revolution: Black Friday',
#     'japanese': None},
#    'abbreviation': '1979_revolution_black_friday',
#    'weblink': 'https://www.speedrun.com/1979_revolution_black_friday'},
#   {'id': 'w6j2p51j',
#    'names': {'international': '1982 (Steam)', 'japanese': None},
#    'abbreviation': '1982',
#    'weblink': 'https://www.speedrun.com/1982'},
#   {'id': '3dx2v9p1',
#    'names': {'international': '198X', 'japanese': None},
#    'abbreviation': '198x',
#    'weblink': 'https://www.speedrun.com/198x'},
#   {'id': 'o6gnl9x1',
#    'names': {'international': '1999 Bizarre Obby', 'japanese': None},
#    'abbreviation': '1999_bizarre_obby',
#    'weblink': 'https://www.speedrun.com/1999_bizarre_obby'},
#   {'id': 'yd4p3xde',
#    'names': {'international': '1999: Hore, Mita koto ka! Seikimatsu',
#     'japanese': '1999ほれ、みたことか!世紀末'},
#    'abbreviation': '1999_hore_mita_koto_ka_seikimatsu',
#    'weblink': 'https://www.speedrun.com/1999_hore_mita_koto_ka_seikimatsu'},
#   {'id': '9dow9q71',
#    'names': {'international': '19XX: The War Against Destiny',
#     'japanese': None},
#    'abbreviation': '19xx_the_war_against_destiny',
#    'weblink': 'https://www.speedrun.com/19xx_the_war_against_destiny'},
#   {'id': '369pr3g1',
#    'names': {'international': '1BeatHeart', 'japanese': None},
#    'abbreviation': '1beatheart',
#    'weblink': 'https://www.speedrun.com/1beatheart'},
#   {'id': '268eyj76',
#    'names': {'international': '1bitHeart', 'japanese': None},
#    'abbreviation': '1bitheart',
#    'weblink': 'https://www.speedrun.com/1bitheart'},
#   {'id': '9d38m8w1',
#    'names': {'international': '1bitMarcos', 'japanese': None},
#    'abbreviation': '1bitmarcos',
#    'weblink': 'https://www.speedrun.com/1bitmarcos'},
#   {'id': 'm1zy2yz6',
#    'names': {'international': "1f y0u're a gh0st ca11 me here!",
#     'japanese': None},
#    'abbreviation': '1f_y0ure_a_gh0st_ca11_me_here',
#    'weblink': 'https://www.speedrun.com/1f_y0ure_a_gh0st_ca11_me_here'},
#   {'id': '46w3wmn1',
#    'names': {'international': '1nsane', 'japanese': None},
#    'abbreviation': '1nsane',
#    'weblink': 'https://www.speedrun.com/1nsane'},
#   {'id': '369ppxg1',
#    'names': {'international': '1px', 'japanese': None},
#    'abbreviation': '1px',
#    'weblink': 'https://www.speedrun.com/1px'},
#   {'id': '9d38xn01',
#    'names': {'international': '1UP Golden Tee', 'japanese': None},
#    'abbreviation': '1up_golden_tee',
#    'weblink': 'https://www.speedrun.com/1up_golden_tee'},
#   {'id': 'j1n8zq91',
#    'names': {'international': '1v1.LOL', 'japanese': None},
#    'abbreviation': '1v1lol',
#    'weblink': 'https://www.speedrun.com/1v1lol'},
#   {'id': 'w6j7g4e6',
#    'names': {'international': '2', 'japanese': None},
#    'abbreviation': '2',
#    'weblink': 'https://www.speedrun.com/2'},
#   {'id': 'pd0qmgv1',
#    'names': {'international': '2 3 4 players minigames pixel',
#     'japanese': None},
#    'abbreviation': '234pmp',
#    'weblink': 'https://www.speedrun.com/234pmp'},
#   {'id': 'm1mxgep6',
#    'names': {'international': '2 Builders 2 Tools', 'japanese': None},
#    'abbreviation': '2b2t',
#    'weblink': 'https://www.speedrun.com/2b2t'},
#   {'id': 'o6g989d2',
#    'names': {'international': '2 Cars', 'japanese': None},
#    'abbreviation': '2_cars',
#    'weblink': 'https://www.speedrun.com/2_cars'},
#   {'id': '3dxkgzp1',
#    'names': {'international': '2 Fast 4 Gnomz (Demo)', 'japanese': None},
#    'abbreviation': '2_fast_4_gnomz_demo',
#    'weblink': 'https://www.speedrun.com/2_fast_4_gnomz_demo'},
#   {'id': 'ldejjq51',
#    'names': {'international': '2 Fast 4 You', 'japanese': None},
#    'abbreviation': '2_fast_4_you',
#    'weblink': 'https://www.speedrun.com/2_fast_4_you'},
#   {'id': 'o1yjq2k1',
#    'names': {'international': '2 Games in One! - Marble Madness + Klax',
#     'japanese': None},
#    'abbreviation': 'mmklax',
#    'weblink': 'https://www.speedrun.com/mmklax'},
#   {'id': 'v1pkg4d8',
#    'names': {'international': '2 Ninjas 1 Cup', 'japanese': None},
#    'abbreviation': '2_ninjas_1_cup',
#    'weblink': 'https://www.speedrun.com/2_ninjas_1_cup'},
#   {'id': 'v1pxyv76',
#    'names': {'international': '2 Pipes 2', 'japanese': None},
#    'abbreviation': '2p2',
#    'weblink': 'https://www.speedrun.com/2p2'},
#   {'id': 'm1mngzxd',
#    'names': {'international': '2 Player Games - Bar', 'japanese': None},
#    'abbreviation': '2pgb',
#    'weblink': 'https://www.speedrun.com/2pgb'},
#   {'id': '36983q0d',
#    'names': {'international': '2 Player Games - Party Battle',
#     'japanese': None},
#    'abbreviation': '2pgpb',
#    'weblink': 'https://www.speedrun.com/2pgpb'},
#   {'id': 'nd28xr5d',
#    'names': {'international': '2 Player Games - Pastimes', 'japanese': None},
#    'abbreviation': '2pgp',
#    'weblink': 'https://www.speedrun.com/2pgp'},
#   {'id': 'k6qwqrx6',
#    'names': {'international': '2 Player Games - School', 'japanese': None},
#    'abbreviation': '2pgschool',
#    'weblink': 'https://www.speedrun.com/2pgschool'},
#   {'id': 'm1zkwnm1',
#    'names': {'international': '2 Player Games - Sports', 'japanese': None},
#    'abbreviation': '2pgs',
#    'weblink': 'https://www.speedrun.com/2pgs'},
#   {'id': 'y65r5471',
#    'names': {'international': '2 Player Games: the Challenge',
#     'japanese': None},
#    'abbreviation': '2_Player_Games_the_Challenge',
#    'weblink': 'https://www.speedrun.com/2_Player_Games_the_Challenge'},
#   {'id': '9d38pq01',
#    'names': {'international': '20 Bunnies', 'japanese': None},
#    'abbreviation': '20_bunnies',
#    'weblink': 'https://www.speedrun.com/20_bunnies'},
#   {'id': 'y655gv46',
#    'names': {'international': '20 Minutes Till Dawn', 'japanese': None},
#    'abbreviation': '20_minutes_till_dawn',
#    'weblink': 'https://www.speedrun.com/20_minutes_till_dawn'},
#   {'id': '46w2wpq6',
#    'names': {'international': '20.000 Leghe sotto i mari', 'japanese': None},
#    'abbreviation': '20000',
#    'weblink': 'https://www.speedrun.com/20000'},
#   {'id': 'o6g82512',
#    'names': {'international': '200% Mixed Juice!',
#     'japanese': '200％みっくすじゅ～すっ！'},
#    'abbreviation': '200mj',
#    'weblink': 'https://www.speedrun.com/200mj'},
#   {'id': 'kdk74g1m',
#    'names': {'international': '2000:1: A Space Felony', 'japanese': None},
#    'abbreviation': '2000-1-asf',
#    'weblink': 'https://www.speedrun.com/2000-1-asf'},
#   {'id': 'j1lexz6g',
#    'names': {'international': '2003 Gu Huo Lang II / 2003 Crash II Advance',
#     'japanese': None},
#    'abbreviation': 'crashiiadv',
#    'weblink': 'https://www.speedrun.com/crashiiadv'},
#   {'id': '268wzok6',
#    'names': {'international': '2009s Classic Longest Obby!', 'japanese': None},
#    'abbreviation': '2009s_classic_longest_obby',
#    'weblink': 'https://www.speedrun.com/2009s_classic_longest_obby'},
#   {'id': 'j1n87rw1',
#    'names': {'international': '200m Peanut Dash', 'japanese': None},
#    'abbreviation': '200m_peanut_dash',
#    'weblink': 'https://www.speedrun.com/200m_peanut_dash'},
#   {'id': 'nd28eo3d',
#    'names': {'international': '2010: The Graphic Adventure Game',
#     'japanese': None},
#    'abbreviation': '2010_the_graphic_adventure_game',
#    'weblink': 'https://www.speedrun.com/2010_the_graphic_adventure_game'},
#   {'id': '3698ve0d',
#    'names': {'international': '2013:Infected Wars', 'japanese': None},
#    'abbreviation': '2013infected_wars',
#    'weblink': 'https://www.speedrun.com/2013infected_wars'},
#   {'id': 'm1zjpy26',
#    'names': {'international': '2014 Fifa World Cup Brazil', 'japanese': None},
#    'abbreviation': '2014_fifa_world_cup_brazil',
#    'weblink': 'https://www.speedrun.com/2014_fifa_world_cup_brazil'},
#   {'id': 'o1yjqe41',
#    'names': {'international': '2020 Game', 'japanese': None},
#    'abbreviation': '2020_game',
#    'weblink': 'https://www.speedrun.com/2020_game'},
#   {'id': 'k6qw4q06',
#    'names': {'international': '2020 Spring Collab', 'japanese': None},
#    'abbreviation': 'sc2020',
#    'weblink': 'https://www.speedrun.com/sc2020'},
#   {'id': '576rp418',
#    'names': {'international': '2048', 'japanese': None},
#    'abbreviation': '2048',
#    'weblink': 'https://www.speedrun.com/2048'},
#   {'id': '9do57m1p',
#    'names': {'international': '2064: Read Only Memories', 'japanese': None},
#    'abbreviation': '2064_read_only_memories',
#    'weblink': 'https://www.speedrun.com/2064_read_only_memories'},
#   {'id': 'ldepze13',
#    'names': {'international': '20XX', 'japanese': None},
#    'abbreviation': '20xx',
#    'weblink': 'https://www.speedrun.com/20xx'},
#   {'id': 'y654478d',
#    'names': {'international': '222 Hearts', 'japanese': None},
#    'abbreviation': '222hearts',
#    'weblink': 'https://www.speedrun.com/222hearts'},
#   {'id': '4d7n3er6',
# ...
#    'weblink': 'https://www.speedrun.com/aikatsustars_my_special_appeal'},
#   {'id': 'pdv2pmo6',
#    'names': {'international': 'Aim Climb', 'japanese': None},
#    'abbreviation': 'aim_climb',
#    'weblink': 'https://www.speedrun.com/aim_climb'},
#   {'id': '369pyz21',
#    'names': {'international': 'Aim Course 2 by uLLeticaL', 'japanese': None},
#    'abbreviation': 'aim_course_2_by_ulletical',
#    'weblink': 'https://www.speedrun.com/aim_course_2_by_ulletical'},
#   {'id': 'j1njwl6p',
#    'names': {'international': 'Aim Course by uLLeticaL', 'japanese': None},
#    'abbreviation': 'aim_course_by_ulletical',
#    'weblink': 'https://www.speedrun.com/aim_course_by_ulletical'},
#   {'id': 'yd4o70g1',
#    'names': {'international': 'Aim GAMERZ by uLLeticaL', 'japanese': None},
#    'abbreviation': 'aim_gamerz_by_ulletical',
#    'weblink': 'https://www.speedrun.com/aim_gamerz_by_ulletical'},
#   {'id': '3dx2z351',
#    'names': {'international': 'Aim Time Trial by uLLeticaL', 'japanese': None},
#    'abbreviation': 'aim_time_trial_by_ulletical',
#    'weblink': 'https://www.speedrun.com/aim_time_trial_by_ulletical'},
#   {'id': '9d380001',
#    'names': {'international': 'Aim training', 'japanese': None},
#    'abbreviation': 'aimtraining',
#    'weblink': 'https://www.speedrun.com/aimtraining'},
#   {'id': 'j1nele91',
#    'names': {'international': 'Aimi', 'japanese': None},
#    'abbreviation': 'aimi',
#    'weblink': 'https://www.speedrun.com/aimi'},
#   {'id': 'y655rk06',
#    'names': {'international': 'Ain Dodo', 'japanese': None},
#    'abbreviation': 'ain_dodo',
#    'weblink': 'https://www.speedrun.com/ain_dodo'},
#   {'id': 'lde3zpe6',
#    'names': {'international': 'Aion Free-to-Play', 'japanese': None},
#    'abbreviation': 'aion_free-to-play',
#    'weblink': 'https://www.speedrun.com/aion_free-to-play'},
#   {'id': '4d7q5l67',
#    'names': {'international': 'Aion: Ascension', 'japanese': None},
#    'abbreviation': 'aion',
#    'weblink': 'https://www.speedrun.com/aion'},
#   {'id': 'm1mnw4d2',
#    'names': {'international': 'Air', 'japanese': None},
#    'abbreviation': 'smb1-air',
#    'weblink': 'https://www.speedrun.com/smb1-air'},
#   {'id': 'm1zk0ex1',
#    'names': {'international': 'Air Assault', 'japanese': None},
#    'abbreviation': 'air_assault',
#    'weblink': 'https://www.speedrun.com/air_assault'},
#   {'id': 'w6j70q76',
#    'names': {'international': 'Air Attack', 'japanese': None},
#    'abbreviation': 'air_attack',
#    'weblink': 'https://www.speedrun.com/air_attack'},
#   {'id': 'o1y94jo6',
#    'names': {'international': 'Air Boarder 64', 'japanese': None},
#    'abbreviation': 'air_boarder_64',
#    'weblink': 'https://www.speedrun.com/air_boarder_64'},
#   {'id': 'o1y9gyo6',
#    'names': {'international': "Air Bounce - The Jump 'n' Run Challenge",
#     'japanese': None},
#    'abbreviation': 'air_bounce',
#    'weblink': 'https://www.speedrun.com/air_bounce'},
#   {'id': 'yd4keyk6',
#    'names': {'international': 'Air Buster: Trouble Speciality Raid Unit',
#     'japanese': None},
#    'abbreviation': 'air_buster_trouble_speciality_raid_unit',
#    'weblink': 'https://www.speedrun.com/air_buster_trouble_speciality_raid_unit'},
#   {'id': 'pd0exv1e',
#    'names': {'international': 'Air Combat', 'japanese': None},
#    'abbreviation': 'aircombat',
#    'weblink': 'https://www.speedrun.com/aircombat'},
#   {'id': '46wv0ndr',
#    'names': {'international': 'Air Control', 'japanese': None},
#    'abbreviation': 'aircontrol',
#    'weblink': 'https://www.speedrun.com/aircontrol'},
#   {'id': '9d385791',
#    'names': {'international': 'Air Dribble Challenge', 'japanese': None},
#    'abbreviation': 'adc',
#    'weblink': 'https://www.speedrun.com/adc'},
#   {'id': '3dxk8vv1',
#    'names': {'international': 'Air Dribble Hoops', 'japanese': None},
#    'abbreviation': 'adhoops',
#    'weblink': 'https://www.speedrun.com/adhoops'},
#   {'id': 'pd0qz2l1',
#    'names': {'international': 'Air Dribble Melee', 'japanese': None},
#    'abbreviation': 'airdribblemelee',
#    'weblink': 'https://www.speedrun.com/airdribblemelee'},
#   {'id': 'm1mnp2xd',
#    'names': {'international': 'Air Duel', 'japanese': None},
#    'abbreviation': 'air_duel',
#    'weblink': 'https://www.speedrun.com/air_duel'},
#   {'id': 'm1zww010',
#    'names': {'international': 'Air Fortress', 'japanese': None},
#    'abbreviation': 'air_fortress',
#    'weblink': 'https://www.speedrun.com/air_fortress'},
#   {'id': 'pdv2wpv6',
#    'names': {'international': 'Air Gallet', 'japanese': None},
#    'abbreviation': 'air_gallet',
#    'weblink': 'https://www.speedrun.com/air_gallet'},
#   {'id': 'kdkm89e1',
#    'names': {'international': 'Air Hockey', 'japanese': None},
#    'abbreviation': 'air_hockey',
#    'weblink': 'https://www.speedrun.com/air_hockey'},
#   {'id': '369prm21',
#    'names': {'international': 'Air Nomad', 'japanese': None},
#    'abbreviation': 'air_nomad',
#    'weblink': 'https://www.speedrun.com/air_nomad'},
#   {'id': '4d7n8436',
#    'names': {'international': 'Air Rescue', 'japanese': None},
#    'abbreviation': 'air_rescue',
#    'weblink': 'https://www.speedrun.com/air_rescue'},
#   {'id': '9dowky31',
#    'names': {'international': 'Air Zonk', 'japanese': None},
#    'abbreviation': 'air_zonk',
#    'weblink': 'https://www.speedrun.com/air_zonk'},
#   {'id': 'm1zr8xd0',
#    'names': {'international': 'Air-Sea Battle', 'japanese': None},
#    'abbreviation': 'asb',
#    'weblink': 'https://www.speedrun.com/asb'},
#   {'id': '76rj2e18',
#    'names': {'international': 'AiRace Speed', 'japanese': 'Aiレース：スピード'},
#    'abbreviation': 'airspeed',
#    'weblink': 'https://www.speedrun.com/airspeed'},
#   {'id': 'j1l9jv1g',
#    'names': {'international': 'AiRace Xeno', 'japanese': 'Aiレース：X'},
#    'abbreviation': 'airxeno',
#    'weblink': 'https://www.speedrun.com/airxeno'},
#   {'id': 'o6g30od2',
#    'names': {'international': 'AiRace: Tunnel', 'japanese': None},
#    'abbreviation': 'airtunnel',
#    'weblink': 'https://www.speedrun.com/airtunnel'},
#   {'id': '46w94n1r',
#    'names': {'international': 'AirBlade', 'japanese': None},
#    'abbreviation': 'airblade',
#    'weblink': 'https://www.speedrun.com/airblade'},
#   {'id': 'kdkmyle1',
#    'names': {'international': 'Airborne Troops: Countdown to D-Day',
#     'japanese': None},
#    'abbreviation': 'airborne_troops',
#    'weblink': 'https://www.speedrun.com/airborne_troops'},
#   {'id': '76rx7ve6',
#    'names': {'international': 'Airfix Dogfighter', 'japanese': None},
#    'abbreviation': 'airfix_dogfighter',
#    'weblink': 'https://www.speedrun.com/airfix_dogfighter'},
#   {'id': 'o1y39846',
#    'names': {'international': 'AirForce Delta Storm (GBA)', 'japanese': None},
#    'abbreviation': 'AirForce_Delta_Storm_GBA',
#    'weblink': 'https://www.speedrun.com/AirForce_Delta_Storm_GBA'},
#   {'id': '369wzp0d',
#    'names': {'international': 'Airforce Delta Strike', 'japanese': None},
#    'abbreviation': 'airforce_delta_strike',
#    'weblink': 'https://www.speedrun.com/airforce_delta_strike'},
#   {'id': 'w6jlym4d',
#    'names': {'international': 'AirGrave', 'japanese': None},
#    'abbreviation': 'airgrave',
#    'weblink': 'https://www.speedrun.com/airgrave'},
#   {'id': '46w2omn6',
#    'names': {'international': 'Airhead', 'japanese': None},
#    'abbreviation': 'airhead',
#    'weblink': 'https://www.speedrun.com/airhead'},
#   {'id': 'j1neg5w1',
#    'names': {'international': 'AIRHEART - Tales of broken Wings',
#     'japanese': None},
#    'abbreviation': 'airheart_-_tales_of_broken_wings',
#    'weblink': 'https://www.speedrun.com/airheart_-_tales_of_broken_wings'},
#   {'id': 'lde7q513',
#    'names': {'international': 'Airlock', 'japanese': None},
#    'abbreviation': 'airlock',
#    'weblink': 'https://www.speedrun.com/airlock'},
#   {'id': 'pd0weq01',
#    'names': {'international': 'Airplane Mode', 'japanese': None},
#    'abbreviation': 'airplane_mode',
#    'weblink': 'https://www.speedrun.com/airplane_mode'},
#   {'id': 'y6555o46',
#    'names': {'international': 'Airport CEO', 'japanese': None},
#    'abbreviation': 'airport_ceo',
#    'weblink': 'https://www.speedrun.com/airport_ceo'},
#   {'id': '46w3q891',
#    'names': {'international': 'Airport Madness 3D', 'japanese': None},
#    'abbreviation': 'airport_madness_3d',
#    'weblink': 'https://www.speedrun.com/airport_madness_3d'},
#   {'id': 'o6gnn2n1',
#    'names': {'international': 'Airport Madness 3D: Volume 2',
#     'japanese': None},
#    'abbreviation': 'airport_madness_3d_volume_2',
#    'weblink': 'https://www.speedrun.com/airport_madness_3d_volume_2'},
#   {'id': 'w6j7jx76',
#    'names': {'international': 'Airs Adventure', 'japanese': None},
#    'abbreviation': 'airs_adventure',
#    'weblink': 'https://www.speedrun.com/airs_adventure'},
#   {'id': '4d7rzz17',
#    'names': {'international': 'Airscape: The Fall of Gravity',
#     'japanese': None},
#    'abbreviation': 'airscape',
#    'weblink': 'https://www.speedrun.com/airscape'},
#   {'id': '46w3k5n1',
#    'names': {'international': 'Airships: Conquer the Skies', 'japanese': None},
#    'abbreviation': 'airships_conquer_the_skies',
#    'weblink': 'https://www.speedrun.com/airships_conquer_the_skies'},
#   {'id': '46w297n6',
#    'names': {'international': 'Airu De Puzzle', 'japanese': None},
#    'abbreviation': 'airu_de_puzzle',
#    'weblink': 'https://www.speedrun.com/airu_de_puzzle'},
#   {'id': 'j1ner2l1',
#    'names': {'international': 'Airwolf (Arcade)', 'japanese': None},
#    'abbreviation': 'airwolf_arcade',
#    'weblink': 'https://www.speedrun.com/airwolf_arcade'},
#   {'id': 'k6q50o6g',
#    'names': {'international': 'Airwolf (Japan)', 'japanese': 'エアーウルフ'},
#    'abbreviation': 'airwolfjp',
#    'weblink': 'https://www.speedrun.com/airwolfjp'},
#   {'id': 'w6jl7w4d',
#    'names': {'international': 'Airwolf (US/EU)', 'japanese': None},
#    'abbreviation': 'airwolf_useu',
#    'weblink': 'https://www.speedrun.com/airwolf_useu'},
#   {'id': '268evyo6',
#    'names': {'international': 'AirXonix', 'japanese': None},
#    'abbreviation': 'airxonix',
#    'weblink': 'https://www.speedrun.com/airxonix'},
#   {'id': '76r32zq6',
#    'names': {'international': 'AK-xolotl', 'japanese': None},
#    'abbreviation': 'akxolotl',
#    'weblink': 'https://www.speedrun.com/akxolotl'},
#   {'id': 'lde3qwe6',
#    'names': {'international': 'Aka Manto | 赤マント', 'japanese': None},
#    'abbreviation': 'aka_manto',
#    'weblink': 'https://www.speedrun.com/aka_manto'},
#   {'id': 'ldej80e1',
#    'names': {'international': 'Akai Katana', 'japanese': None},
#    'abbreviation': 'akai_katana',
#    'weblink': 'https://www.speedrun.com/akai_katana'},
#   {'id': 'k6q4mr9d',
#    'names': {'international': 'Akalabeth: World of Doom', 'japanese': None},
#    'abbreviation': 'akalabeth',
#    'weblink': 'https://www.speedrun.com/akalabeth'},
#   {'id': '9do8r4k1',
#    'names': {'international': 'Akane', 'japanese': None},
#    'abbreviation': 'akane',
#    'weblink': 'https://www.speedrun.com/akane'},
#   {'id': 'm1zxx0d0',
#    'names': {'international': 'Akane the Kunoichi', 'japanese': None},
#    'abbreviation': 'akane_the_kunoichi',
#    'weblink': 'https://www.speedrun.com/akane_the_kunoichi'},
#   {'id': '369p0k21',
#    'names': {'international': 'Akatsuki Blitzkampf', 'japanese': None},
#    'abbreviation': 'akatsuki_blitzkampf',
#    'weblink': 'https://www.speedrun.com/akatsuki_blitzkampf'},
#   {'id': '3dxk3xp1',
#    'names': {'international': 'Akatsuki Blitzkampf Ausf. Achse',
#     'japanese': None},
#    'abbreviation': 'akatsuki_blitzkampf_ausf_achse',
#    'weblink': 'https://www.speedrun.com/akatsuki_blitzkampf_ausf_achse'},
#   {'id': '9d384091',
#    'names': {'international': 'Akazukin Chacha', 'japanese': None},
#    'abbreviation': 'akazukin_chacha',
#    'weblink': 'https://www.speedrun.com/akazukin_chacha'},
#   {'id': 'nd2eoged',
#    'names': {'international': 'Akemi Tan', 'japanese': None},
#    'abbreviation': 'akemi_tan',
#    'weblink': 'https://www.speedrun.com/akemi_tan'},
#   {'id': 'kdkmjwg1',
#    'names': {'international': "AKIBA'S BEAT", 'japanese': None},
#    'abbreviation': 'akibas_beat',
#    'weblink': 'https://www.speedrun.com/akibas_beat'},
#   {'id': 'y6555m76',
#    'names': {'international': "Akiba's Trip: Hellbound and Debriefed",
#     'japanese': None},
#    'abbreviation': 'akibas_trip_hellbound_and_debriefed',
#    'weblink': 'https://www.speedrun.com/akibas_trip_hellbound_and_debriefed'},
#   {'id': 'm1zekm10',
#    'names': {'international': "Akiba's Trip: Undead & Undressed",
#     'japanese': 'アキバズトリップ2'},
#    'abbreviation': 'akibas_trip_undead_and_undressed',
#    'weblink': 'https://www.speedrun.com/akibas_trip_undead_and_undressed'},
#   {'id': 'm1zkg921',
#    'names': {'international': 'Akimbo: Kung-Fu Hero', 'japanese': None},
#    'abbreviation': 'akimbo',
#    'weblink': 'https://www.speedrun.com/akimbo'},
#   {'id': '3dxkv7v1',
#    'names': {'international': 'Akirry Roll', 'japanese': None},
#    'abbreviation': 'akirry_roll',
#    'weblink': 'https://www.speedrun.com/akirry_roll'},
#   {'id': '9do8q7m1',
#    'names': {'international': 'Akkanvader', 'japanese': None},
#    'abbreviation': 'akkanvader',
#    'weblink': 'https://www.speedrun.com/akkanvader'},
#   {'id': '268w32k6',
#    'names': {'international': 'Akogare 2', 'japanese': None},
#    'abbreviation': 'akogare_2',
#    'weblink': 'https://www.speedrun.com/akogare_2'},
#   {'id': '369po721',
#    'names': {'international': 'Akogare Mario World', 'japanese': None},
#    'abbreviation': 'akogaremarioworld',
#    'weblink': 'https://www.speedrun.com/akogaremarioworld'},
#   {'id': '268wrpk6',
#    'names': {'international': 'Akuji the Demon', 'japanese': None},
#    'abbreviation': 'akuji_the_demon',
#    'weblink': 'https://www.speedrun.com/akuji_the_demon'},
#   {'id': 'w6j8021j',
#    'names': {'international': 'Akuji: The Heartless', 'japanese': None},
#    'abbreviation': 'akuji_the_heartless',
#    'weblink': 'https://www.speedrun.com/akuji_the_heartless'},
#   {'id': 'j1n4z96p',
#    'names': {'international': 'Akumajou Special Boku Dracula-kun',
#     'japanese': None},
#    'abbreviation': 'akumajou_special_boku_dracula_kun',
#    'weblink': 'https://www.speedrun.com/akumajou_special_boku_dracula_kun'},
#   {'id': 'nd28ne3d',
#    'names': {'international': 'Akumajyo Dracula Peke', 'japanese': None},
#    'abbreviation': 'peke',
#    'weblink': 'https://www.speedrun.com/peke'},
#   {'id': 'nd28375d',
#    'names': {'international': 'Akumu', 'japanese': None},
#    'abbreviation': 'akumu',
#    'weblink': 'https://www.speedrun.com/akumu'},
#   {'id': 'k6q4o7md',
#    'names': {'international': "Al Unser Jr's Road To The Top",
#     'japanese': None},
#    'abbreviation': 'al_unser_jrs_road_to_the_top',
#    'weblink': 'https://www.speedrun.com/al_unser_jrs_road_to_the_top'},
#   {'id': '4d79q5r1',
#    'names': {'international': 'Al Unser Jr. Turbo Racing', 'japanese': None},
#    'abbreviation': 'al_unser_jr._turbo_racing',
#    'weblink': 'https://www.speedrun.com/al_unser_jr._turbo_racing'},
#   {'id': 'k6qw7lm6',
#    'names': {'international': 'Alabaras Shells', 'japanese': None},
#    'abbreviation': 'alabaras_shells',
#    'weblink': 'https://www.speedrun.com/alabaras_shells'},
#   {'id': '9d3roywd',
#    'names': {'international': 'Aladdin (Hummer Team)', 'japanese': None},
#    'abbreviation': 'aladdin_hummer_team',
#    'weblink': 'https://www.speedrun.com/aladdin_hummer_team'},
#   {'id': '268exq76',
#    'names': {'international': 'Aladdin (Super Game)', 'japanese': None},
#    'abbreviation': 'aladdin_super_game',
#    'weblink': 'https://www.speedrun.com/aladdin_super_game'},
#   {'id': 'y6543g4d',
#    'names': {'international': 'Aladdin 2000 (SNES Bootleg)', 'japanese': None},
#    'abbreviation': 'aladdin_2000_snes_bootleg',
#    'weblink': 'https://www.speedrun.com/aladdin_2000_snes_bootleg'},
#   {'id': 'm1zkw0z1',
#    'names': {'international': 'Aladdin and Magic skull', 'japanese': None},
#    'abbreviation': 'aladdin_and_magic_skull',
#    'weblink': 'https://www.speedrun.com/aladdin_and_magic_skull'},
#   {'id': '76rxnrv6',
#    'names': {'international': 'Aladdin II', 'japanese': None},
#    'abbreviation': 'aladdin_ii',
#    'weblink': 'https://www.speedrun.com/aladdin_ii'}],
#  'pagination': {'offset': 0,
#   'max': 1000,
#   'size': 1000,
#   'links': [{'rel': 'next',
#     'uri': 'https://www.speedrun.com/api/v1/games?_bulk=yes&max=1000&offset=1000'}]}}

# %% [markdown]
# ### JSON Parsing

# %%
import pandas as pd
import json

# %%
first_page_json = first_page.json()

# %%
print([key for key in first_page_json])
# Out:
# ['data', 'pagination']

# %%
first_page_data = first_page_json['data']
first_page_data
# Out:
# [{'id': 'o1y32j26',
#   'names': {'international': ' Bike Unchained 2', 'japanese': None},
#   'abbreviation': '_bike_unchained_2',
#   'weblink': 'https://www.speedrun.com/_bike_unchained_2'},
#  {'id': 'y65rm041',
#   'names': {'international': " BIRDIE WING -Golf Girls' Story-",
#    'japanese': None},
#   'abbreviation': '_birdie_wing_golf_girls_story',
#   'weblink': 'https://www.speedrun.com/_birdie_wing_golf_girls_story'},
#  {'id': 'kdkqz3xd',
#   'names': {'international': ' DYNAMITE BOMB!! ', 'japanese': None},
#   'abbreviation': '_DYNAMITE_BOMB_',
#   'weblink': 'https://www.speedrun.com/_DYNAMITE_BOMB_'},
#  {'id': '3698qwld',
#   'names': {'international': ' Great Dungeon In The Sky ', 'japanese': None},
#   'abbreviation': '_great_dungeon_in_the_sky_',
#   'weblink': 'https://www.speedrun.com/_great_dungeon_in_the_sky_'},
#  {'id': 'ldej48j1',
#   'names': {'international': ' House of Da Vinci 2', 'japanese': None},
#   'abbreviation': 'the_house_of_da_vinci_2',
#   'weblink': 'https://www.speedrun.com/the_house_of_da_vinci_2'},
#  {'id': '76r3p3q6',
#   'names': {'international': ' Interference: Dead Air', 'japanese': None},
#   'abbreviation': '_interference_dead_air',
#   'weblink': 'https://www.speedrun.com/_interference_dead_air'},
#  {'id': 'j1lqerz6',
#   'names': {'international': ' LIDAR.EXE', 'japanese': None},
#   'abbreviation': 'lidar_exe',
#   'weblink': 'https://www.speedrun.com/lidar_exe'},
#  {'id': 'o6gn9981',
#   'names': {'international': ' Metal Tales: Fury of the Guitar Gods',
#    'japanese': None},
#   'abbreviation': '_metal_tales_fury_of_the_guitar_gods',
#   'weblink': 'https://www.speedrun.com/_metal_tales_fury_of_the_guitar_gods'},
#  {'id': 'pdv92zk1',
#   'names': {'international': ' Sakura X Clash - Last Millenial Spring -',
#    'japanese': None},
#   'abbreviation': '_Sakura_X_Clash__Last_Millenial_Spring_',
#   'weblink': 'https://www.speedrun.com/_Sakura_X_Clash__Last_Millenial_Spring_'},
#  {'id': 'yd4k9pg6',
#   'names': {'international': ' Shutokou Battle Gaiden - Super Technic Challenge',
#    'japanese': None},
#   'abbreviation': 'sbg_stc',
#   'weblink': 'https://www.speedrun.com/sbg_stc'},
#  {'id': 'o6gnmp81',
#   'names': {'international': ' Sōkyūgurentai/Terra Diver (Arcade)',
#    'japanese': None},
#   'abbreviation': '_sokyugurentaiterra_diver_arcade',
#   'weblink': 'https://www.speedrun.com/_sokyugurentaiterra_diver_arcade'},
#  {'id': 'o1yjg0r1',
#   'names': {'international': ' Space Opera: Wyvern Wings', 'japanese': None},
#   'abbreviation': '_space_opera_wyvern_wings',
#   'weblink': 'https://www.speedrun.com/_space_opera_wyvern_wings'},
#  {'id': '268wqg96',
#   'names': {'international': ' Stories of Nibel: Tale of Ura',
#    'japanese': None},
#   'abbreviation': '_stories_of_nibel_tale_of_ura',
#   'weblink': 'https://www.speedrun.com/_stories_of_nibel_tale_of_ura'},
#  {'id': 'j1n47nw6',
#   'names': {'international': ' Ultimate Board Game Collection 12 Classics from Around The World',
#    'japanese': None},
#   'abbreviation': 'Ultimate_Board_Game_Collection_12_Classics_from_Around_The_World',
#   'weblink': 'https://www.speedrun.com/Ultimate_Board_Game_Collection_12_Classics_from_Around_The_World'},
#  {'id': '76r43ge1',
#   'names': {'international': ' Wing of Darkness', 'japanese': None},
#   'abbreviation': '_Wing_of_Darkness',
#   'weblink': 'https://www.speedrun.com/_Wing_of_Darkness'},
#  {'id': 'k6qqkx6g',
#   'names': {'international': '! Fishy !', 'japanese': None},
#   'abbreviation': 'fishy',
#   'weblink': 'https://www.speedrun.com/fishy'},
#  {'id': '268w4876',
#   'names': {'international': '! Wild Russia !', 'japanese': None},
#   'abbreviation': '1287250',
#   'weblink': 'https://www.speedrun.com/1287250'},
#  {'id': '3dx2pk41',
#   'names': {'international': '!findseed the map', 'japanese': None},
#   'abbreviation': 'findseed',
#   'weblink': 'https://www.speedrun.com/findseed'},
#  {'id': 'j1n83r91',
#   'names': {'international': '"Happy" Platformer', 'japanese': None},
#   'abbreviation': 'happy_platformer',
#   'weblink': 'https://www.speedrun.com/happy_platformer'},
#  {'id': 'y655yj46',
#   'names': {'international': '#21: The World', 'japanese': None},
#   'abbreviation': '_the_world',
#   'weblink': 'https://www.speedrun.com/_the_world'},
#  {'id': 'ldej49n1',
#   'names': {'international': '#compass', 'japanese': None},
#   'abbreviation': 'compass',
#   'weblink': 'https://www.speedrun.com/compass'},
#  {'id': '3dxk5051',
#   'names': {'international': '#FUNTIME', 'japanese': None},
#   'abbreviation': 'funtime',
#   'weblink': 'https://www.speedrun.com/funtime'},
#  {'id': 'j1n8eol1',
#   'names': {'international': '#SaveDiscord', 'japanese': None},
#   'abbreviation': 'discord',
#   'weblink': 'https://www.speedrun.com/discord'},
#  {'id': '46wxo91r',
#   'names': {'international': '&meow; (Meow)', 'japanese': None},
#   'abbreviation': 'meow',
#   'weblink': 'https://www.speedrun.com/meow'},
#  {'id': 'pdvp7kdw',
#   'names': {'international': "'Allo 'Allo! Cartoon Fun!", 'japanese': None},
#   'abbreviation': 'allo_allo_cartoon_fun',
#   'weblink': 'https://www.speedrun.com/allo_allo_cartoon_fun'},
#  {'id': 'm1mx54x6',
#   'names': {'international': "'n Verlore Verstand", 'japanese': None},
#   'abbreviation': 'nvv',
#   'weblink': 'https://www.speedrun.com/nvv'},
#  {'id': 'm1m8opd2',
#   'names': {'international': "'Splosion Man", 'japanese': None},
#   'abbreviation': 'splosion_man',
#   'weblink': 'https://www.speedrun.com/splosion_man'},
#  {'id': 'j1n8ell1',
#   'names': {'international': '(ben) bonk the ball', 'japanese': None},
#   'abbreviation': 'ben_bonk_the_ball',
#   'weblink': 'https://www.speedrun.com/ben_bonk_the_ball'},
#  {'id': '268wqw56',
#   'names': {'international': "(Deltarune Chapter 3) - Mike's Big Showdown",
#    'japanese': None},
#   'abbreviation': 'mikes_big_showdown',
#   'weblink': 'https://www.speedrun.com/mikes_big_showdown'},
#  {'id': 'lde3q7x6',
#   'names': {'international': '(Mario) The Music Box -ARC-', 'japanese': None},
#   'abbreviation': 'mtmba',
#   'weblink': 'https://www.speedrun.com/mtmba'},
#  {'id': '76r335l6',
#   'names': {'international': '(Mario) The Music Box Remastered',
#    'japanese': None},
#   'abbreviation': 'mtmbr',
#   'weblink': 'https://www.speedrun.com/mtmbr'},
#  {'id': '3dxkwry1',
#   'names': {'international': '(Scratch) Undieable Appel', 'japanese': None},
#   'abbreviation': 'Die_No_Appel_Scratch',
#   'weblink': 'https://www.speedrun.com/Die_No_Appel_Scratch'},
#  {'id': 'pd0nwj21',
#   'names': {'international': '(square)', 'japanese': None},
#   'abbreviation': 'square',
#   'weblink': 'https://www.speedrun.com/square'},
#  {'id': '9d3yzw6l',
#   'names': {'international': '(The) Final Fantasy Legend',
#    'japanese': '魔界塔士 Sa・Ga'},
#   'abbreviation': 'the_final_fantasy_legend',
#   'weblink': 'https://www.speedrun.com/the_final_fantasy_legend'},
#  {'id': 'y6552w06',
#   'names': {'international': '*NEW* SCUFFED BHOP SIMULATION 2026 GOTY EDITION',
#    'japanese': None},
#   'abbreviation': 'new_scuffed_bhop_simulation_2026_goty_edition',
#   'weblink': 'https://www.speedrun.com/new_scuffed_bhop_simulation_2026_goty_edition'},
#  {'id': 'v1pxx376',
#   'names': {'international': '*NEW* SCUFFED EPIC BHOP SIMULATOR 2023 (POG CHAMP)',
#    'japanese': None},
#   'abbreviation': 'new_scuffed_epic_bhop_simulator_2023_pog_champ',
#   'weblink': 'https://www.speedrun.com/new_scuffed_epic_bhop_simulator_2023_pog_champ'},
#  {'id': '268wv896',
#   'names': {'international': '- Pixel Sheep -', 'japanese': None},
#   'abbreviation': 'pixel_sheep',
#   'weblink': 'https://www.speedrun.com/pixel_sheep'},
#  {'id': 'm1zyjpx6',
#   'names': {'international': '-256', 'japanese': None},
#   'abbreviation': '256',
#   'weblink': 'https://www.speedrun.com/256'},
#  {'id': '46w3n071',
#   'names': {'international': '-SPROUT-', 'japanese': None},
#   'abbreviation': '-sprout-',
#   'weblink': 'https://www.speedrun.com/-sprout-'},
#  {'id': 'y655rn36',
#   'names': {'international': '...Iru!', 'japanese': None},
#   'abbreviation': 'iru',
#   'weblink': 'https://www.speedrun.com/iru'},
#  {'id': 'm1m8r3d2',
#   'names': {'international': '..and the mooncats', 'japanese': None},
#   'abbreviation': '.and_the_mooncats',
#   'weblink': 'https://www.speedrun.com/.and_the_mooncats'},
#  {'id': 'o6gnx591',
#   'names': {'international': '.cat Milk', 'japanese': None},
#   'abbreviation': 'cat_milk',
#   'weblink': 'https://www.speedrun.com/cat_milk'},
#  {'id': 'y65e0e6e',
#   'names': {'international': '.flow', 'japanese': None},
#   'abbreviation': 'dotflow',
#   'weblink': 'https://www.speedrun.com/dotflow'},
#  {'id': 'nd2ekj5d',
#   'names': {'international': '.hack//G.U. Last Recode', 'japanese': None},
#   'abbreviation': 'guhd',
#   'weblink': 'https://www.speedrun.com/guhd'},
#  {'id': 'pd0y226e',
#   'names': {'international': '.hack//G.U. Volume 1: Rebirth',
#    'japanese': None},
#   'abbreviation': '.hack_g.u._volume_1_rebirth',
#   'weblink': 'https://www.speedrun.com/.hack_g.u._volume_1_rebirth'},
#  {'id': 'kdk7ye1m',
#   'names': {'international': '.hack//G.U. Volume 2: Reminisce',
#    'japanese': None},
#   'abbreviation': '.hack_g.u._volume_2_reminisce',
#   'weblink': 'https://www.speedrun.com/.hack_g.u._volume_2_reminisce'},
#  {'id': 'o1ygzr1q',
#   'names': {'international': '.hack//G.U. Volume 3: Redemption',
#    'japanese': None},
#   'abbreviation': '.hack_g.u._volume_3_redemption',
#   'weblink': 'https://www.speedrun.com/.hack_g.u._volume_3_redemption'},
#  {'id': 'k6qrzm1g',
#   'names': {'international': '.hack//Infection', 'japanese': '.hack//感染拡大'},
#   'abbreviation': '.hackinfection',
#   'weblink': 'https://www.speedrun.com/.hackinfection'},
#  {'id': '369k2gdl',
#   'names': {'international': '.hack//Mutation', 'japanese': '.hack//悪性変異'},
#   'abbreviation': '.hackmutation',
#   'weblink': 'https://www.speedrun.com/.hackmutation'},
#  {'id': 'y65p30de',
#   'names': {'international': '.hack//Outbreak', 'japanese': None},
#   'abbreviation': '.hackoutbreak',
#   'weblink': 'https://www.speedrun.com/.hackoutbreak'},
#  {'id': 'w6j2ye1j',
#   'names': {'international': '.hack//Quarantine', 'japanese': None},
#   'abbreviation': '.hackquarantine',
#   'weblink': 'https://www.speedrun.com/.hackquarantine'},
#  {'id': 'pdvnrv6w',
#   'names': {'international': '.kkrieger', 'japanese': None},
#   'abbreviation': 'kkrieger',
#   'weblink': 'https://www.speedrun.com/kkrieger'},
#  {'id': 'pdv2e8v6',
#   'names': {'international': '.S', 'japanese': None},
#   'abbreviation': 's_torcado',
#   'weblink': 'https://www.speedrun.com/s_torcado'},
#  {'id': 'v1pxvxm6',
#   'names': {'international': '//N.P.P.D. RUSH//- The milk of Ultraviolet',
#    'japanese': None},
#   'abbreviation': 'nppdrush',
#   'weblink': 'https://www.speedrun.com/nppdrush'},
#  {'id': 'nd28v03d',
#   'names': {'international': '0 Degrees', 'japanese': None},
#   'abbreviation': '0_degrees',
#   'weblink': 'https://www.speedrun.com/0_degrees'},
#  {'id': 'nd2g9v10',
#   'names': {'international': '007 Legends', 'japanese': None},
#   'abbreviation': '007_legends',
#   'weblink': 'https://www.speedrun.com/007_legends'},
#  {'id': 'o1y93e46',
#   'names': {'international': '007 Racing', 'japanese': None},
#   'abbreviation': '007_racing',
#   'weblink': 'https://www.speedrun.com/007_racing'},
#  {'id': 'y65r071e',
#   'names': {'international': '007: Agent Under Fire', 'japanese': None},
#   'abbreviation': 'auf',
#   'weblink': 'https://www.speedrun.com/auf'},
#  {'id': 'o1yql4dq',
#   'names': {'international': '007: From Russia With Love', 'japanese': None},
#   'abbreviation': '007frwl',
#   'weblink': 'https://www.speedrun.com/007frwl'},
#  {'id': '268j3kdp',
#   'names': {'international': '007: NightFire (GBA)', 'japanese': None},
#   'abbreviation': '007nf_gba',
#   'weblink': 'https://www.speedrun.com/007nf_gba'},
#  {'id': 'j1llvev1',
#   'names': {'international': '007: Nightfire Category Extensions',
#    'japanese': None},
#   'abbreviation': '007nfca',
#   'weblink': 'https://www.speedrun.com/007nfca'},
#  {'id': 'nd272v10',
#   'names': {'international': '007: The World is Not Enough', 'japanese': None},
#   'abbreviation': 'twine',
#   'weblink': 'https://www.speedrun.com/twine'},
#  {'id': 'v1p5rpd8',
#   'names': {'international': '007: The World is Not Enough (PS1)',
#    'japanese': None},
#   'abbreviation': 'twineps1',
#   'weblink': 'https://www.speedrun.com/twineps1'},
#  {'id': 'o6gl8y8d',
#   'names': {'international': '03.04', 'japanese': None},
#   'abbreviation': '03.04',
#   'weblink': 'https://www.speedrun.com/03.04'},
#  {'id': 'y65pv8de',
#   'names': {'international': '0error0', 'japanese': None},
#   'abbreviation': '0error0',
#   'weblink': 'https://www.speedrun.com/0error0'},
#  {'id': 'j1n80491',
#   'names': {'international': '0h n0', 'japanese': None},
#   'abbreviation': '0h_n0',
#   'weblink': 'https://www.speedrun.com/0h_n0'},
#  {'id': '46w22k96',
#   'names': {'international': '0R8 Demo', 'japanese': None},
#   'abbreviation': '0r8_demo',
#   'weblink': 'https://www.speedrun.com/0r8_demo'},
#  {'id': '76r3z4q6',
#   'names': {'international': '1 Bit Survivor', 'japanese': None},
#   'abbreviation': '1bs',
#   'weblink': 'https://www.speedrun.com/1bs'},
#  {'id': 'yd4knwg6',
#   'names': {'international': '1 on 1 Government', 'japanese': None},
#   'abbreviation': '1_on_1_government',
#   'weblink': 'https://www.speedrun.com/1_on_1_government'},
#  {'id': 'o1y9np26',
#   'names': {'international': '1 Screen Platformer', 'japanese': None},
#   'abbreviation': '1sp',
#   'weblink': 'https://www.speedrun.com/1sp'},
#  {'id': 'pdvv39dw',
#   'names': {'international': '1 vs 100', 'japanese': None},
#   'abbreviation': '1_vs_100',
#   'weblink': 'https://www.speedrun.com/1_vs_100'},
#  {'id': '4d72l367',
#   'names': {'international': '1-2-Switch', 'japanese': None},
#   'abbreviation': '1-2-switch',
#   'weblink': 'https://www.speedrun.com/1-2-switch'},
#  {'id': 'yd4oqp51',
#   'names': {'international': '10 Beautiful Postcards', 'japanese': None},
#   'abbreviation': 'tenpostcards',
#   'weblink': 'https://www.speedrun.com/tenpostcards'},
#  {'id': '46w332l1',
#   'names': {'international': '10 Gnomes 10: Seashore', 'japanese': None},
#   'abbreviation': '10_gnomes_10_2008',
#   'weblink': 'https://www.speedrun.com/10_gnomes_10_2008'},
#  {'id': 'o6glln8d',
#   'names': {'international': '10 Gnomes 11: the Remains', 'japanese': None},
#   'abbreviation': '10_gnomes_11',
#   'weblink': 'https://www.speedrun.com/10_gnomes_11'},
#  {'id': '76rxx3v6',
#   'names': {'international': '10 Gnomes 12: the Tank', 'japanese': None},
#   'abbreviation': '10_gnomes_12',
#   'weblink': 'https://www.speedrun.com/10_gnomes_12'},
#  {'id': 'k6q44wmd',
#   'names': {'international': '10 Gnomes 1: the Rooftops', 'japanese': None},
#   'abbreviation': '10_gnomes_1',
#   'weblink': 'https://www.speedrun.com/10_gnomes_1'},
#  {'id': 'j1nee8e1',
#   'names': {'international': '10 Gnomes 2: Walk in the Park',
#    'japanese': None},
#   'abbreviation': '10_gnomes_2',
#   'weblink': 'https://www.speedrun.com/10_gnomes_2'},
#  {'id': 'lde33jj6',
#   'names': {'international': '10 Gnomes 3: Early Spring Garden',
#    'japanese': None},
#   'abbreviation': '10_gnomes_3',
#   'weblink': 'https://www.speedrun.com/10_gnomes_3'},
#  {'id': '268eew96',
#   'names': {'international': '10 Gnomes 4: Foggy Flat', 'japanese': None},
#   'abbreviation': '10_gnomes_4',
#   'weblink': 'https://www.speedrun.com/10_gnomes_4'},
#  {'id': '9doww8k1',
#   'names': {'international': '10 Gnomes 5: the Shipyard', 'japanese': None},
#   'abbreviation': '10_gnomes_5',
#   'weblink': 'https://www.speedrun.com/10_gnomes_5'},
#  {'id': 'm1mxxn36',
#   'names': {'international': '10 Gnomes 6: the Hall', 'japanese': None},
#   'abbreviation': '10_gnomes_6',
#   'weblink': 'https://www.speedrun.com/10_gnomes_6'},
#  {'id': 'yd4ookg1',
#   'names': {'international': '10 Gnomes 7: the Solitude', 'japanese': None},
#   'abbreviation': '10_gnomes_7',
#   'weblink': 'https://www.speedrun.com/10_gnomes_7'},
#  {'id': '3dx22k51',
#   'names': {'international': '10 Gnomes 8: Water Forge', 'japanese': None},
#   'abbreviation': '10_gnomes_8',
#   'weblink': 'https://www.speedrun.com/10_gnomes_8'},
#  {'id': 'v1pooxz6',
#   'names': {'international': '10 Gnomes 9: Chemistry', 'japanese': None},
#   'abbreviation': '10_gnomes_9_chemistry',
#   'weblink': 'https://www.speedrun.com/10_gnomes_9_chemistry'},
#  {'id': 'j1lllqj1',
#   'names': {'international': '10 Gnomes in Bologna', 'japanese': None},
#   'abbreviation': '10_gnomes_in_b',
#   'weblink': 'https://www.speedrun.com/10_gnomes_in_b'},
#  {'id': 'pdvzz2k6',
#   'names': {'international': '10 Gnomes in Dubrovnik', 'japanese': None},
#   'abbreviation': '10_gnomes_in_d',
#   'weblink': 'https://www.speedrun.com/10_gnomes_in_d'},
#  {'id': 'pd0wwq31',
#   'names': {'international': '10 Gnomes in Liege', 'japanese': None},
#   'abbreviation': '10_gnomes_in_l',
#   'weblink': 'https://www.speedrun.com/10_gnomes_in_l'},
#  {'id': '9d3r9p0d',
#   'names': {'international': '10 Gnomes in Malmo', 'japanese': None},
#   'abbreviation': '10_gnomes_in_malmo',
#   'weblink': 'https://www.speedrun.com/10_gnomes_in_malmo'},
#  {'id': 'nd2ee8qd',
#   'names': {'international': '10 Gnomes in Montaigut-le-Blanc',
#    'japanese': None},
#   'abbreviation': '10_gnomes_in_m',
#   'weblink': 'https://www.speedrun.com/10_gnomes_in_m'},
#  {'id': '36983w8d',
#   'names': {'international': '10 Gnomes in New York', 'japanese': None},
#   'abbreviation': '10_gnomes_in_new_york',
#   'weblink': 'https://www.speedrun.com/10_gnomes_in_new_york'},
#  {'id': 'j1ne2ml1',
#   'names': {'international': '10 Gnomes in Oristano', 'japanese': None},
#   'abbreviation': '10_gnomes_in_oristano',
#   'weblink': 'https://www.speedrun.com/10_gnomes_in_oristano'},
#  {'id': 'k6q4krxd',
#   'names': {'international': '10 Gnomes in Paris', 'japanese': None},
#   'abbreviation': '10_gnomes_in_paris',
#   'weblink': 'https://www.speedrun.com/10_gnomes_in_paris'},
#  {'id': '369pp831',
#   'names': {'international': '10 Gnomes in Porto Petro', 'japanese': None},
#   'abbreviation': '10_gnomes_in_p',
#   'weblink': 'https://www.speedrun.com/10_gnomes_in_p'},
#  {'id': '4d799nr1',
#   'names': {'international': '10 Gnomes in Pothia', 'japanese': None},
#   'abbreviation': '10_gnomes_in_pothia',
#   'weblink': 'https://www.speedrun.com/10_gnomes_in_pothia'},
#  {'id': '9d3rr80d',
#   'names': {'international': '10 Gnomes in Trstenik', 'japanese': None},
#   'abbreviation': '10_gnomes_in_t',
#   'weblink': 'https://www.speedrun.com/10_gnomes_in_t'},
#  {'id': 'm1zjjk06',
#   'names': {'international': '10 Gnomes in Venice', 'japanese': None},
#   'abbreviation': '10_gnomes_in_v',
#   'weblink': 'https://www.speedrun.com/10_gnomes_in_v'},
#  {'id': '4d7n55r6',
#   'names': {'international': '10 Minutes 1 Hour 2 Hours', 'japanese': None},
#   'abbreviation': '10_minutes_1_hour_2_hours',
#   'weblink': 'https://www.speedrun.com/10_minutes_1_hour_2_hours'},
#  {'id': 'm1zm2m60',
#   'names': {'international': '10 Second Ninja', 'japanese': None},
#   'abbreviation': '10sn',
#   'weblink': 'https://www.speedrun.com/10sn'},
#  {'id': 'm1mkwpd2',
#   'names': {'international': '10 Second Ninja X', 'japanese': None},
#   'abbreviation': '10snx',
#   'weblink': 'https://www.speedrun.com/10snx'},
#  {'id': 'pdvz9v46',
#   'names': {'international': '10 Second Run Returns', 'japanese': None},
#   'abbreviation': '10srr',
#   'weblink': 'https://www.speedrun.com/10srr'},
#  {'id': 'j1llv941',
#   'names': {'international': '10 Second Shuriken', 'japanese': None},
#   'abbreviation': '10_second_shuriken',
#   'weblink': 'https://www.speedrun.com/10_second_shuriken'},
#  {'id': '46w27y36',
#   'names': {'international': '10 second to win', 'japanese': None},
#   'abbreviation': '10_seconds_to_win',
#   'weblink': 'https://www.speedrun.com/10_seconds_to_win'},
#  {'id': 'v1pxrm86',
#   'names': {'international': '10 Seconds', 'japanese': None},
#   'abbreviation': '10_seconds',
#   'weblink': 'https://www.speedrun.com/10_seconds'},
#  {'id': '3dxkexy1',
#   'names': {'international': '10 Seconds or less', 'japanese': None},
#   'abbreviation': '10s_or_less',
#   'weblink': 'https://www.speedrun.com/10s_or_less'},
#  {'id': 'ldejx3l1',
#   'names': {'international': '10-Pin Bowling', 'japanese': None},
#   'abbreviation': '10pinbowling',
#   'weblink': 'https://www.speedrun.com/10pinbowling'},
#  {'id': 'm1m0wx62',
#   'names': {'international': '10-Yard Fight', 'japanese': '10ヤードファイト'},
#   'abbreviation': '10-yard_fight',
#   'weblink': 'https://www.speedrun.com/10-yard_fight'},
#  {'id': 'o6gkzx51',
#   'names': {'international': '100 Hidden Aliens', 'japanese': None},
#   'abbreviation': '100_hidden_aliens',
#   'weblink': 'https://www.speedrun.com/100_hidden_aliens'},
#  {'id': 'w6j7wp76',
#   'names': {'international': '100 Hidden Birds', 'japanese': None},
#   'abbreviation': '100_hidden_birds',
#   'weblink': 'https://www.speedrun.com/100_hidden_birds'},
#  {'id': 'ldejo9n1',
#   'names': {'international': '100 hidden cats', 'japanese': None},
#   'abbreviation': '100_hidden_cats',
#   'weblink': 'https://www.speedrun.com/100_hidden_cats'},
#  {'id': '9d3woew1',
#   'names': {'international': '100 Hidden Cats 2', 'japanese': None},
#   'abbreviation': '100_hidden_cats_2',
#   'weblink': 'https://www.speedrun.com/100_hidden_cats_2'},
#  {'id': 'nd27kne1',
#   'names': {'international': '100 Hidden Cupcakes', 'japanese': None},
#   'abbreviation': '100_hidden_cupcakes',
#   'weblink': 'https://www.speedrun.com/100_hidden_cupcakes'},
#  {'id': 'j1ln4oe6',
#   'names': {'international': '100 Hidden Cups', 'japanese': None},
#   'abbreviation': '100_hidden_cups',
#   'weblink': 'https://www.speedrun.com/100_hidden_cups'},
#  {'id': 'y65rmo01',
#   'names': {'international': '100 Hidden Fish', 'japanese': None},
#   'abbreviation': '100_hidden_fish',
#   'weblink': 'https://www.speedrun.com/100_hidden_fish'},
#  {'id': 'v1px3y76',
#   'names': {'international': '100 Hidden Frogs', 'japanese': None},
#   'abbreviation': '100_hidden_frogs',
#   'weblink': 'https://www.speedrun.com/100_hidden_frogs'},
#  {'id': 'o1y325r6',
#   'names': {'international': '100 Hidden Gnomes', 'japanese': None},
#   'abbreviation': '100_hidden_gnomes',
#   'weblink': 'https://www.speedrun.com/100_hidden_gnomes'},
#  {'id': '76r4wgq1',
#   'names': {'international': '100 Hidden Hares', 'japanese': None},
#   'abbreviation': '100_hidden_hares',
#   'weblink': 'https://www.speedrun.com/100_hidden_hares'},
#  {'id': 'pdv93041',
#   'names': {'international': '100 Hidden Mice', 'japanese': None},
#   'abbreviation': '100_hidden_mice',
#   'weblink': 'https://www.speedrun.com/100_hidden_mice'},
#  {'id': 'j1n8gme1',
#   'names': {'international': '100 hidden rams', 'japanese': None},
#   'abbreviation': '100_hidden_rams',
#   'weblink': 'https://www.speedrun.com/100_hidden_rams'},
#  {'id': '369wzgld',
#   'names': {'international': '100 Hidden Turtles', 'japanese': None},
#   'abbreviation': '100_hidden_turtles',
#   'weblink': 'https://www.speedrun.com/100_hidden_turtles'},
#  {'id': '268w2v96',
#   'names': {'international': '100 Meters Race', 'japanese': None},
#   'abbreviation': '100_meters_race',
#   'weblink': 'https://www.speedrun.com/100_meters_race'},
#  {'id': 'lde33q56',
#   'names': {'international': '100 Rooms of Enemies', 'japanese': None},
#   'abbreviation': '100rooms',
#   'weblink': 'https://www.speedrun.com/100rooms'},
#  {'id': '9dowmo31',
#   'names': {'international': '100 Rooms of Kuso', 'japanese': None},
#   'abbreviation': '100_rooms_of_kuso',
#   'weblink': 'https://www.speedrun.com/100_rooms_of_kuso'},
#  {'id': '369plr21',
#   'names': {'international': '100 vacas', 'japanese': None},
#   'abbreviation': '100_vacas',
#   'weblink': 'https://www.speedrun.com/100_vacas'},
#  {'id': 'j1n8evl1',
#   'names': {'international': '100% Complete', 'japanese': None},
#   'abbreviation': '100_complete',
#   'weblink': 'https://www.speedrun.com/100_complete'},
#  {'id': 'j1n2gw1p',
#   'names': {'international': '100% Orange Juice!',
#    'japanese': '100%おれんじじゅ～すっ！'},
#   'abbreviation': '100oj',
#   'weblink': 'https://www.speedrun.com/100oj'},
#  {'id': 'o6ge0n12',
#   'names': {'international': '1000 Amps', 'japanese': None},
#   'abbreviation': '1000_amps',
#   'weblink': 'https://www.speedrun.com/1000_amps'},
#  {'id': 'm1mk8xd2',
#   'names': {'international': '1000 Coins', 'japanese': None},
#   'abbreviation': '1000',
#   'weblink': 'https://www.speedrun.com/1000'},
#  {'id': 'j1llmjj1',
#   'names': {'international': '1000 Days to Escape', 'japanese': None},
#   'abbreviation': '1000_days_to_escape',
#   'weblink': 'https://www.speedrun.com/1000_days_to_escape'},
#  {'id': '9do4vm6p',
#   'names': {'international': '10000000', 'japanese': None},
#   'abbreviation': '10000000',
#   'weblink': 'https://www.speedrun.com/10000000'},
#  {'id': 'yd4o5w1e',
#   'names': {'international': '1001 Spikes', 'japanese': None},
#   'abbreviation': '1001_spikes',
#   'weblink': 'https://www.speedrun.com/1001_spikes'},
#  {'id': 'm1zk3721',
#   'names': {'international': '100m Race', 'japanese': None},
#   'abbreviation': 'race',
#   'weblink': 'https://www.speedrun.com/race'},
#  {'id': 'o1y989r6',
#   'names': {'international': '100th Anniversary of the Crossword Puzzle',
#    'japanese': None},
#   'abbreviation': '100th_anniversary_of_the_crossword_puzzle',
#   'weblink': 'https://www.speedrun.com/100th_anniversary_of_the_crossword_puzzle'},
#  {'id': '268eko56',
#   'names': {'international': '101 Dalmatians: Escape from DeVil Manor',
#    'japanese': None},
#   'abbreviation': '101_dalmatians_escape_from_devil_manor',
#   'weblink': 'https://www.speedrun.com/101_dalmatians_escape_from_devil_manor'},
#  {'id': 'v1pxz2m6',
#   'names': {'international': '101-in-1 Explosive Megamix (DS)',
#    'japanese': None},
#   'abbreviation': '101in1_explosive_megamix_ds',
#   'weblink': 'https://www.speedrun.com/101in1_explosive_megamix_ds'},
#  {'id': 'm1mnlokd',
#   'names': {'international': '101-in-1 Games', 'japanese': None},
#   'abbreviation': '101in1games',
#   'weblink': 'https://www.speedrun.com/101in1games'},
#  {'id': '76r37p56',
#   'names': {'international': '101-in-1 Games 2: Evolution ', 'japanese': None},
#   'abbreviation': '101in12',
#   'weblink': 'https://www.speedrun.com/101in12'},
#  {'id': '268w8r76',
#   'names': {'international': '101-in-1 Games Anthology', 'japanese': None},
#   'abbreviation': '101in1ant',
#   'weblink': 'https://www.speedrun.com/101in1ant'},
#  {'id': 'pdvlzo1w',
#   'names': {'international': '1010!', 'japanese': None},
#   'abbreviation': '1010',
#   'weblink': 'https://www.speedrun.com/1010'},
#  {'id': 'w6jlpned',
#   'names': {'international': '1066', 'japanese': None},
#   'abbreviation': '1066',
#   'weblink': 'https://www.speedrun.com/1066'},
#  {'id': '9dowvo1p',
#   'names': {'international': '1080° Avalanche',
#    'japanese': 'テン・エイティ シルバーストーム'},
#   'abbreviation': '1080avalanche',
#   'weblink': 'https://www.speedrun.com/1080avalanche'},
#  {'id': '268ery6p',
#   'names': {'international': '1080° Snowboarding',
#    'japanese': 'テン・エイティ スノーボーディング'},
#   'abbreviation': '1080snowboarding',
#   'weblink': 'https://www.speedrun.com/1080snowboarding'},
#  {'id': 'o6gn0vx1',
#   'names': {'international': '10mg :)', 'japanese': None},
#   'abbreviation': '10mgsmileyface',
#   'weblink': 'https://www.speedrun.com/10mgsmileyface'},
#  {'id': 'j1llgoe1',
#   'names': {'international': '10S', 'japanese': None},
#   'abbreviation': '10s',
#   'weblink': 'https://www.speedrun.com/10s'},
#  {'id': 'k6q47god',
#   'names': {'international': '10th Anniversary Map', 'japanese': None},
#   'abbreviation': 'mcm_10am',
#   'weblink': 'https://www.speedrun.com/mcm_10am'},
#  {'id': 'pdvze346',
#   'names': {'international': '10^2 (Minecraft Map)', 'japanese': None},
#   'abbreviation': '10_squared_series',
#   'weblink': 'https://www.speedrun.com/10_squared_series'},
#  {'id': '4d79m331',
#   'names': {'international': '112 Operator', 'japanese': None},
#   'abbreviation': '112_operator',
#   'weblink': 'https://www.speedrun.com/112_operator'},
#  {'id': '3dx2xk41',
#   'names': {'international': '1187: Episode One', 'japanese': None},
#   'abbreviation': '1187ep1',
#   'weblink': 'https://www.speedrun.com/1187ep1'},
#  {'id': '3dxwxg1y',
#   'names': {'international': '12 is Better Than 6', 'japanese': None},
#   'abbreviation': '12_is_better_than_6',
#   'weblink': 'https://www.speedrun.com/12_is_better_than_6'},
#  {'id': 'nd297r60',
#   'names': {'international': '12 Labours of Hercules', 'japanese': None},
#   'abbreviation': '12loh1',
#   'weblink': 'https://www.speedrun.com/12loh1'},
#  {'id': 'ldevql13',
#   'names': {'international': '12 Labours of Hercules II: The Cretan Bull',
#    'japanese': None},
#   'abbreviation': '12loh2',
#   'weblink': 'https://www.speedrun.com/12loh2'},
#  {'id': '268g4ydp',
#   'names': {'international': '12 Labours of Hercules III: Girl Power',
#    'japanese': None},
#   'abbreviation': '12loh3',
#   'weblink': 'https://www.speedrun.com/12loh3'},
#  {'id': '9dom5o6p',
#   'names': {'international': '12 Labours of Hercules IV: Mother Nature',
#    'japanese': None},
#   'abbreviation': '12loh4',
#   'weblink': 'https://www.speedrun.com/12loh4'},
#  {'id': 'pdv27mk6',
#   'names': {'international': "12 Labours of Hercules IX: A Hero's Moonwalk",
#    'japanese': None},
#   'abbreviation': '12_labours_of_hercules_ix_a_heros_moonwalk',
#   'weblink': 'https://www.speedrun.com/12_labours_of_hercules_ix_a_heros_moonwalk'},
#  {'id': 'm1m85xd2',
#   'names': {'international': '12 Labours of Hercules V: Kids of Hellas',
#    'japanese': None},
#   'abbreviation': '12loh5',
#   'weblink': 'https://www.speedrun.com/12loh5'},
#  {'id': 'yd44pkde',
#   'names': {'international': '12 Labours of Hercules VI: Race for Olympus',
#    'japanese': None},
#   'abbreviation': '12loh6',
#   'weblink': 'https://www.speedrun.com/12loh6'},
#  {'id': 'nd283xqd',
#   'names': {'international': '12 Labours of Hercules VII: Fleecing The Fleece',
#    'japanese': None},
#   'abbreviation': '12_labours_of_hercules_vii_fleecing_the_fleece',
#   'weblink': 'https://www.speedrun.com/12_labours_of_hercules_vii_fleecing_the_fleece'},
#  {'id': '3698433d',
#   'names': {'international': '12 Labours of Hercules VIII: How I Met Megara',
#    'japanese': None},
#   'abbreviation': '12_labours_of_hercules_viii_how_i_met_megara',
#   'weblink': 'https://www.speedrun.com/12_labours_of_hercules_viii_how_i_met_megara'},
#  {'id': 'ldejmnn1',
#   'names': {'international': '12 Labours of Hercules X: Greed For Speed',
#    'japanese': None},
#   'abbreviation': '12_labours_of_hercules_x_greed_for_speed',
#   'weblink': 'https://www.speedrun.com/12_labours_of_hercules_x_greed_for_speed'},
#  {'id': 'm1zk35z1',
#   'names': {'international': '12 Labours of Hercules XI: Painted Adventure',
#    'japanese': None},
#   'abbreviation': '12_labours_of_hercules_xi_painted_adventure_',
#   'weblink': 'https://www.speedrun.com/12_labours_of_hercules_xi_painted_adventure_'},
#  {'id': '9d38qp01',
#   'names': {'international': '12 Labours of Hercules XII: Timeless Adventure',
#    'japanese': None},
#   'abbreviation': '12_labours_of_hercules_xii_timeless_adventure',
#   'weblink': 'https://www.speedrun.com/12_labours_of_hercules_xii_timeless_adventure'},
#  {'id': '9do8plk1',
#   'names': {'international': '12 Labours of Hercules XIII: Wonder-ful Builder',
#    'japanese': None},
#   'abbreviation': '12_labours_of_hercules_xiii_wonder_ful_builder',
#   'weblink': 'https://www.speedrun.com/12_labours_of_hercules_xiii_wonder_ful_builder'},
#  {'id': '268wjyk6',
#   'names': {'international': '12 Labours of Hercules XIV: Message in a Bottle',
#    'japanese': None},
#   'abbreviation': '12_labours_of_hercules_xiv_message_in_a_bottle',
#   'weblink': 'https://www.speedrun.com/12_labours_of_hercules_xiv_message_in_a_bottle'},
#  {'id': 'pd0nwyw1',
#   'names': {'international': '12 Labours of Hercules XV: Little Big Adventure',
#    'japanese': None},
#   'abbreviation': '12_Labours_of_Hercules_XV_Little_Big_Adventure',
#   'weblink': 'https://www.speedrun.com/12_Labours_of_Hercules_XV_Little_Big_Adventure'},
#  {'id': '46w2e4n6',
#   'names': {'international': '12 locks and keys', 'japanese': None},
#   'abbreviation': '_12',
#   'weblink': 'https://www.speedrun.com/_12'},
#  {'id': 'y655k5e6',
#   'names': {'international': '12 LOCKS: Plasticine room', 'japanese': None},
#   'abbreviation': '12_rooms_plasticine_room',
#   'weblink': 'https://www.speedrun.com/12_rooms_plasticine_room'},
#  {'id': 'ldej5wn1',
#   'names': {'international': '12 Sai Honto no kimochi', 'japanese': None},
#   'abbreviation': '12_sai_honto_no_kimochi',
#   'weblink': 'https://www.speedrun.com/12_sai_honto_no_kimochi'},
#  {'id': 'y655jy86',
#   'names': {'international': '12 Sai Koi Suru Diary', 'japanese': None},
#   'abbreviation': '12_sai_koi_suru_diary',
#   'weblink': 'https://www.speedrun.com/12_sai_koi_suru_diary'},
#  {'id': 'o6gn5rn1',
#   'names': {'international': '12 Sai Torokeru Puzzle Futari no Harmony',
#    'japanese': None},
#   'abbreviation': '12_sai_torokeru_puzzle_futari_no_harmony',
#   'weblink': 'https://www.speedrun.com/12_sai_torokeru_puzzle_futari_no_harmony'},
#  {'id': 'nd28qlvd',
#   'names': {'international': '123 Slaughter Me Street 2', 'japanese': None},
#   'abbreviation': '123_slaughter_me_street_2',
#   'weblink': 'https://www.speedrun.com/123_slaughter_me_street_2'},
#  {'id': 'w6jg7e76',
#   'names': {'international': '123 Slaughter Me Street Super Retro ',
#    'japanese': None},
#   'abbreviation': '123_Slaughter_Me_Street_Super_Retro_',
#   'weblink': 'https://www.speedrun.com/123_Slaughter_Me_Street_Super_Retro_'},
#  {'id': 'j1n8lqw1',
#   'names': {'international': '13 Days After Survival', 'japanese': None},
#   'abbreviation': '13_days_after_survival',
#   'weblink': 'https://www.speedrun.com/13_days_after_survival'},
#  {'id': 'j1n8rex1',
#   'names': {'international': '13 Days In Hell', 'japanese': None},
#   'abbreviation': '13_days_in_hell',
#   'weblink': 'https://www.speedrun.com/13_days_in_hell'},
#  {'id': 'yd4o0551',
#   'names': {'international': '13 Gates', 'japanese': None},
#   'abbreviation': '13g',
#   'weblink': 'https://www.speedrun.com/13g'},
#  {'id': 'ldej8n51',
#   'names': {'international': '13 More Days In Hell', 'japanese': None},
#   'abbreviation': '13_more_days_in_hell',
#   'weblink': 'https://www.speedrun.com/13_more_days_in_hell'},
#  {'id': 'j1llk3e1',
#   'names': {'international': '13 Sentinels: Aegis Rim', 'japanese': None},
#   'abbreviation': '13_sentinels_aegis_rim',
#   'weblink': 'https://www.speedrun.com/13_sentinels_aegis_rim'},
#  {'id': 'nd2vx510',
#   'names': {'international': '14 Locks', 'japanese': None},
#   'abbreviation': '14locks',
#   'weblink': 'https://www.speedrun.com/14locks'},
#  {'id': 'kdkqm8qd',
#   'names': {'international': '14 Minesweeper Variants', 'japanese': None},
#   'abbreviation': '14_Minesweeper_Variants',
#   'weblink': 'https://www.speedrun.com/14_Minesweeper_Variants'},
#  {'id': '9d3r70dl',
#   'names': {'international': '140', 'japanese': None},
#   'abbreviation': '140',
#   'weblink': 'https://www.speedrun.com/140'},
#  {'id': '3dx03ydy',
#   'names': {'international': '15 Seconds', 'japanese': None},
#   'abbreviation': 'mcm_15s',
#   'weblink': 'https://www.speedrun.com/mcm_15s'},
#  {'id': '76r43lq1',
#   'names': {'international': '150 Level IQ Escape Room', 'japanese': None},
#   'abbreviation': '150_Level_IQ_Escape_Room',
#   'weblink': 'https://www.speedrun.com/150_Level_IQ_Escape_Room'},
#  {'id': '4d794jn1',
#   'names': {'international': '150,000 B.C.', 'japanese': None},
#   'abbreviation': '150000_b.c.',
#   'weblink': 'https://www.speedrun.com/150000_b.c.'},
#  {'id': '46w250q6',
#   'names': {'international': '16 Greens', 'japanese': None},
#   'abbreviation': '16_greens',
#   'weblink': 'https://www.speedrun.com/16_greens'},
#  {'id': 'o1y90ov6',
#   'names': {'international': '16t', 'japanese': None},
#   'abbreviation': '16t',
#   'weblink': 'https://www.speedrun.com/16t'},
#  {'id': '268e9776',
#   'names': {'international': '18 Wheeler: American Pro Trucker',
#    'japanese': None},
#   'abbreviation': '18_wheeler_american_pro_trucker',
#   'weblink': 'https://www.speedrun.com/18_wheeler_american_pro_trucker'},
#  {'id': '76r3x8l6',
#   'names': {'international': '18 Wheels of Steel: Pedal to the Metal',
#    'japanese': None},
#   'abbreviation': '18_wheels_of_steel_pedal_to_the_metal',
#   'weblink': 'https://www.speedrun.com/18_wheels_of_steel_pedal_to_the_metal'},
#  {'id': 'm1mnml4d',
#   'names': {'international': '180', 'japanese': None},
#   'abbreviation': '180',
#   'weblink': 'https://www.speedrun.com/180'},
#  {'id': 'm1mx9536',
#   'names': {'international': '187 Ride or Die', 'japanese': None},
#   'abbreviation': '187_ride_or_die',
#   'weblink': 'https://www.speedrun.com/187_ride_or_die'},
#  {'id': '4d7nw536',
#   'names': {'international': '1916 - Der Unbekannte Krieg', 'japanese': None},
#   'abbreviation': '1916_der_unbekannte_krieg',
#   'weblink': 'https://www.speedrun.com/1916_der_unbekannte_krieg'},
#  {'id': 'o6gl3vod',
#   'names': {'international': '1917 - The Alien Invasion DX', 'japanese': None},
#   'abbreviation': '1917_-_the_alien_invasion_dx',
#   'weblink': 'https://www.speedrun.com/1917_-_the_alien_invasion_dx'},
#  {'id': 'v1pogy76',
#   'names': {'international': '1941: Counter Attack', 'japanese': None},
#   'abbreviation': '1941_counter_attack',
#   'weblink': 'https://www.speedrun.com/1941_counter_attack'},
#  {'id': 'w6j5zx1j',
#   'names': {'international': '1942', 'japanese': None},
#   'abbreviation': '1942',
#   'weblink': 'https://www.speedrun.com/1942'},
#  {'id': '369pkx31',
#   'names': {'international': '1942: First Strike', 'japanese': None},
#   'abbreviation': '1942_first_strike',
#   'weblink': 'https://www.speedrun.com/1942_first_strike'},
#  {'id': '76rxm0v6',
#   'names': {'international': '1942: Joint Strike', 'japanese': None},
#   'abbreviation': '1942_joint_strike',
#   'weblink': 'https://www.speedrun.com/1942_joint_strike'},
#  {'id': '76rxj056',
#   'names': {'international': '1943 Kai: Midway Kaisen', 'japanese': None},
#   'abbreviation': '1943_kai_midway_kaisen',
#   'weblink': 'https://www.speedrun.com/1943_kai_midway_kaisen'},
#  {'id': 'yd49zp1e',
#   'names': {'international': '1943: The Battle of Midway', 'japanese': None},
#   'abbreviation': '1943_the_battle_of_midway',
#   'weblink': 'https://www.speedrun.com/1943_the_battle_of_midway'},
#  {'id': 'v1pxmv46',
#   'names': {'international': '1943: The Battle of Midway Mark II',
#    'japanese': None},
#   'abbreviation': '1943_the_battle_of_midway_mark_ii',
#   'weblink': 'https://www.speedrun.com/1943_the_battle_of_midway_mark_ii'},
#  {'id': '3dx2pwp1',
#   'names': {'international': '1944: The Loop Master', 'japanese': None},
#   'abbreviation': '1944_the_loop_master_',
#   'weblink': 'https://www.speedrun.com/1944_the_loop_master_'},
#  {'id': 'kdkm9yg1',
#   'names': {'international': '1945 Air force', 'japanese': None},
#   'abbreviation': '1945',
#   'weblink': 'https://www.speedrun.com/1945'},
#  {'id': '268wlek6',
#   'names': {'international': '1945k III', 'japanese': None},
#   'abbreviation': '1945k_iii',
#   'weblink': 'https://www.speedrun.com/1945k_iii'},
#  {'id': '76rx0kv6',
#   'names': {'international': '194X: 3D Dogfight', 'japanese': None},
#   'abbreviation': '194x_3d_dogfight',
#   'weblink': 'https://www.speedrun.com/194x_3d_dogfight'},
#  {'id': '9d3rj3ed',
#   'names': {'international': '1954: Alcatraz', 'japanese': None},
#   'abbreviation': '1954_alcatraz',
#   'weblink': 'https://www.speedrun.com/1954_alcatraz'},
#  {'id': '3dxk8qv1',
#   'names': {'international': '1979 Revolution: Black Friday',
#    'japanese': None},
#   'abbreviation': '1979_revolution_black_friday',
#   'weblink': 'https://www.speedrun.com/1979_revolution_black_friday'},
#  {'id': 'w6j2p51j',
#   'names': {'international': '1982 (Steam)', 'japanese': None},
#   'abbreviation': '1982',
#   'weblink': 'https://www.speedrun.com/1982'},
#  {'id': '3dx2v9p1',
#   'names': {'international': '198X', 'japanese': None},
#   'abbreviation': '198x',
#   'weblink': 'https://www.speedrun.com/198x'},
#  {'id': 'o6gnl9x1',
#   'names': {'international': '1999 Bizarre Obby', 'japanese': None},
#   'abbreviation': '1999_bizarre_obby',
#   'weblink': 'https://www.speedrun.com/1999_bizarre_obby'},
#  {'id': 'yd4p3xde',
#   'names': {'international': '1999: Hore, Mita koto ka! Seikimatsu',
#    'japanese': '1999ほれ、みたことか!世紀末'},
#   'abbreviation': '1999_hore_mita_koto_ka_seikimatsu',
#   'weblink': 'https://www.speedrun.com/1999_hore_mita_koto_ka_seikimatsu'},
#  {'id': '9dow9q71',
#   'names': {'international': '19XX: The War Against Destiny',
#    'japanese': None},
#   'abbreviation': '19xx_the_war_against_destiny',
#   'weblink': 'https://www.speedrun.com/19xx_the_war_against_destiny'},
#  {'id': '369pr3g1',
#   'names': {'international': '1BeatHeart', 'japanese': None},
#   'abbreviation': '1beatheart',
#   'weblink': 'https://www.speedrun.com/1beatheart'},
#  {'id': '268eyj76',
#   'names': {'international': '1bitHeart', 'japanese': None},
#   'abbreviation': '1bitheart',
#   'weblink': 'https://www.speedrun.com/1bitheart'},
#  {'id': '9d38m8w1',
#   'names': {'international': '1bitMarcos', 'japanese': None},
#   'abbreviation': '1bitmarcos',
#   'weblink': 'https://www.speedrun.com/1bitmarcos'},
#  {'id': 'm1zy2yz6',
#   'names': {'international': "1f y0u're a gh0st ca11 me here!",
#    'japanese': None},
#   'abbreviation': '1f_y0ure_a_gh0st_ca11_me_here',
#   'weblink': 'https://www.speedrun.com/1f_y0ure_a_gh0st_ca11_me_here'},
#  {'id': '46w3wmn1',
#   'names': {'international': '1nsane', 'japanese': None},
#   'abbreviation': '1nsane',
#   'weblink': 'https://www.speedrun.com/1nsane'},
#  {'id': '369ppxg1',
#   'names': {'international': '1px', 'japanese': None},
#   'abbreviation': '1px',
#   'weblink': 'https://www.speedrun.com/1px'},
#  {'id': '9d38xn01',
#   'names': {'international': '1UP Golden Tee', 'japanese': None},
#   'abbreviation': '1up_golden_tee',
#   'weblink': 'https://www.speedrun.com/1up_golden_tee'},
#  {'id': 'j1n8zq91',
#   'names': {'international': '1v1.LOL', 'japanese': None},
#   'abbreviation': '1v1lol',
#   'weblink': 'https://www.speedrun.com/1v1lol'},
#  {'id': 'w6j7g4e6',
#   'names': {'international': '2', 'japanese': None},
#   'abbreviation': '2',
#   'weblink': 'https://www.speedrun.com/2'},
#  {'id': 'pd0qmgv1',
#   'names': {'international': '2 3 4 players minigames pixel',
#    'japanese': None},
#   'abbreviation': '234pmp',
#   'weblink': 'https://www.speedrun.com/234pmp'},
#  {'id': 'm1mxgep6',
#   'names': {'international': '2 Builders 2 Tools', 'japanese': None},
#   'abbreviation': '2b2t',
#   'weblink': 'https://www.speedrun.com/2b2t'},
#  {'id': 'o6g989d2',
#   'names': {'international': '2 Cars', 'japanese': None},
#   'abbreviation': '2_cars',
#   'weblink': 'https://www.speedrun.com/2_cars'},
#  {'id': '3dxkgzp1',
#   'names': {'international': '2 Fast 4 Gnomz (Demo)', 'japanese': None},
#   'abbreviation': '2_fast_4_gnomz_demo',
#   'weblink': 'https://www.speedrun.com/2_fast_4_gnomz_demo'},
#  {'id': 'ldejjq51',
#   'names': {'international': '2 Fast 4 You', 'japanese': None},
#   'abbreviation': '2_fast_4_you',
#   'weblink': 'https://www.speedrun.com/2_fast_4_you'},
#  {'id': 'o1yjq2k1',
#   'names': {'international': '2 Games in One! - Marble Madness + Klax',
#    'japanese': None},
#   'abbreviation': 'mmklax',
#   'weblink': 'https://www.speedrun.com/mmklax'},
#  {'id': 'v1pkg4d8',
#   'names': {'international': '2 Ninjas 1 Cup', 'japanese': None},
#   'abbreviation': '2_ninjas_1_cup',
#   'weblink': 'https://www.speedrun.com/2_ninjas_1_cup'},
#  {'id': 'v1pxyv76',
#   'names': {'international': '2 Pipes 2', 'japanese': None},
#   'abbreviation': '2p2',
#   'weblink': 'https://www.speedrun.com/2p2'},
#  {'id': 'm1mngzxd',
#   'names': {'international': '2 Player Games - Bar', 'japanese': None},
#   'abbreviation': '2pgb',
#   'weblink': 'https://www.speedrun.com/2pgb'},
#  {'id': '36983q0d',
#   'names': {'international': '2 Player Games - Party Battle',
#    'japanese': None},
#   'abbreviation': '2pgpb',
#   'weblink': 'https://www.speedrun.com/2pgpb'},
#  {'id': 'nd28xr5d',
#   'names': {'international': '2 Player Games - Pastimes', 'japanese': None},
#   'abbreviation': '2pgp',
#   'weblink': 'https://www.speedrun.com/2pgp'},
#  {'id': 'k6qwqrx6',
#   'names': {'international': '2 Player Games - School', 'japanese': None},
#   'abbreviation': '2pgschool',
#   'weblink': 'https://www.speedrun.com/2pgschool'},
#  {'id': 'm1zkwnm1',
#   'names': {'international': '2 Player Games - Sports', 'japanese': None},
#   'abbreviation': '2pgs',
#   'weblink': 'https://www.speedrun.com/2pgs'},
#  {'id': 'y65r5471',
#   'names': {'international': '2 Player Games: the Challenge',
#    'japanese': None},
#   'abbreviation': '2_Player_Games_the_Challenge',
#   'weblink': 'https://www.speedrun.com/2_Player_Games_the_Challenge'},
#  {'id': '9d38pq01',
#   'names': {'international': '20 Bunnies', 'japanese': None},
#   'abbreviation': '20_bunnies',
#   'weblink': 'https://www.speedrun.com/20_bunnies'},
#  {'id': 'y655gv46',
#   'names': {'international': '20 Minutes Till Dawn', 'japanese': None},
#   'abbreviation': '20_minutes_till_dawn',
#   'weblink': 'https://www.speedrun.com/20_minutes_till_dawn'},
#  {'id': '46w2wpq6',
#   'names': {'international': '20.000 Leghe sotto i mari', 'japanese': None},
#   'abbreviation': '20000',
#   'weblink': 'https://www.speedrun.com/20000'},
#  {'id': 'o6g82512',
#   'names': {'international': '200% Mixed Juice!',
#    'japanese': '200％みっくすじゅ～すっ！'},
#   'abbreviation': '200mj',
#   'weblink': 'https://www.speedrun.com/200mj'},
#  {'id': 'kdk74g1m',
#   'names': {'international': '2000:1: A Space Felony', 'japanese': None},
#   'abbreviation': '2000-1-asf',
#   'weblink': 'https://www.speedrun.com/2000-1-asf'},
#  {'id': 'j1lexz6g',
#   'names': {'international': '2003 Gu Huo Lang II / 2003 Crash II Advance',
#    'japanese': None},
#   'abbreviation': 'crashiiadv',
#   'weblink': 'https://www.speedrun.com/crashiiadv'},
#  {'id': '268wzok6',
#   'names': {'international': '2009s Classic Longest Obby!', 'japanese': None},
#   'abbreviation': '2009s_classic_longest_obby',
#   'weblink': 'https://www.speedrun.com/2009s_classic_longest_obby'},
#  {'id': 'j1n87rw1',
#   'names': {'international': '200m Peanut Dash', 'japanese': None},
#   'abbreviation': '200m_peanut_dash',
#   'weblink': 'https://www.speedrun.com/200m_peanut_dash'},
#  {'id': 'nd28eo3d',
#   'names': {'international': '2010: The Graphic Adventure Game',
#    'japanese': None},
#   'abbreviation': '2010_the_graphic_adventure_game',
#   'weblink': 'https://www.speedrun.com/2010_the_graphic_adventure_game'},
#  {'id': '3698ve0d',
#   'names': {'international': '2013:Infected Wars', 'japanese': None},
#   'abbreviation': '2013infected_wars',
#   'weblink': 'https://www.speedrun.com/2013infected_wars'},
#  {'id': 'm1zjpy26',
#   'names': {'international': '2014 Fifa World Cup Brazil', 'japanese': None},
#   'abbreviation': '2014_fifa_world_cup_brazil',
#   'weblink': 'https://www.speedrun.com/2014_fifa_world_cup_brazil'},
#  {'id': 'o1yjqe41',
#   'names': {'international': '2020 Game', 'japanese': None},
#   'abbreviation': '2020_game',
#   'weblink': 'https://www.speedrun.com/2020_game'},
#  {'id': 'k6qw4q06',
#   'names': {'international': '2020 Spring Collab', 'japanese': None},
#   'abbreviation': 'sc2020',
#   'weblink': 'https://www.speedrun.com/sc2020'},
#  {'id': '576rp418',
#   'names': {'international': '2048', 'japanese': None},
#   'abbreviation': '2048',
#   'weblink': 'https://www.speedrun.com/2048'},
#  {'id': '9do57m1p',
#   'names': {'international': '2064: Read Only Memories', 'japanese': None},
#   'abbreviation': '2064_read_only_memories',
#   'weblink': 'https://www.speedrun.com/2064_read_only_memories'},
#  {'id': 'ldepze13',
#   'names': {'international': '20XX', 'japanese': None},
#   'abbreviation': '20xx',
#   'weblink': 'https://www.speedrun.com/20xx'},
#  {'id': 'y654478d',
#   'names': {'international': '222 Hearts', 'japanese': None},
#   'abbreviation': '222hearts',
#   'weblink': 'https://www.speedrun.com/222hearts'},
#  {'id': '4d7n3er6',
#   'names': {'international': '2310 seconds in hell', 'japanese': None},
#   'abbreviation': '2310_seconds_in_hell',
#   'weblink': 'https://www.speedrun.com/2310_seconds_in_hell'},
#  {'id': 'j1lqp0e6',
#   'names': {'international': '234PlayerGames', 'japanese': None},
#   'abbreviation': '234pg',
#   'weblink': 'https://www.speedrun.com/234pg'},
#  {'id': '46w2jk36',
#   'names': {'international': '24 Hour Hack', 'japanese': None},
#   'abbreviation': '24_hour_hack',
#   'weblink': 'https://www.speedrun.com/24_hour_hack'},
#  {'id': 'o1yk0odq',
#   'names': {'international': '24 HOURS', 'japanese': None},
#   'abbreviation': '24_hours',
#   'weblink': 'https://www.speedrun.com/24_hours'},
#  {'id': '268wq2o6',
#   'names': {'international': '24 Killers', 'japanese': None},
#   'abbreviation': '24_killers',
#   'weblink': 'https://www.speedrun.com/24_killers'},
#  {'id': '76r34k46',
#   'names': {'international': '24: The Game', 'japanese': None},
#   'abbreviation': '24_the_game',
#   'weblink': 'https://www.speedrun.com/24_the_game'},
#  {'id': 'pdv5o46w',
# ...
#    'japanese': None},
#   'abbreviation': 'aighina_no_yogen_from_the_legend_of_balubalouk',
#   'weblink': 'https://www.speedrun.com/aighina_no_yogen_from_the_legend_of_balubalouk'},
#  {'id': '4d7nkj36',
#   'names': {'international': 'Aikatsu-stars! First appral', 'japanese': None},
#   'abbreviation': 'aikatsustars_first_appral',
#   'weblink': 'https://www.speedrun.com/aikatsustars_first_appral'},
#  {'id': 'm1mex2pd',
#   'names': {'international': 'aikatsu-stars! my special appeal',
#    'japanese': None},
#   'abbreviation': 'aikatsustars_my_special_appeal',
#   'weblink': 'https://www.speedrun.com/aikatsustars_my_special_appeal'},
#  {'id': 'pdv2pmo6',
#   'names': {'international': 'Aim Climb', 'japanese': None},
#   'abbreviation': 'aim_climb',
#   'weblink': 'https://www.speedrun.com/aim_climb'},
#  {'id': '369pyz21',
#   'names': {'international': 'Aim Course 2 by uLLeticaL', 'japanese': None},
#   'abbreviation': 'aim_course_2_by_ulletical',
#   'weblink': 'https://www.speedrun.com/aim_course_2_by_ulletical'},
#  {'id': 'j1njwl6p',
#   'names': {'international': 'Aim Course by uLLeticaL', 'japanese': None},
#   'abbreviation': 'aim_course_by_ulletical',
#   'weblink': 'https://www.speedrun.com/aim_course_by_ulletical'},
#  {'id': 'yd4o70g1',
#   'names': {'international': 'Aim GAMERZ by uLLeticaL', 'japanese': None},
#   'abbreviation': 'aim_gamerz_by_ulletical',
#   'weblink': 'https://www.speedrun.com/aim_gamerz_by_ulletical'},
#  {'id': '3dx2z351',
#   'names': {'international': 'Aim Time Trial by uLLeticaL', 'japanese': None},
#   'abbreviation': 'aim_time_trial_by_ulletical',
#   'weblink': 'https://www.speedrun.com/aim_time_trial_by_ulletical'},
#  {'id': '9d380001',
#   'names': {'international': 'Aim training', 'japanese': None},
#   'abbreviation': 'aimtraining',
#   'weblink': 'https://www.speedrun.com/aimtraining'},
#  {'id': 'j1nele91',
#   'names': {'international': 'Aimi', 'japanese': None},
#   'abbreviation': 'aimi',
#   'weblink': 'https://www.speedrun.com/aimi'},
#  {'id': 'y655rk06',
#   'names': {'international': 'Ain Dodo', 'japanese': None},
#   'abbreviation': 'ain_dodo',
#   'weblink': 'https://www.speedrun.com/ain_dodo'},
#  {'id': 'lde3zpe6',
#   'names': {'international': 'Aion Free-to-Play', 'japanese': None},
#   'abbreviation': 'aion_free-to-play',
#   'weblink': 'https://www.speedrun.com/aion_free-to-play'},
#  {'id': '4d7q5l67',
#   'names': {'international': 'Aion: Ascension', 'japanese': None},
#   'abbreviation': 'aion',
#   'weblink': 'https://www.speedrun.com/aion'},
#  {'id': 'm1mnw4d2',
#   'names': {'international': 'Air', 'japanese': None},
#   'abbreviation': 'smb1-air',
#   'weblink': 'https://www.speedrun.com/smb1-air'},
#  {'id': 'm1zk0ex1',
#   'names': {'international': 'Air Assault', 'japanese': None},
#   'abbreviation': 'air_assault',
#   'weblink': 'https://www.speedrun.com/air_assault'},
#  {'id': 'w6j70q76',
#   'names': {'international': 'Air Attack', 'japanese': None},
#   'abbreviation': 'air_attack',
#   'weblink': 'https://www.speedrun.com/air_attack'},
#  {'id': 'o1y94jo6',
#   'names': {'international': 'Air Boarder 64', 'japanese': None},
#   'abbreviation': 'air_boarder_64',
#   'weblink': 'https://www.speedrun.com/air_boarder_64'},
#  {'id': 'o1y9gyo6',
#   'names': {'international': "Air Bounce - The Jump 'n' Run Challenge",
#    'japanese': None},
#   'abbreviation': 'air_bounce',
#   'weblink': 'https://www.speedrun.com/air_bounce'},
#  {'id': 'yd4keyk6',
#   'names': {'international': 'Air Buster: Trouble Speciality Raid Unit',
#    'japanese': None},
#   'abbreviation': 'air_buster_trouble_speciality_raid_unit',
#   'weblink': 'https://www.speedrun.com/air_buster_trouble_speciality_raid_unit'},
#  {'id': 'pd0exv1e',
#   'names': {'international': 'Air Combat', 'japanese': None},
#   'abbreviation': 'aircombat',
#   'weblink': 'https://www.speedrun.com/aircombat'},
#  {'id': '46wv0ndr',
#   'names': {'international': 'Air Control', 'japanese': None},
#   'abbreviation': 'aircontrol',
#   'weblink': 'https://www.speedrun.com/aircontrol'},
#  {'id': '9d385791',
#   'names': {'international': 'Air Dribble Challenge', 'japanese': None},
#   'abbreviation': 'adc',
#   'weblink': 'https://www.speedrun.com/adc'},
#  {'id': '3dxk8vv1',
#   'names': {'international': 'Air Dribble Hoops', 'japanese': None},
#   'abbreviation': 'adhoops',
#   'weblink': 'https://www.speedrun.com/adhoops'},
#  {'id': 'pd0qz2l1',
#   'names': {'international': 'Air Dribble Melee', 'japanese': None},
#   'abbreviation': 'airdribblemelee',
#   'weblink': 'https://www.speedrun.com/airdribblemelee'},
#  {'id': 'm1mnp2xd',
#   'names': {'international': 'Air Duel', 'japanese': None},
#   'abbreviation': 'air_duel',
#   'weblink': 'https://www.speedrun.com/air_duel'},
#  {'id': 'm1zww010',
#   'names': {'international': 'Air Fortress', 'japanese': None},
#   'abbreviation': 'air_fortress',
#   'weblink': 'https://www.speedrun.com/air_fortress'},
#  {'id': 'pdv2wpv6',
#   'names': {'international': 'Air Gallet', 'japanese': None},
#   'abbreviation': 'air_gallet',
#   'weblink': 'https://www.speedrun.com/air_gallet'},
#  {'id': 'kdkm89e1',
#   'names': {'international': 'Air Hockey', 'japanese': None},
#   'abbreviation': 'air_hockey',
#   'weblink': 'https://www.speedrun.com/air_hockey'},
#  {'id': '369prm21',
#   'names': {'international': 'Air Nomad', 'japanese': None},
#   'abbreviation': 'air_nomad',
#   'weblink': 'https://www.speedrun.com/air_nomad'},
#  {'id': '4d7n8436',
#   'names': {'international': 'Air Rescue', 'japanese': None},
#   'abbreviation': 'air_rescue',
#   'weblink': 'https://www.speedrun.com/air_rescue'},
#  {'id': '9dowky31',
#   'names': {'international': 'Air Zonk', 'japanese': None},
#   'abbreviation': 'air_zonk',
#   'weblink': 'https://www.speedrun.com/air_zonk'},
#  {'id': 'm1zr8xd0',
#   'names': {'international': 'Air-Sea Battle', 'japanese': None},
#   'abbreviation': 'asb',
#   'weblink': 'https://www.speedrun.com/asb'},
#  {'id': '76rj2e18',
#   'names': {'international': 'AiRace Speed', 'japanese': 'Aiレース：スピード'},
#   'abbreviation': 'airspeed',
#   'weblink': 'https://www.speedrun.com/airspeed'},
#  {'id': 'j1l9jv1g',
#   'names': {'international': 'AiRace Xeno', 'japanese': 'Aiレース：X'},
#   'abbreviation': 'airxeno',
#   'weblink': 'https://www.speedrun.com/airxeno'},
#  {'id': 'o6g30od2',
#   'names': {'international': 'AiRace: Tunnel', 'japanese': None},
#   'abbreviation': 'airtunnel',
#   'weblink': 'https://www.speedrun.com/airtunnel'},
#  {'id': '46w94n1r',
#   'names': {'international': 'AirBlade', 'japanese': None},
#   'abbreviation': 'airblade',
#   'weblink': 'https://www.speedrun.com/airblade'},
#  {'id': 'kdkmyle1',
#   'names': {'international': 'Airborne Troops: Countdown to D-Day',
#    'japanese': None},
#   'abbreviation': 'airborne_troops',
#   'weblink': 'https://www.speedrun.com/airborne_troops'},
#  {'id': '76rx7ve6',
#   'names': {'international': 'Airfix Dogfighter', 'japanese': None},
#   'abbreviation': 'airfix_dogfighter',
#   'weblink': 'https://www.speedrun.com/airfix_dogfighter'},
#  {'id': 'o1y39846',
#   'names': {'international': 'AirForce Delta Storm (GBA)', 'japanese': None},
#   'abbreviation': 'AirForce_Delta_Storm_GBA',
#   'weblink': 'https://www.speedrun.com/AirForce_Delta_Storm_GBA'},
#  {'id': '369wzp0d',
#   'names': {'international': 'Airforce Delta Strike', 'japanese': None},
#   'abbreviation': 'airforce_delta_strike',
#   'weblink': 'https://www.speedrun.com/airforce_delta_strike'},
#  {'id': 'w6jlym4d',
#   'names': {'international': 'AirGrave', 'japanese': None},
#   'abbreviation': 'airgrave',
#   'weblink': 'https://www.speedrun.com/airgrave'},
#  {'id': '46w2omn6',
#   'names': {'international': 'Airhead', 'japanese': None},
#   'abbreviation': 'airhead',
#   'weblink': 'https://www.speedrun.com/airhead'},
#  {'id': 'j1neg5w1',
#   'names': {'international': 'AIRHEART - Tales of broken Wings',
#    'japanese': None},
#   'abbreviation': 'airheart_-_tales_of_broken_wings',
#   'weblink': 'https://www.speedrun.com/airheart_-_tales_of_broken_wings'},
#  {'id': 'lde7q513',
#   'names': {'international': 'Airlock', 'japanese': None},
#   'abbreviation': 'airlock',
#   'weblink': 'https://www.speedrun.com/airlock'},
#  {'id': 'pd0weq01',
#   'names': {'international': 'Airplane Mode', 'japanese': None},
#   'abbreviation': 'airplane_mode',
#   'weblink': 'https://www.speedrun.com/airplane_mode'},
#  {'id': 'y6555o46',
#   'names': {'international': 'Airport CEO', 'japanese': None},
#   'abbreviation': 'airport_ceo',
#   'weblink': 'https://www.speedrun.com/airport_ceo'},
#  {'id': '46w3q891',
#   'names': {'international': 'Airport Madness 3D', 'japanese': None},
#   'abbreviation': 'airport_madness_3d',
#   'weblink': 'https://www.speedrun.com/airport_madness_3d'},
#  {'id': 'o6gnn2n1',
#   'names': {'international': 'Airport Madness 3D: Volume 2', 'japanese': None},
#   'abbreviation': 'airport_madness_3d_volume_2',
#   'weblink': 'https://www.speedrun.com/airport_madness_3d_volume_2'},
#  {'id': 'w6j7jx76',
#   'names': {'international': 'Airs Adventure', 'japanese': None},
#   'abbreviation': 'airs_adventure',
#   'weblink': 'https://www.speedrun.com/airs_adventure'},
#  {'id': '4d7rzz17',
#   'names': {'international': 'Airscape: The Fall of Gravity',
#    'japanese': None},
#   'abbreviation': 'airscape',
#   'weblink': 'https://www.speedrun.com/airscape'},
#  {'id': '46w3k5n1',
#   'names': {'international': 'Airships: Conquer the Skies', 'japanese': None},
#   'abbreviation': 'airships_conquer_the_skies',
#   'weblink': 'https://www.speedrun.com/airships_conquer_the_skies'},
#  {'id': '46w297n6',
#   'names': {'international': 'Airu De Puzzle', 'japanese': None},
#   'abbreviation': 'airu_de_puzzle',
#   'weblink': 'https://www.speedrun.com/airu_de_puzzle'},
#  {'id': 'j1ner2l1',
#   'names': {'international': 'Airwolf (Arcade)', 'japanese': None},
#   'abbreviation': 'airwolf_arcade',
#   'weblink': 'https://www.speedrun.com/airwolf_arcade'},
#  {'id': 'k6q50o6g',
#   'names': {'international': 'Airwolf (Japan)', 'japanese': 'エアーウルフ'},
#   'abbreviation': 'airwolfjp',
#   'weblink': 'https://www.speedrun.com/airwolfjp'},
#  {'id': 'w6jl7w4d',
#   'names': {'international': 'Airwolf (US/EU)', 'japanese': None},
#   'abbreviation': 'airwolf_useu',
#   'weblink': 'https://www.speedrun.com/airwolf_useu'},
#  {'id': '268evyo6',
#   'names': {'international': 'AirXonix', 'japanese': None},
#   'abbreviation': 'airxonix',
#   'weblink': 'https://www.speedrun.com/airxonix'},
#  {'id': '76r32zq6',
#   'names': {'international': 'AK-xolotl', 'japanese': None},
#   'abbreviation': 'akxolotl',
#   'weblink': 'https://www.speedrun.com/akxolotl'},
#  {'id': 'lde3qwe6',
#   'names': {'international': 'Aka Manto | 赤マント', 'japanese': None},
#   'abbreviation': 'aka_manto',
#   'weblink': 'https://www.speedrun.com/aka_manto'},
#  {'id': 'ldej80e1',
#   'names': {'international': 'Akai Katana', 'japanese': None},
#   'abbreviation': 'akai_katana',
#   'weblink': 'https://www.speedrun.com/akai_katana'},
#  {'id': 'k6q4mr9d',
#   'names': {'international': 'Akalabeth: World of Doom', 'japanese': None},
#   'abbreviation': 'akalabeth',
#   'weblink': 'https://www.speedrun.com/akalabeth'},
#  {'id': '9do8r4k1',
#   'names': {'international': 'Akane', 'japanese': None},
#   'abbreviation': 'akane',
#   'weblink': 'https://www.speedrun.com/akane'},
#  {'id': 'm1zxx0d0',
#   'names': {'international': 'Akane the Kunoichi', 'japanese': None},
#   'abbreviation': 'akane_the_kunoichi',
#   'weblink': 'https://www.speedrun.com/akane_the_kunoichi'},
#  {'id': '369p0k21',
#   'names': {'international': 'Akatsuki Blitzkampf', 'japanese': None},
#   'abbreviation': 'akatsuki_blitzkampf',
#   'weblink': 'https://www.speedrun.com/akatsuki_blitzkampf'},
#  {'id': '3dxk3xp1',
#   'names': {'international': 'Akatsuki Blitzkampf Ausf. Achse',
#    'japanese': None},
#   'abbreviation': 'akatsuki_blitzkampf_ausf_achse',
#   'weblink': 'https://www.speedrun.com/akatsuki_blitzkampf_ausf_achse'},
#  {'id': '9d384091',
#   'names': {'international': 'Akazukin Chacha', 'japanese': None},
#   'abbreviation': 'akazukin_chacha',
#   'weblink': 'https://www.speedrun.com/akazukin_chacha'},
#  {'id': 'nd2eoged',
#   'names': {'international': 'Akemi Tan', 'japanese': None},
#   'abbreviation': 'akemi_tan',
#   'weblink': 'https://www.speedrun.com/akemi_tan'},
#  {'id': 'kdkmjwg1',
#   'names': {'international': "AKIBA'S BEAT", 'japanese': None},
#   'abbreviation': 'akibas_beat',
#   'weblink': 'https://www.speedrun.com/akibas_beat'},
#  {'id': 'y6555m76',
#   'names': {'international': "Akiba's Trip: Hellbound and Debriefed",
#    'japanese': None},
#   'abbreviation': 'akibas_trip_hellbound_and_debriefed',
#   'weblink': 'https://www.speedrun.com/akibas_trip_hellbound_and_debriefed'},
#  {'id': 'm1zekm10',
#   'names': {'international': "Akiba's Trip: Undead & Undressed",
#    'japanese': 'アキバズトリップ2'},
#   'abbreviation': 'akibas_trip_undead_and_undressed',
#   'weblink': 'https://www.speedrun.com/akibas_trip_undead_and_undressed'},
#  {'id': 'm1zkg921',
#   'names': {'international': 'Akimbo: Kung-Fu Hero', 'japanese': None},
#   'abbreviation': 'akimbo',
#   'weblink': 'https://www.speedrun.com/akimbo'},
#  {'id': '3dxkv7v1',
#   'names': {'international': 'Akirry Roll', 'japanese': None},
#   'abbreviation': 'akirry_roll',
#   'weblink': 'https://www.speedrun.com/akirry_roll'},
#  {'id': '9do8q7m1',
#   'names': {'international': 'Akkanvader', 'japanese': None},
#   'abbreviation': 'akkanvader',
#   'weblink': 'https://www.speedrun.com/akkanvader'},
#  {'id': '268w32k6',
#   'names': {'international': 'Akogare 2', 'japanese': None},
#   'abbreviation': 'akogare_2',
#   'weblink': 'https://www.speedrun.com/akogare_2'},
#  {'id': '369po721',
#   'names': {'international': 'Akogare Mario World', 'japanese': None},
#   'abbreviation': 'akogaremarioworld',
#   'weblink': 'https://www.speedrun.com/akogaremarioworld'},
#  {'id': '268wrpk6',
#   'names': {'international': 'Akuji the Demon', 'japanese': None},
#   'abbreviation': 'akuji_the_demon',
#   'weblink': 'https://www.speedrun.com/akuji_the_demon'},
#  {'id': 'w6j8021j',
#   'names': {'international': 'Akuji: The Heartless', 'japanese': None},
#   'abbreviation': 'akuji_the_heartless',
#   'weblink': 'https://www.speedrun.com/akuji_the_heartless'},
#  {'id': 'j1n4z96p',
#   'names': {'international': 'Akumajou Special Boku Dracula-kun',
#    'japanese': None},
#   'abbreviation': 'akumajou_special_boku_dracula_kun',
#   'weblink': 'https://www.speedrun.com/akumajou_special_boku_dracula_kun'},
#  {'id': 'nd28ne3d',
#   'names': {'international': 'Akumajyo Dracula Peke', 'japanese': None},
#   'abbreviation': 'peke',
#   'weblink': 'https://www.speedrun.com/peke'},
#  {'id': 'nd28375d',
#   'names': {'international': 'Akumu', 'japanese': None},
#   'abbreviation': 'akumu',
#   'weblink': 'https://www.speedrun.com/akumu'},
#  {'id': 'k6q4o7md',
#   'names': {'international': "Al Unser Jr's Road To The Top",
#    'japanese': None},
#   'abbreviation': 'al_unser_jrs_road_to_the_top',
#   'weblink': 'https://www.speedrun.com/al_unser_jrs_road_to_the_top'},
#  {'id': '4d79q5r1',
#   'names': {'international': 'Al Unser Jr. Turbo Racing', 'japanese': None},
#   'abbreviation': 'al_unser_jr._turbo_racing',
#   'weblink': 'https://www.speedrun.com/al_unser_jr._turbo_racing'},
#  {'id': 'k6qw7lm6',
#   'names': {'international': 'Alabaras Shells', 'japanese': None},
#   'abbreviation': 'alabaras_shells',
#   'weblink': 'https://www.speedrun.com/alabaras_shells'},
#  {'id': '9d3roywd',
#   'names': {'international': 'Aladdin (Hummer Team)', 'japanese': None},
#   'abbreviation': 'aladdin_hummer_team',
#   'weblink': 'https://www.speedrun.com/aladdin_hummer_team'},
#  {'id': '268exq76',
#   'names': {'international': 'Aladdin (Super Game)', 'japanese': None},
#   'abbreviation': 'aladdin_super_game',
#   'weblink': 'https://www.speedrun.com/aladdin_super_game'},
#  {'id': 'y6543g4d',
#   'names': {'international': 'Aladdin 2000 (SNES Bootleg)', 'japanese': None},
#   'abbreviation': 'aladdin_2000_snes_bootleg',
#   'weblink': 'https://www.speedrun.com/aladdin_2000_snes_bootleg'},
#  {'id': 'm1zkw0z1',
#   'names': {'international': 'Aladdin and Magic skull', 'japanese': None},
#   'abbreviation': 'aladdin_and_magic_skull',
#   'weblink': 'https://www.speedrun.com/aladdin_and_magic_skull'},
#  {'id': '76rxnrv6',
#   'names': {'international': 'Aladdin II', 'japanese': None},
#   'abbreviation': 'aladdin_ii',
#   'weblink': 'https://www.speedrun.com/aladdin_ii'}]

# %% [markdown]
# Flatten nested JSON structure to a dataframe:

# %%
game_data = []

for game in first_page_data:
    identifier = game['id']
    name = game['names']['international']
    abbreviation = game['abbreviation']
    weblink = game['weblink']
    game_data.append((identifier, name, abbreviation, weblink))

# %%
def game_data_to_tuple(game):
    identifier = game['id']
    name = game['names']['international']
    abbreviation = game['abbreviation']
    weblink = game['weblink']
    return (identifier, name, abbreviation, weblink)

# %%
game_data_to_tuple(first_page_data[0])
# Out:
# ('o1y32j26',
#  ' Bike Unchained 2',
#  '_bike_unchained_2',
#  'https://www.speedrun.com/_bike_unchained_2')

# %%
def page_data_to_list(page_data):
    return [game_data_to_tuple(game) for game in page_data]

# %%
page_data_to_list(first_page_data)
# Out:
# [('o1y32j26',
#   ' Bike Unchained 2',
#   '_bike_unchained_2',
#   'https://www.speedrun.com/_bike_unchained_2'),
#  ('y65rm041',
#   " BIRDIE WING -Golf Girls' Story-",
#   '_birdie_wing_golf_girls_story',
#   'https://www.speedrun.com/_birdie_wing_golf_girls_story'),
#  ('kdkqz3xd',
#   ' DYNAMITE BOMB!! ',
#   '_DYNAMITE_BOMB_',
#   'https://www.speedrun.com/_DYNAMITE_BOMB_'),
#  ('3698qwld',
#   ' Great Dungeon In The Sky ',
#   '_great_dungeon_in_the_sky_',
#   'https://www.speedrun.com/_great_dungeon_in_the_sky_'),
#  ('ldej48j1',
#   ' House of Da Vinci 2',
#   'the_house_of_da_vinci_2',
#   'https://www.speedrun.com/the_house_of_da_vinci_2'),
#  ('76r3p3q6',
#   ' Interference: Dead Air',
#   '_interference_dead_air',
#   'https://www.speedrun.com/_interference_dead_air'),
#  ('j1lqerz6', ' LIDAR.EXE', 'lidar_exe', 'https://www.speedrun.com/lidar_exe'),
#  ('o6gn9981',
#   ' Metal Tales: Fury of the Guitar Gods',
#   '_metal_tales_fury_of_the_guitar_gods',
#   'https://www.speedrun.com/_metal_tales_fury_of_the_guitar_gods'),
#  ('pdv92zk1',
#   ' Sakura X Clash - Last Millenial Spring -',
#   '_Sakura_X_Clash__Last_Millenial_Spring_',
#   'https://www.speedrun.com/_Sakura_X_Clash__Last_Millenial_Spring_'),
#  ('yd4k9pg6',
#   ' Shutokou Battle Gaiden - Super Technic Challenge',
#   'sbg_stc',
#   'https://www.speedrun.com/sbg_stc'),
#  ('o6gnmp81',
#   ' Sōkyūgurentai/Terra Diver (Arcade)',
#   '_sokyugurentaiterra_diver_arcade',
#   'https://www.speedrun.com/_sokyugurentaiterra_diver_arcade'),
#  ('o1yjg0r1',
#   ' Space Opera: Wyvern Wings',
#   '_space_opera_wyvern_wings',
#   'https://www.speedrun.com/_space_opera_wyvern_wings'),
#  ('268wqg96',
#   ' Stories of Nibel: Tale of Ura',
#   '_stories_of_nibel_tale_of_ura',
#   'https://www.speedrun.com/_stories_of_nibel_tale_of_ura'),
#  ('j1n47nw6',
#   ' Ultimate Board Game Collection 12 Classics from Around The World',
#   'Ultimate_Board_Game_Collection_12_Classics_from_Around_The_World',
#   'https://www.speedrun.com/Ultimate_Board_Game_Collection_12_Classics_from_Around_The_World'),
#  ('76r43ge1',
#   ' Wing of Darkness',
#   '_Wing_of_Darkness',
#   'https://www.speedrun.com/_Wing_of_Darkness'),
#  ('k6qqkx6g', '! Fishy !', 'fishy', 'https://www.speedrun.com/fishy'),
#  ('268w4876',
#   '! Wild Russia !',
#   '1287250',
#   'https://www.speedrun.com/1287250'),
#  ('3dx2pk41',
#   '!findseed the map',
#   'findseed',
#   'https://www.speedrun.com/findseed'),
#  ('j1n83r91',
#   '"Happy" Platformer',
#   'happy_platformer',
#   'https://www.speedrun.com/happy_platformer'),
#  ('y655yj46',
#   '#21: The World',
#   '_the_world',
#   'https://www.speedrun.com/_the_world'),
#  ('ldej49n1', '#compass', 'compass', 'https://www.speedrun.com/compass'),
#  ('3dxk5051', '#FUNTIME', 'funtime', 'https://www.speedrun.com/funtime'),
#  ('j1n8eol1', '#SaveDiscord', 'discord', 'https://www.speedrun.com/discord'),
#  ('46wxo91r', '&meow; (Meow)', 'meow', 'https://www.speedrun.com/meow'),
#  ('pdvp7kdw',
#   "'Allo 'Allo! Cartoon Fun!",
#   'allo_allo_cartoon_fun',
#   'https://www.speedrun.com/allo_allo_cartoon_fun'),
#  ('m1mx54x6', "'n Verlore Verstand", 'nvv', 'https://www.speedrun.com/nvv'),
#  ('m1m8opd2',
#   "'Splosion Man",
#   'splosion_man',
#   'https://www.speedrun.com/splosion_man'),
#  ('j1n8ell1',
#   '(ben) bonk the ball',
#   'ben_bonk_the_ball',
#   'https://www.speedrun.com/ben_bonk_the_ball'),
#  ('268wqw56',
#   "(Deltarune Chapter 3) - Mike's Big Showdown",
#   'mikes_big_showdown',
#   'https://www.speedrun.com/mikes_big_showdown'),
#  ('lde3q7x6',
#   '(Mario) The Music Box -ARC-',
#   'mtmba',
#   'https://www.speedrun.com/mtmba'),
#  ('76r335l6',
#   '(Mario) The Music Box Remastered',
#   'mtmbr',
#   'https://www.speedrun.com/mtmbr'),
#  ('3dxkwry1',
#   '(Scratch) Undieable Appel',
#   'Die_No_Appel_Scratch',
#   'https://www.speedrun.com/Die_No_Appel_Scratch'),
#  ('pd0nwj21', '(square)', 'square', 'https://www.speedrun.com/square'),
#  ('9d3yzw6l',
#   '(The) Final Fantasy Legend',
#   'the_final_fantasy_legend',
#   'https://www.speedrun.com/the_final_fantasy_legend'),
#  ('y6552w06',
#   '*NEW* SCUFFED BHOP SIMULATION 2026 GOTY EDITION',
#   'new_scuffed_bhop_simulation_2026_goty_edition',
#   'https://www.speedrun.com/new_scuffed_bhop_simulation_2026_goty_edition'),
#  ('v1pxx376',
#   '*NEW* SCUFFED EPIC BHOP SIMULATOR 2023 (POG CHAMP)',
#   'new_scuffed_epic_bhop_simulator_2023_pog_champ',
#   'https://www.speedrun.com/new_scuffed_epic_bhop_simulator_2023_pog_champ'),
#  ('268wv896',
#   '- Pixel Sheep -',
#   'pixel_sheep',
#   'https://www.speedrun.com/pixel_sheep'),
#  ('m1zyjpx6', '-256', '256', 'https://www.speedrun.com/256'),
#  ('46w3n071', '-SPROUT-', '-sprout-', 'https://www.speedrun.com/-sprout-'),
#  ('y655rn36', '...Iru!', 'iru', 'https://www.speedrun.com/iru'),
#  ('m1m8r3d2',
#   '..and the mooncats',
#   '.and_the_mooncats',
#   'https://www.speedrun.com/.and_the_mooncats'),
#  ('o6gnx591', '.cat Milk', 'cat_milk', 'https://www.speedrun.com/cat_milk'),
#  ('y65e0e6e', '.flow', 'dotflow', 'https://www.speedrun.com/dotflow'),
#  ('nd2ekj5d',
#   '.hack//G.U. Last Recode',
#   'guhd',
#   'https://www.speedrun.com/guhd'),
#  ('pd0y226e',
#   '.hack//G.U. Volume 1: Rebirth',
#   '.hack_g.u._volume_1_rebirth',
#   'https://www.speedrun.com/.hack_g.u._volume_1_rebirth'),
#  ('kdk7ye1m',
#   '.hack//G.U. Volume 2: Reminisce',
#   '.hack_g.u._volume_2_reminisce',
#   'https://www.speedrun.com/.hack_g.u._volume_2_reminisce'),
#  ('o1ygzr1q',
#   '.hack//G.U. Volume 3: Redemption',
#   '.hack_g.u._volume_3_redemption',
#   'https://www.speedrun.com/.hack_g.u._volume_3_redemption'),
#  ('k6qrzm1g',
#   '.hack//Infection',
#   '.hackinfection',
#   'https://www.speedrun.com/.hackinfection'),
#  ('369k2gdl',
#   '.hack//Mutation',
#   '.hackmutation',
#   'https://www.speedrun.com/.hackmutation'),
#  ('y65p30de',
#   '.hack//Outbreak',
#   '.hackoutbreak',
#   'https://www.speedrun.com/.hackoutbreak'),
#  ('w6j2ye1j',
#   '.hack//Quarantine',
#   '.hackquarantine',
#   'https://www.speedrun.com/.hackquarantine'),
#  ('pdvnrv6w', '.kkrieger', 'kkrieger', 'https://www.speedrun.com/kkrieger'),
#  ('pdv2e8v6', '.S', 's_torcado', 'https://www.speedrun.com/s_torcado'),
#  ('v1pxvxm6',
#   '//N.P.P.D. RUSH//- The milk of Ultraviolet',
#   'nppdrush',
#   'https://www.speedrun.com/nppdrush'),
#  ('nd28v03d', '0 Degrees', '0_degrees', 'https://www.speedrun.com/0_degrees'),
#  ('nd2g9v10',
#   '007 Legends',
#   '007_legends',
#   'https://www.speedrun.com/007_legends'),
#  ('o1y93e46',
#   '007 Racing',
#   '007_racing',
#   'https://www.speedrun.com/007_racing'),
#  ('y65r071e', '007: Agent Under Fire', 'auf', 'https://www.speedrun.com/auf'),
#  ('o1yql4dq',
#   '007: From Russia With Love',
#   '007frwl',
#   'https://www.speedrun.com/007frwl'),
#  ('268j3kdp',
#   '007: NightFire (GBA)',
#   '007nf_gba',
#   'https://www.speedrun.com/007nf_gba'),
#  ('j1llvev1',
#   '007: Nightfire Category Extensions',
#   '007nfca',
#   'https://www.speedrun.com/007nfca'),
#  ('nd272v10',
#   '007: The World is Not Enough',
#   'twine',
#   'https://www.speedrun.com/twine'),
#  ('v1p5rpd8',
#   '007: The World is Not Enough (PS1)',
#   'twineps1',
#   'https://www.speedrun.com/twineps1'),
#  ('o6gl8y8d', '03.04', '03.04', 'https://www.speedrun.com/03.04'),
#  ('y65pv8de', '0error0', '0error0', 'https://www.speedrun.com/0error0'),
#  ('j1n80491', '0h n0', '0h_n0', 'https://www.speedrun.com/0h_n0'),
#  ('46w22k96', '0R8 Demo', '0r8_demo', 'https://www.speedrun.com/0r8_demo'),
#  ('76r3z4q6', '1 Bit Survivor', '1bs', 'https://www.speedrun.com/1bs'),
#  ('yd4knwg6',
#   '1 on 1 Government',
#   '1_on_1_government',
#   'https://www.speedrun.com/1_on_1_government'),
#  ('o1y9np26', '1 Screen Platformer', '1sp', 'https://www.speedrun.com/1sp'),
#  ('pdvv39dw', '1 vs 100', '1_vs_100', 'https://www.speedrun.com/1_vs_100'),
#  ('4d72l367',
#   '1-2-Switch',
#   '1-2-switch',
#   'https://www.speedrun.com/1-2-switch'),
#  ('yd4oqp51',
#   '10 Beautiful Postcards',
#   'tenpostcards',
#   'https://www.speedrun.com/tenpostcards'),
#  ('46w332l1',
#   '10 Gnomes 10: Seashore',
#   '10_gnomes_10_2008',
#   'https://www.speedrun.com/10_gnomes_10_2008'),
#  ('o6glln8d',
#   '10 Gnomes 11: the Remains',
#   '10_gnomes_11',
#   'https://www.speedrun.com/10_gnomes_11'),
#  ('76rxx3v6',
#   '10 Gnomes 12: the Tank',
#   '10_gnomes_12',
#   'https://www.speedrun.com/10_gnomes_12'),
#  ('k6q44wmd',
#   '10 Gnomes 1: the Rooftops',
#   '10_gnomes_1',
#   'https://www.speedrun.com/10_gnomes_1'),
#  ('j1nee8e1',
#   '10 Gnomes 2: Walk in the Park',
#   '10_gnomes_2',
#   'https://www.speedrun.com/10_gnomes_2'),
#  ('lde33jj6',
#   '10 Gnomes 3: Early Spring Garden',
#   '10_gnomes_3',
#   'https://www.speedrun.com/10_gnomes_3'),
#  ('268eew96',
#   '10 Gnomes 4: Foggy Flat',
#   '10_gnomes_4',
#   'https://www.speedrun.com/10_gnomes_4'),
#  ('9doww8k1',
#   '10 Gnomes 5: the Shipyard',
#   '10_gnomes_5',
#   'https://www.speedrun.com/10_gnomes_5'),
#  ('m1mxxn36',
#   '10 Gnomes 6: the Hall',
#   '10_gnomes_6',
#   'https://www.speedrun.com/10_gnomes_6'),
#  ('yd4ookg1',
#   '10 Gnomes 7: the Solitude',
#   '10_gnomes_7',
#   'https://www.speedrun.com/10_gnomes_7'),
#  ('3dx22k51',
#   '10 Gnomes 8: Water Forge',
#   '10_gnomes_8',
#   'https://www.speedrun.com/10_gnomes_8'),
#  ('v1pooxz6',
#   '10 Gnomes 9: Chemistry',
#   '10_gnomes_9_chemistry',
#   'https://www.speedrun.com/10_gnomes_9_chemistry'),
#  ('j1lllqj1',
#   '10 Gnomes in Bologna',
#   '10_gnomes_in_b',
#   'https://www.speedrun.com/10_gnomes_in_b'),
#  ('pdvzz2k6',
#   '10 Gnomes in Dubrovnik',
#   '10_gnomes_in_d',
#   'https://www.speedrun.com/10_gnomes_in_d'),
#  ('pd0wwq31',
#   '10 Gnomes in Liege',
#   '10_gnomes_in_l',
#   'https://www.speedrun.com/10_gnomes_in_l'),
#  ('9d3r9p0d',
#   '10 Gnomes in Malmo',
#   '10_gnomes_in_malmo',
#   'https://www.speedrun.com/10_gnomes_in_malmo'),
#  ('nd2ee8qd',
#   '10 Gnomes in Montaigut-le-Blanc',
#   '10_gnomes_in_m',
#   'https://www.speedrun.com/10_gnomes_in_m'),
#  ('36983w8d',
#   '10 Gnomes in New York',
#   '10_gnomes_in_new_york',
#   'https://www.speedrun.com/10_gnomes_in_new_york'),
#  ('j1ne2ml1',
#   '10 Gnomes in Oristano',
#   '10_gnomes_in_oristano',
#   'https://www.speedrun.com/10_gnomes_in_oristano'),
#  ('k6q4krxd',
#   '10 Gnomes in Paris',
#   '10_gnomes_in_paris',
#   'https://www.speedrun.com/10_gnomes_in_paris'),
#  ('369pp831',
#   '10 Gnomes in Porto Petro',
#   '10_gnomes_in_p',
#   'https://www.speedrun.com/10_gnomes_in_p'),
#  ('4d799nr1',
#   '10 Gnomes in Pothia',
#   '10_gnomes_in_pothia',
#   'https://www.speedrun.com/10_gnomes_in_pothia'),
#  ('9d3rr80d',
#   '10 Gnomes in Trstenik',
#   '10_gnomes_in_t',
#   'https://www.speedrun.com/10_gnomes_in_t'),
#  ('m1zjjk06',
#   '10 Gnomes in Venice',
#   '10_gnomes_in_v',
#   'https://www.speedrun.com/10_gnomes_in_v'),
#  ('4d7n55r6',
#   '10 Minutes 1 Hour 2 Hours',
#   '10_minutes_1_hour_2_hours',
#   'https://www.speedrun.com/10_minutes_1_hour_2_hours'),
#  ('m1zm2m60', '10 Second Ninja', '10sn', 'https://www.speedrun.com/10sn'),
#  ('m1mkwpd2', '10 Second Ninja X', '10snx', 'https://www.speedrun.com/10snx'),
#  ('pdvz9v46',
#   '10 Second Run Returns',
#   '10srr',
#   'https://www.speedrun.com/10srr'),
#  ('j1llv941',
#   '10 Second Shuriken',
#   '10_second_shuriken',
#   'https://www.speedrun.com/10_second_shuriken'),
#  ('46w27y36',
#   '10 second to win',
#   '10_seconds_to_win',
#   'https://www.speedrun.com/10_seconds_to_win'),
#  ('v1pxrm86',
#   '10 Seconds',
#   '10_seconds',
#   'https://www.speedrun.com/10_seconds'),
#  ('3dxkexy1',
#   '10 Seconds or less',
#   '10s_or_less',
#   'https://www.speedrun.com/10s_or_less'),
#  ('ldejx3l1',
#   '10-Pin Bowling',
#   '10pinbowling',
#   'https://www.speedrun.com/10pinbowling'),
#  ('m1m0wx62',
#   '10-Yard Fight',
#   '10-yard_fight',
#   'https://www.speedrun.com/10-yard_fight'),
#  ('o6gkzx51',
#   '100 Hidden Aliens',
#   '100_hidden_aliens',
#   'https://www.speedrun.com/100_hidden_aliens'),
#  ('w6j7wp76',
#   '100 Hidden Birds',
#   '100_hidden_birds',
#   'https://www.speedrun.com/100_hidden_birds'),
#  ('ldejo9n1',
#   '100 hidden cats',
#   '100_hidden_cats',
#   'https://www.speedrun.com/100_hidden_cats'),
#  ('9d3woew1',
#   '100 Hidden Cats 2',
#   '100_hidden_cats_2',
#   'https://www.speedrun.com/100_hidden_cats_2'),
#  ('nd27kne1',
#   '100 Hidden Cupcakes',
#   '100_hidden_cupcakes',
#   'https://www.speedrun.com/100_hidden_cupcakes'),
#  ('j1ln4oe6',
#   '100 Hidden Cups',
#   '100_hidden_cups',
#   'https://www.speedrun.com/100_hidden_cups'),
#  ('y65rmo01',
#   '100 Hidden Fish',
#   '100_hidden_fish',
#   'https://www.speedrun.com/100_hidden_fish'),
#  ('v1px3y76',
#   '100 Hidden Frogs',
#   '100_hidden_frogs',
#   'https://www.speedrun.com/100_hidden_frogs'),
#  ('o1y325r6',
#   '100 Hidden Gnomes',
#   '100_hidden_gnomes',
#   'https://www.speedrun.com/100_hidden_gnomes'),
#  ('76r4wgq1',
#   '100 Hidden Hares',
#   '100_hidden_hares',
#   'https://www.speedrun.com/100_hidden_hares'),
#  ('pdv93041',
#   '100 Hidden Mice',
#   '100_hidden_mice',
#   'https://www.speedrun.com/100_hidden_mice'),
#  ('j1n8gme1',
#   '100 hidden rams',
#   '100_hidden_rams',
#   'https://www.speedrun.com/100_hidden_rams'),
#  ('369wzgld',
#   '100 Hidden Turtles',
#   '100_hidden_turtles',
#   'https://www.speedrun.com/100_hidden_turtles'),
#  ('268w2v96',
#   '100 Meters Race',
#   '100_meters_race',
#   'https://www.speedrun.com/100_meters_race'),
#  ('lde33q56',
#   '100 Rooms of Enemies',
#   '100rooms',
#   'https://www.speedrun.com/100rooms'),
#  ('9dowmo31',
#   '100 Rooms of Kuso',
#   '100_rooms_of_kuso',
#   'https://www.speedrun.com/100_rooms_of_kuso'),
#  ('369plr21', '100 vacas', '100_vacas', 'https://www.speedrun.com/100_vacas'),
#  ('j1n8evl1',
#   '100% Complete',
#   '100_complete',
#   'https://www.speedrun.com/100_complete'),
#  ('j1n2gw1p', '100% Orange Juice!', '100oj', 'https://www.speedrun.com/100oj'),
#  ('o6ge0n12', '1000 Amps', '1000_amps', 'https://www.speedrun.com/1000_amps'),
#  ('m1mk8xd2', '1000 Coins', '1000', 'https://www.speedrun.com/1000'),
#  ('j1llmjj1',
#   '1000 Days to Escape',
#   '1000_days_to_escape',
#   'https://www.speedrun.com/1000_days_to_escape'),
#  ('9do4vm6p', '10000000', '10000000', 'https://www.speedrun.com/10000000'),
#  ('yd4o5w1e',
#   '1001 Spikes',
#   '1001_spikes',
#   'https://www.speedrun.com/1001_spikes'),
#  ('m1zk3721', '100m Race', 'race', 'https://www.speedrun.com/race'),
#  ('o1y989r6',
#   '100th Anniversary of the Crossword Puzzle',
#   '100th_anniversary_of_the_crossword_puzzle',
#   'https://www.speedrun.com/100th_anniversary_of_the_crossword_puzzle'),
#  ('268eko56',
#   '101 Dalmatians: Escape from DeVil Manor',
#   '101_dalmatians_escape_from_devil_manor',
#   'https://www.speedrun.com/101_dalmatians_escape_from_devil_manor'),
#  ('v1pxz2m6',
#   '101-in-1 Explosive Megamix (DS)',
#   '101in1_explosive_megamix_ds',
#   'https://www.speedrun.com/101in1_explosive_megamix_ds'),
#  ('m1mnlokd',
#   '101-in-1 Games',
#   '101in1games',
#   'https://www.speedrun.com/101in1games'),
#  ('76r37p56',
#   '101-in-1 Games 2: Evolution ',
#   '101in12',
#   'https://www.speedrun.com/101in12'),
#  ('268w8r76',
#   '101-in-1 Games Anthology',
#   '101in1ant',
#   'https://www.speedrun.com/101in1ant'),
#  ('pdvlzo1w', '1010!', '1010', 'https://www.speedrun.com/1010'),
#  ('w6jlpned', '1066', '1066', 'https://www.speedrun.com/1066'),
#  ('9dowvo1p',
#   '1080° Avalanche',
#   '1080avalanche',
#   'https://www.speedrun.com/1080avalanche'),
#  ('268ery6p',
#   '1080° Snowboarding',
#   '1080snowboarding',
#   'https://www.speedrun.com/1080snowboarding'),
#  ('o6gn0vx1',
#   '10mg :)',
#   '10mgsmileyface',
#   'https://www.speedrun.com/10mgsmileyface'),
#  ('j1llgoe1', '10S', '10s', 'https://www.speedrun.com/10s'),
#  ('k6q47god',
#   '10th Anniversary Map',
#   'mcm_10am',
#   'https://www.speedrun.com/mcm_10am'),
#  ('pdvze346',
#   '10^2 (Minecraft Map)',
#   '10_squared_series',
#   'https://www.speedrun.com/10_squared_series'),
#  ('4d79m331',
#   '112 Operator',
#   '112_operator',
#   'https://www.speedrun.com/112_operator'),
#  ('3dx2xk41',
#   '1187: Episode One',
#   '1187ep1',
#   'https://www.speedrun.com/1187ep1'),
#  ('3dxwxg1y',
#   '12 is Better Than 6',
#   '12_is_better_than_6',
#   'https://www.speedrun.com/12_is_better_than_6'),
#  ('nd297r60',
#   '12 Labours of Hercules',
#   '12loh1',
#   'https://www.speedrun.com/12loh1'),
#  ('ldevql13',
#   '12 Labours of Hercules II: The Cretan Bull',
#   '12loh2',
#   'https://www.speedrun.com/12loh2'),
#  ('268g4ydp',
#   '12 Labours of Hercules III: Girl Power',
#   '12loh3',
#   'https://www.speedrun.com/12loh3'),
#  ('9dom5o6p',
#   '12 Labours of Hercules IV: Mother Nature',
#   '12loh4',
#   'https://www.speedrun.com/12loh4'),
#  ('pdv27mk6',
#   "12 Labours of Hercules IX: A Hero's Moonwalk",
#   '12_labours_of_hercules_ix_a_heros_moonwalk',
#   'https://www.speedrun.com/12_labours_of_hercules_ix_a_heros_moonwalk'),
#  ('m1m85xd2',
#   '12 Labours of Hercules V: Kids of Hellas',
#   '12loh5',
#   'https://www.speedrun.com/12loh5'),
#  ('yd44pkde',
#   '12 Labours of Hercules VI: Race for Olympus',
#   '12loh6',
#   'https://www.speedrun.com/12loh6'),
#  ('nd283xqd',
#   '12 Labours of Hercules VII: Fleecing The Fleece',
#   '12_labours_of_hercules_vii_fleecing_the_fleece',
#   'https://www.speedrun.com/12_labours_of_hercules_vii_fleecing_the_fleece'),
#  ('3698433d',
#   '12 Labours of Hercules VIII: How I Met Megara',
#   '12_labours_of_hercules_viii_how_i_met_megara',
#   'https://www.speedrun.com/12_labours_of_hercules_viii_how_i_met_megara'),
#  ('ldejmnn1',
#   '12 Labours of Hercules X: Greed For Speed',
#   '12_labours_of_hercules_x_greed_for_speed',
#   'https://www.speedrun.com/12_labours_of_hercules_x_greed_for_speed'),
#  ('m1zk35z1',
#   '12 Labours of Hercules XI: Painted Adventure',
#   '12_labours_of_hercules_xi_painted_adventure_',
#   'https://www.speedrun.com/12_labours_of_hercules_xi_painted_adventure_'),
#  ('9d38qp01',
#   '12 Labours of Hercules XII: Timeless Adventure',
#   '12_labours_of_hercules_xii_timeless_adventure',
#   'https://www.speedrun.com/12_labours_of_hercules_xii_timeless_adventure'),
#  ('9do8plk1',
#   '12 Labours of Hercules XIII: Wonder-ful Builder',
#   '12_labours_of_hercules_xiii_wonder_ful_builder',
#   'https://www.speedrun.com/12_labours_of_hercules_xiii_wonder_ful_builder'),
#  ('268wjyk6',
#   '12 Labours of Hercules XIV: Message in a Bottle',
#   '12_labours_of_hercules_xiv_message_in_a_bottle',
#   'https://www.speedrun.com/12_labours_of_hercules_xiv_message_in_a_bottle'),
#  ('pd0nwyw1',
#   '12 Labours of Hercules XV: Little Big Adventure',
#   '12_Labours_of_Hercules_XV_Little_Big_Adventure',
#   'https://www.speedrun.com/12_Labours_of_Hercules_XV_Little_Big_Adventure'),
#  ('46w2e4n6', '12 locks and keys', '_12', 'https://www.speedrun.com/_12'),
#  ('y655k5e6',
#   '12 LOCKS: Plasticine room',
#   '12_rooms_plasticine_room',
#   'https://www.speedrun.com/12_rooms_plasticine_room'),
#  ('ldej5wn1',
#   '12 Sai Honto no kimochi',
#   '12_sai_honto_no_kimochi',
#   'https://www.speedrun.com/12_sai_honto_no_kimochi'),
#  ('y655jy86',
#   '12 Sai Koi Suru Diary',
#   '12_sai_koi_suru_diary',
#   'https://www.speedrun.com/12_sai_koi_suru_diary'),
#  ('o6gn5rn1',
#   '12 Sai Torokeru Puzzle Futari no Harmony',
#   '12_sai_torokeru_puzzle_futari_no_harmony',
#   'https://www.speedrun.com/12_sai_torokeru_puzzle_futari_no_harmony'),
#  ('nd28qlvd',
#   '123 Slaughter Me Street 2',
#   '123_slaughter_me_street_2',
#   'https://www.speedrun.com/123_slaughter_me_street_2'),
#  ('w6jg7e76',
#   '123 Slaughter Me Street Super Retro ',
#   '123_Slaughter_Me_Street_Super_Retro_',
#   'https://www.speedrun.com/123_Slaughter_Me_Street_Super_Retro_'),
#  ('j1n8lqw1',
#   '13 Days After Survival',
#   '13_days_after_survival',
#   'https://www.speedrun.com/13_days_after_survival'),
#  ('j1n8rex1',
#   '13 Days In Hell',
#   '13_days_in_hell',
#   'https://www.speedrun.com/13_days_in_hell'),
#  ('yd4o0551', '13 Gates', '13g', 'https://www.speedrun.com/13g'),
#  ('ldej8n51',
#   '13 More Days In Hell',
#   '13_more_days_in_hell',
#   'https://www.speedrun.com/13_more_days_in_hell'),
#  ('j1llk3e1',
#   '13 Sentinels: Aegis Rim',
#   '13_sentinels_aegis_rim',
#   'https://www.speedrun.com/13_sentinels_aegis_rim'),
#  ('nd2vx510', '14 Locks', '14locks', 'https://www.speedrun.com/14locks'),
#  ('kdkqm8qd',
#   '14 Minesweeper Variants',
#   '14_Minesweeper_Variants',
#   'https://www.speedrun.com/14_Minesweeper_Variants'),
#  ('9d3r70dl', '140', '140', 'https://www.speedrun.com/140'),
#  ('3dx03ydy', '15 Seconds', 'mcm_15s', 'https://www.speedrun.com/mcm_15s'),
#  ('76r43lq1',
#   '150 Level IQ Escape Room',
#   '150_Level_IQ_Escape_Room',
#   'https://www.speedrun.com/150_Level_IQ_Escape_Room'),
#  ('4d794jn1',
#   '150,000 B.C.',
#   '150000_b.c.',
#   'https://www.speedrun.com/150000_b.c.'),
#  ('46w250q6', '16 Greens', '16_greens', 'https://www.speedrun.com/16_greens'),
#  ('o1y90ov6', '16t', '16t', 'https://www.speedrun.com/16t'),
#  ('268e9776',
#   '18 Wheeler: American Pro Trucker',
#   '18_wheeler_american_pro_trucker',
#   'https://www.speedrun.com/18_wheeler_american_pro_trucker'),
#  ('76r3x8l6',
#   '18 Wheels of Steel: Pedal to the Metal',
#   '18_wheels_of_steel_pedal_to_the_metal',
#   'https://www.speedrun.com/18_wheels_of_steel_pedal_to_the_metal'),
#  ('m1mnml4d', '180', '180', 'https://www.speedrun.com/180'),
#  ('m1mx9536',
#   '187 Ride or Die',
#   '187_ride_or_die',
#   'https://www.speedrun.com/187_ride_or_die'),
#  ('4d7nw536',
#   '1916 - Der Unbekannte Krieg',
#   '1916_der_unbekannte_krieg',
#   'https://www.speedrun.com/1916_der_unbekannte_krieg'),
#  ('o6gl3vod',
#   '1917 - The Alien Invasion DX',
#   '1917_-_the_alien_invasion_dx',
#   'https://www.speedrun.com/1917_-_the_alien_invasion_dx'),
#  ('v1pogy76',
#   '1941: Counter Attack',
#   '1941_counter_attack',
#   'https://www.speedrun.com/1941_counter_attack'),
#  ('w6j5zx1j', '1942', '1942', 'https://www.speedrun.com/1942'),
#  ('369pkx31',
#   '1942: First Strike',
#   '1942_first_strike',
#   'https://www.speedrun.com/1942_first_strike'),
#  ('76rxm0v6',
#   '1942: Joint Strike',
#   '1942_joint_strike',
#   'https://www.speedrun.com/1942_joint_strike'),
#  ('76rxj056',
#   '1943 Kai: Midway Kaisen',
#   '1943_kai_midway_kaisen',
#   'https://www.speedrun.com/1943_kai_midway_kaisen'),
#  ('yd49zp1e',
#   '1943: The Battle of Midway',
#   '1943_the_battle_of_midway',
#   'https://www.speedrun.com/1943_the_battle_of_midway'),
#  ('v1pxmv46',
#   '1943: The Battle of Midway Mark II',
#   '1943_the_battle_of_midway_mark_ii',
#   'https://www.speedrun.com/1943_the_battle_of_midway_mark_ii'),
#  ('3dx2pwp1',
#   '1944: The Loop Master',
#   '1944_the_loop_master_',
#   'https://www.speedrun.com/1944_the_loop_master_'),
#  ('kdkm9yg1', '1945 Air force', '1945', 'https://www.speedrun.com/1945'),
#  ('268wlek6', '1945k III', '1945k_iii', 'https://www.speedrun.com/1945k_iii'),
#  ('76rx0kv6',
#   '194X: 3D Dogfight',
#   '194x_3d_dogfight',
#   'https://www.speedrun.com/194x_3d_dogfight'),
#  ('9d3rj3ed',
#   '1954: Alcatraz',
#   '1954_alcatraz',
#   'https://www.speedrun.com/1954_alcatraz'),
#  ('3dxk8qv1',
#   '1979 Revolution: Black Friday',
#   '1979_revolution_black_friday',
#   'https://www.speedrun.com/1979_revolution_black_friday'),
#  ('w6j2p51j', '1982 (Steam)', '1982', 'https://www.speedrun.com/1982'),
#  ('3dx2v9p1', '198X', '198x', 'https://www.speedrun.com/198x'),
#  ('o6gnl9x1',
#   '1999 Bizarre Obby',
#   '1999_bizarre_obby',
#   'https://www.speedrun.com/1999_bizarre_obby'),
#  ('yd4p3xde',
#   '1999: Hore, Mita koto ka! Seikimatsu',
#   '1999_hore_mita_koto_ka_seikimatsu',
#   'https://www.speedrun.com/1999_hore_mita_koto_ka_seikimatsu'),
#  ('9dow9q71',
#   '19XX: The War Against Destiny',
#   '19xx_the_war_against_destiny',
#   'https://www.speedrun.com/19xx_the_war_against_destiny'),
#  ('369pr3g1',
#   '1BeatHeart',
#   '1beatheart',
#   'https://www.speedrun.com/1beatheart'),
#  ('268eyj76', '1bitHeart', '1bitheart', 'https://www.speedrun.com/1bitheart'),
#  ('9d38m8w1',
#   '1bitMarcos',
#   '1bitmarcos',
#   'https://www.speedrun.com/1bitmarcos'),
#  ('m1zy2yz6',
#   "1f y0u're a gh0st ca11 me here!",
#   '1f_y0ure_a_gh0st_ca11_me_here',
#   'https://www.speedrun.com/1f_y0ure_a_gh0st_ca11_me_here'),
#  ('46w3wmn1', '1nsane', '1nsane', 'https://www.speedrun.com/1nsane'),
#  ('369ppxg1', '1px', '1px', 'https://www.speedrun.com/1px'),
#  ('9d38xn01',
#   '1UP Golden Tee',
#   '1up_golden_tee',
#   'https://www.speedrun.com/1up_golden_tee'),
#  ('j1n8zq91', '1v1.LOL', '1v1lol', 'https://www.speedrun.com/1v1lol'),
#  ('w6j7g4e6', '2', '2', 'https://www.speedrun.com/2'),
#  ('pd0qmgv1',
#   '2 3 4 players minigames pixel',
#   '234pmp',
#   'https://www.speedrun.com/234pmp'),
#  ('m1mxgep6', '2 Builders 2 Tools', '2b2t', 'https://www.speedrun.com/2b2t'),
#  ('o6g989d2', '2 Cars', '2_cars', 'https://www.speedrun.com/2_cars'),
#  ('3dxkgzp1',
#   '2 Fast 4 Gnomz (Demo)',
#   '2_fast_4_gnomz_demo',
#   'https://www.speedrun.com/2_fast_4_gnomz_demo'),
#  ('ldejjq51',
#   '2 Fast 4 You',
#   '2_fast_4_you',
#   'https://www.speedrun.com/2_fast_4_you'),
#  ('o1yjq2k1',
#   '2 Games in One! - Marble Madness + Klax',
#   'mmklax',
#   'https://www.speedrun.com/mmklax'),
#  ('v1pkg4d8',
#   '2 Ninjas 1 Cup',
#   '2_ninjas_1_cup',
#   'https://www.speedrun.com/2_ninjas_1_cup'),
#  ('v1pxyv76', '2 Pipes 2', '2p2', 'https://www.speedrun.com/2p2'),
#  ('m1mngzxd', '2 Player Games - Bar', '2pgb', 'https://www.speedrun.com/2pgb'),
#  ('36983q0d',
#   '2 Player Games - Party Battle',
#   '2pgpb',
#   'https://www.speedrun.com/2pgpb'),
#  ('nd28xr5d',
#   '2 Player Games - Pastimes',
#   '2pgp',
#   'https://www.speedrun.com/2pgp'),
#  ('k6qwqrx6',
#   '2 Player Games - School',
#   '2pgschool',
#   'https://www.speedrun.com/2pgschool'),
#  ('m1zkwnm1',
#   '2 Player Games - Sports',
#   '2pgs',
#   'https://www.speedrun.com/2pgs'),
#  ('y65r5471',
#   '2 Player Games: the Challenge',
#   '2_Player_Games_the_Challenge',
#   'https://www.speedrun.com/2_Player_Games_the_Challenge'),
#  ('9d38pq01',
#   '20 Bunnies',
#   '20_bunnies',
#   'https://www.speedrun.com/20_bunnies'),
#  ('y655gv46',
#   '20 Minutes Till Dawn',
#   '20_minutes_till_dawn',
#   'https://www.speedrun.com/20_minutes_till_dawn'),
#  ('46w2wpq6',
#   '20.000 Leghe sotto i mari',
#   '20000',
#   'https://www.speedrun.com/20000'),
#  ('o6g82512', '200% Mixed Juice!', '200mj', 'https://www.speedrun.com/200mj'),
#  ('kdk74g1m',
#   '2000:1: A Space Felony',
#   '2000-1-asf',
#   'https://www.speedrun.com/2000-1-asf'),
#  ('j1lexz6g',
#   '2003 Gu Huo Lang II / 2003 Crash II Advance',
#   'crashiiadv',
#   'https://www.speedrun.com/crashiiadv'),
#  ('268wzok6',
#   '2009s Classic Longest Obby!',
#   '2009s_classic_longest_obby',
#   'https://www.speedrun.com/2009s_classic_longest_obby'),
#  ('j1n87rw1',
#   '200m Peanut Dash',
#   '200m_peanut_dash',
#   'https://www.speedrun.com/200m_peanut_dash'),
#  ('nd28eo3d',
#   '2010: The Graphic Adventure Game',
#   '2010_the_graphic_adventure_game',
#   'https://www.speedrun.com/2010_the_graphic_adventure_game'),
#  ('3698ve0d',
#   '2013:Infected Wars',
#   '2013infected_wars',
#   'https://www.speedrun.com/2013infected_wars'),
#  ('m1zjpy26',
#   '2014 Fifa World Cup Brazil',
#   '2014_fifa_world_cup_brazil',
#   'https://www.speedrun.com/2014_fifa_world_cup_brazil'),
#  ('o1yjqe41', '2020 Game', '2020_game', 'https://www.speedrun.com/2020_game'),
#  ('k6qw4q06',
#   '2020 Spring Collab',
#   'sc2020',
#   'https://www.speedrun.com/sc2020'),
#  ('576rp418', '2048', '2048', 'https://www.speedrun.com/2048'),
#  ('9do57m1p',
#   '2064: Read Only Memories',
#   '2064_read_only_memories',
#   'https://www.speedrun.com/2064_read_only_memories'),
#  ('ldepze13', '20XX', '20xx', 'https://www.speedrun.com/20xx'),
#  ('y654478d', '222 Hearts', '222hearts', 'https://www.speedrun.com/222hearts'),
#  ('4d7n3er6',
#   '2310 seconds in hell',
#   '2310_seconds_in_hell',
#   'https://www.speedrun.com/2310_seconds_in_hell'),
#  ('j1lqp0e6', '234PlayerGames', '234pg', 'https://www.speedrun.com/234pg'),
#  ('46w2jk36',
#   '24 Hour Hack',
#   '24_hour_hack',
#   'https://www.speedrun.com/24_hour_hack'),
#  ('o1yk0odq', '24 HOURS', '24_hours', 'https://www.speedrun.com/24_hours'),
#  ('268wq2o6',
#   '24 Killers',
#   '24_killers',
#   'https://www.speedrun.com/24_killers'),
#  ('76r34k46',
#   '24: The Game',
#   '24_the_game',
#   'https://www.speedrun.com/24_the_game'),
#  ('pdv5o46w',
#   '25 To Life',
#   '25_to_life',
#   'https://www.speedrun.com/25_to_life'),
#  ('m1mnyqxd', '255', '255', 'https://www.speedrun.com/255'),
#  ('kdkmv0e1', '25BIT', '25bit', 'https://www.speedrun.com/25bit'),
#  ('k6qwwj96',
#   '2D Platformer',
#   '2d_platformer',
#   'https://www.speedrun.com/2d_platformer'),
#  ('3dx27j41', '2D Zelda Games', '2dzelda', 'https://www.speedrun.com/2dzelda'),
#  ('m1zkqkx1', '2D-RUSH', '2drush', 'https://www.speedrun.com/2drush'),
#  ('pdvlg41w', '2Dark', '2dark', 'https://www.speedrun.com/2dark'),
#  ('o1y9g926', '2DOOM', '2doom', 'https://www.speedrun.com/2doom'),
#  ('pdvzymr6', '2weistein', '2weistein', 'https://www.speedrun.com/2weistein'),
#  ('v1ploj76', '2Xtreme', '2Xtreme', 'https://www.speedrun.com/2Xtreme'),
#  ('46w8736r',
#   '3 Foot Ninja',
#   '3_foot_ninja',
#   'https://www.speedrun.com/3_foot_ninja'),
#  ('pd0wpl31',
#   '3 in 1 Supergun',
#   '3_in_1_supergun',
#   'https://www.speedrun.com/3_in_1_supergun'),
#  ('yd4oxyp1',
#   '3 Islands of Shells',
#   '3_islands_of_shells',
#   'https://www.speedrun.com/3_islands_of_shells'),
#  ('369w20dl',
#   '3 Ninjas Kick Back',
#   '3_ninjas_kick_back',
#   'https://www.speedrun.com/3_ninjas_kick_back'),
#  ('o1y94ok6',
#   '3 on 3 NHL Arcade',
#   '3_on_3_nhl_arcade',
#   'https://www.speedrun.com/3_on_3_nhl_arcade'),
#  ('76r344v6', '3 Pandas', '3pandas', 'https://www.speedrun.com/3pandas'),
#  ('pd0qnn31',
#   '3 Pandas 2. Night',
#   '3pandasnight',
#   'https://www.speedrun.com/3pandasnight'),
#  ('3698ww3d',
#   '3 Pandas in Brazil',
#   '3pandasbrazil',
#   'https://www.speedrun.com/3pandasbrazil'),
#  ('m1zkrn21',
#   '3 Pandas In Fantasy',
#   '3pandasfantasy',
#   'https://www.speedrun.com/3pandasfantasy'),
#  ('9do8qw31',
#   '3 Pandas In Japan',
#   '3pandasjapan',
#   'https://www.speedrun.com/3pandasjapan'),
#  ('o1yj0kr1', '3 Second Maze', '3sm', 'https://www.speedrun.com/3sm'),
#  ('k6q47xmd',
#   '3-2-1, Rattle Battle!',
#   '3-2-1_rattle_battle',
#   'https://www.speedrun.com/3-2-1_rattle_battle'),
#  ('76rxwje6',
#   '3-D Dinosaur Adventure',
#   '3-d_dinosaur_adventure',
#   'https://www.speedrun.com/3-d_dinosaur_adventure'),
#  ('pd0qo501', '3-D Tic-Tac-Toe', '3dttt', 'https://www.speedrun.com/3dttt'),
#  ('3dx2wyv1',
#   '3-D Ultra Radio Control Racers',
#   '3_d_ultra_radio_control_racers',
#   'https://www.speedrun.com/3_d_ultra_radio_control_racers'),
#  ('m1z44060',
#   '3-D WorldRunner',
#   '3-d_worldrunner',
#   'https://www.speedrun.com/3-d_worldrunner'),
#  ('pdv2x8r6',
#   '300 Miles to Pigsland',
#   '300_miles_to_pigsland',
#   'https://www.speedrun.com/300_miles_to_pigsland'),
#  ('4d7n93n6', '300: March to Glory ', '300', 'https://www.speedrun.com/300'),
#  ('nd28lmvd',
#   '300: Seize Your Glory',
#   '300_seize_your_glory',
#   'https://www.speedrun.com/300_seize_your_glory'),
#  ('m1z8yz10',
#   '30th Anniversary of PAC-MAN',
#   'googlepacman',
#   'https://www.speedrun.com/googlepacman'),
#  ('o6gklpx1', '30XX', '30XX', 'https://www.speedrun.com/30XX'),
#  ('3690z06l', '35MM', '35mm', 'https://www.speedrun.com/35mm'),
#  ('j1neejw1',
#   '36 Fragments of Midnight',
#   '36_fragments_of_midnight',
#   'https://www.speedrun.com/36_fragments_of_midnight'),
#  ('yd4kqjg6',
#   '36 Great Holes Starring Fred Couples',
#   '36_great_holes_starring_fred_couples',
#   'https://www.speedrun.com/36_great_holes_starring_fred_couples'),
#  ('lde3p4x6',
#   '39 Days to Mars',
#   '39_days_to_mars',
#   'https://www.speedrun.com/39_days_to_mars'),
#  ('4d79z731',
#   '3AM At The Krusty Krab',
#   '3am_at_the_krusty_krab',
#   'https://www.speedrun.com/3am_at_the_krusty_krab'),
#  ('lde3knx6',
#   '3D Body Adventure',
#   '3dbody',
#   'https://www.speedrun.com/3dbody'),
#  ('369nw0dl',
#   '3D Classics: Excitebike',
#   'arikaeb',
#   'https://www.speedrun.com/arikaeb'),
#  ('76r3z468',
#   '3D Dot Game Heroes',
#   '3d_dot_game_heroes',
#   'https://www.speedrun.com/3d_dot_game_heroes'),
#  ('m1mn2j3d',
#   '3D Fantasy Zone II W',
#   '3d_fantasy_zone_ii_w',
#   'https://www.speedrun.com/3d_fantasy_zone_ii_w'),
#  ('268emp76', '3D Frog Frenzy', '3dfrog', 'https://www.speedrun.com/3dfrog'),
#  ('yd4o3rx1',
#   '3D Frog Man',
#   '3d_frog_man',
#   'https://www.speedrun.com/3d_frog_man'),
#  ('j1lqmmj6',
#   '3D Land Rebirth',
#   '3d_land_rebirth',
#   'https://www.speedrun.com/3d_land_rebirth'),
#  ('ldejrej1', '3D Mario Racing', '3dmr', 'https://www.speedrun.com/3dmr'),
#  ('3698weld',
#   '3D Maze Escape',
#   'mazeescaape',
#   'https://www.speedrun.com/mazeescaape'),
#  ('o1y9yer6',
#   '3D Maze Man: Adventures in Winter Wonderland',
#   '3d_maze_man_adventures_in_winter_wonderland',
#   'https://www.speedrun.com/3d_maze_man_adventures_in_winter_wonderland'),
#  ('76rx2w56',
#   '3D Maze Man: Amazing Adventures',
#   '3d_maze_man_amazing_adventures',
#   'https://www.speedrun.com/3d_maze_man_amazing_adventures'),
#  ('j1new091',
#   '3D Minesweeper in Minecraft!',
#   '3d_minesweeper_in_minecraft',
#   'https://www.speedrun.com/3d_minesweeper_in_minecraft'),
#  ('m1mryx62',
#   '3D Monster Maze',
#   '3d_monster_maze',
#   'https://www.speedrun.com/3d_monster_maze'),
#  ('yd4oyxp1',
#   '3D Ms. Maze: Tropical Adventures',
#   '3d_ms_maze_tropical_adventures',
#   'https://www.speedrun.com/3d_ms_maze_tropical_adventures'),
#  ('3dx2mzg1',
#   '3D Munch Man II',
#   '3d_munch_man_ii',
#   'https://www.speedrun.com/3d_munch_man_ii'),
#  ('k6qp4p9d',
#   '3D Parkour (Scratch)',
#   '3D_Parkour_Scratch',
#   'https://www.speedrun.com/3D_Parkour_Scratch'),
#  ('pd0mz26e',
#   '3D Pinball for Windows: Space Cadet',
#   '3pwsc',
#   'https://www.speedrun.com/3pwsc'),
#  ('k6qw8zm6',
#   '3D platformer',
#   '3dplatformer',
#   'https://www.speedrun.com/3dplatformer'),
#  ('m1zjnz36',
#   '3D Retro Dungeon Puzzle Challenge',
#   '3drdpc',
#   'https://www.speedrun.com/3drdpc'),
#  ('9do8p7k1',
#   '3D Rotation Platformer',
#   'spidertest_rotate2',
#   'https://www.speedrun.com/spidertest_rotate2'),
#  ('268e0l56',
#   '3D Stress Ball',
#   '3d_stress_ball',
#   'https://www.speedrun.com/3d_stress_ball'),
#  ('y659e31e', '3D Tetris', '3d_tetris', 'https://www.speedrun.com/3d_tetris'),
#  ('j1lwze6g',
#   '3D Ultra Minigolf',
#   '3d_ultra_minigolf',
#   'https://www.speedrun.com/3d_ultra_minigolf'),
#  ('3dxv3g6y',
#   '3D Ultra Minigolf Adventures',
#   '3duma',
#   'https://www.speedrun.com/3duma'),
#  ('k6q40o9d',
#   '3D Ultra NASCAR Pinball',
#   '3d_ultra_nascar_pinball',
#   'https://www.speedrun.com/3d_ultra_nascar_pinball'),
#  ('9dowjjk1',
#   '3D Ultra Pinball',
#   '3d_ultra_pinball',
#   'https://www.speedrun.com/3d_ultra_pinball'),
#  ('pd0w54v1',
#   '3D Ultra Pinball: Creep Night',
#   '3d_ultra_pinball_creep_night',
#   'https://www.speedrun.com/3d_ultra_pinball_creep_night'),
#  ('o6glwmnd',
#   '3D Ultra Pinball: The Lost Continent',
#   '3d_ultra_pinball_the_lost_continent',
#   'https://www.speedrun.com/3d_ultra_pinball_the_lost_continent'),
#  ('m1zj3lz6',
#   '3D Ultra Pinball: Thrillride',
#   '3d_ultra_pinball_thrillride',
#   'https://www.speedrun.com/3d_ultra_pinball_thrillride'),
#  ('76r3wzl6',
#   '3D Viper Rush',
#   '3d_viper_rush',
#   'https://www.speedrun.com/3d_viper_rush'),
#  ('o6glv55d', '3D Zelda Games', '3dzelda', 'https://www.speedrun.com/3dzelda'),
#  ('w6jreedj',
#   '3D Zelda Relay',
#   '3d_zelda_relay',
#   'https://www.speedrun.com/3d_zelda_relay'),
#  ('76r2zqd8',
#   '3D Zombie Hell 2',
#   '3d_zombie_hell_2',
#   'https://www.speedrun.com/3d_zombie_hell_2'),
#  ('j1l0p41g', '3DCube', '3dcube', 'https://www.speedrun.com/3dcube'),
#  ('46w2vol6', '3DTris', '3dtris', 'https://www.speedrun.com/3dtris'),
#  ('4d79wzn1', '3rd eye', '3rd_eye', 'https://www.speedrun.com/3rd_eye'),
#  ('j1n89me1',
#   '3rd World Farmer',
#   '3rd_world_farmer',
#   'https://www.speedrun.com/3rd_world_farmer'),
#  ('3dxgwy6y', '3Xtreme', '3xtreme', 'https://www.speedrun.com/3xtreme'),
#  ('k6qwl4z6', '4 Dot Frenzy!', '4df', 'https://www.speedrun.com/4df'),
#  ('9d3wrwg1',
#   '4 Elements',
#   '4_Elements',
#   'https://www.speedrun.com/4_Elements'),
#  ('kdkqzeed',
#   '4 Elements II',
#   '4_Elements_II',
#   'https://www.speedrun.com/4_Elements_II'),
#  ('ldejzl51',
#   '4 Months of You',
#   '4_months_of_you',
#   'https://www.speedrun.com/4_months_of_you'),
#  ('yd4owrp1',
#   '4 PAK All Action',
#   '4_pak_all_action',
#   'https://www.speedrun.com/4_pak_all_action'),
#  ('yd4oxxg1',
#   '4 YUMPs For Yoshi',
#   '4_yumps_for_yoshi',
#   'https://www.speedrun.com/4_yumps_for_yoshi'),
#  ('3698032d',
#   '4-D Warriors',
#   '4_d_warriors',
#   'https://www.speedrun.com/4_d_warriors'),
#  ('9do2g31p',
#   '4-in-1 Fun Pak',
#   '4-in-1_fun_pak',
#   'https://www.speedrun.com/4-in-1_fun_pak'),
#  ('pd0g836e',
#   '4-in-1 Funpak: Volume II',
#   '4-in-1_funpak_volume_ii',
#   'https://www.speedrun.com/4-in-1_funpak_volume_ii'),
#  ('46wo3q1r', '40 Winks', '40winks', 'https://www.speedrun.com/40winks'),
#  ('o1y95kr6', '400 Years', '400_years', 'https://www.speedrun.com/400_years'),
#  ('ldekmld3', '404Sight', '404sight', 'https://www.speedrun.com/404sight'),
#  ('o1y4r41q', '40xEscape', '40xescape', 'https://www.speedrun.com/40xescape'),
#  ('76r39m56',
#   '44 Minutes in Nightmare',
#   '44_minutes_in_nightmare',
#   'https://www.speedrun.com/44_minutes_in_nightmare'),
#  ('w6jl0m7d',
#   '44th Anniversary of the Birth of Hip Hop',
#   '44th_anniversary_of_the_birth_of_hip_hop',
#   'https://www.speedrun.com/44th_anniversary_of_the_birth_of_hip_hop'),
#  ('9d3v7y6l',
#   '46 Okunen Monogatari: The Shinkaron',
#   '46_omts_evo',
#   'https://www.speedrun.com/46_omts_evo'),
#  ('m1zk0qm1', '4Fun Guys', '4fun_guys', 'https://www.speedrun.com/4fun_guys'),
#  ('m1mx7wj6', '4PM', '4pm', 'https://www.speedrun.com/4pm'),
#  ('j1lv94dg',
#   '4th Of July 64',
#   '4th_of_july_64',
#   'https://www.speedrun.com/4th_of_july_64'),
#  ('9d3rxrwd', '4x4 EVO 2', '4x4_evo_2', 'https://www.speedrun.com/4x4_evo_2'),
#  ('pdvzjpo6', '4XM', '4xm', 'https://www.speedrun.com/4xm'),
#  ('j1nvmx6p',
#   '5 Days a Stranger',
#   'five_days_a_stranger',
#   'https://www.speedrun.com/five_days_a_stranger'),
#  ('4d7w2l67',
#   '5 in 1 Funpak',
#   '5_in_1_funpak',
#   'https://www.speedrun.com/5_in_1_funpak'),
#  ('v1po7k86', '5.0', '5.0', 'https://www.speedrun.com/5.0'),
#  ('k6qjmxdg',
#   '50 Cent: Blood on the Sand',
#   'bots',
#   'https://www.speedrun.com/bots'),
#  ('3dxmm56y',
#   '50 Cent: Bulletproof',
#   '50_cent_bulletproof',
#   'https://www.speedrun.com/50_cent_bulletproof'),
#  ('yd4o7851',
#   '50 Cent: Bulletproof - G Unit Edition',
#   'bpg',
#   'https://www.speedrun.com/bpg'),
#  ('m1zyk206',
#   '50 Level Deathrun [Easy]',
#   '50_Level_Deathrun_Easy',
#   'https://www.speedrun.com/50_Level_Deathrun_Easy'),
#  ('3698jp0d',
#   '50 Levels Pixel Deathrun',
#   '50_levels_pixel_deathrun',
#   'https://www.speedrun.com/50_levels_pixel_deathrun'),
#  ('w6jl442d', '50 Years', '50_years', 'https://www.speedrun.com/50_years'),
#  ('9do8o9m1',
#   '5D Chess with Multiverse Time Travel',
#   '5d_chess',
#   'https://www.speedrun.com/5d_chess'),
#  ('o6gllpnd', '5xMan', '5xman', 'https://www.speedrun.com/5xman'),
#  ('kdklnx6m',
#   '6 Days a Sacrifice',
#   '6_days_a_sacrifice',
#   'https://www.speedrun.com/6_days_a_sacrifice'),
#  ('268934y1',
#   '6-Mon Adventure',
#   '6Mon_Adventure',
#   'https://www.speedrun.com/6Mon_Adventure'),
#  ('lde3o8x6', '6.0', '6.0', 'https://www.speedrun.com/6.0'),
#  ('j1nem291',
#   '60 Parsecs!',
#   '60_parsecs',
#   'https://www.speedrun.com/60_parsecs'),
#  ('o6g4mo62',
#   '60 Seconds Burger Run',
#   '60sbr',
#   'https://www.speedrun.com/60sbr'),
#  ('yd4kojx6',
#   '60 Seconds Santa Run',
#   '60ssr',
#   'https://www.speedrun.com/60ssr'),
#  ('nd2vpq10',
#   '60 Seconds to Save the Queen',
#   '60_seconds_to_save_the_queen',
#   'https://www.speedrun.com/60_seconds_to_save_the_queen'),
#  ('j1ljjjdg',
#   '60 Seconds!',
#   '60_seconds',
#   'https://www.speedrun.com/60_seconds'),
#  ('4d7n99r6',
#   '60 Seconds! Category Extensions',
#   '60_seconds_ce',
#   'https://www.speedrun.com/60_seconds_ce'),
#  ('nd2e9z3d',
#   '60 Seconds! Reatomized',
#   '60_seconds_reatomized',
#   'https://www.speedrun.com/60_seconds_reatomized'),
#  ('kdkz7k2d',
#   "60th Anniversary of Stanislaw Lem's First Publication",
#   '60th_anniversary_of_stanislaw_lems_first_publication',
#   'https://www.speedrun.com/60th_anniversary_of_stanislaw_lems_first_publication'),
#  ('4d79lz17',
#   '6180 the moon',
#   '6180_the_moon',
#   'https://www.speedrun.com/6180_the_moon'),
#  ('w6j7vxe6',
#   '64dehakken!!tamagotchi minnade tamagotchi world',
#   '64dehakkentamagotchi_minnade_tamagotchi_world',
#   'https://www.speedrun.com/64dehakkentamagotchi_minnade_tamagotchi_world'),
#  ('46w39391',
#   '64th Street: A Detective Story',
#   '64th_street_a_detective_story',
#   'https://www.speedrun.com/64th_street_a_detective_story'),
#  ('4d79m9n1',
#   '6AM at The Chum Bucket',
#   '6am_at_the_chum_bucket',
#   'https://www.speedrun.com/6am_at_the_chum_bucket'),
#  ('v1poyn46', '6PackMan', '6packman', 'https://www.speedrun.com/6packman'),
#  ('nd2e29qd', '7', '7', 'https://www.speedrun.com/7'),
#  ('pd0gkl6e',
#   '7 Days a Skeptic',
#   'seven_days_a_skeptic',
#   'https://www.speedrun.com/seven_days_a_skeptic'),
#  ('j1lq7je6', '7 Days to Die', '7dtd', 'https://www.speedrun.com/7dtd'),
#  ('j1n8n0y1',
#   '7 Wonders II',
#   '7_wonders_ii',
#   'https://www.speedrun.com/7_wonders_ii'),
#  ('w6jlp34d',
#   '7 Wonders of the Ancient World',
#   '7_wonders_of_the_ancient_world',
#   'https://www.speedrun.com/7_wonders_of_the_ancient_world'),
#  ('3dxkywy1',
#   '7 Wonders: Treasures of Seven',
#   '7_wonders_treasures_of_seven',
#   'https://www.speedrun.com/7_wonders_treasures_of_seven'),
#  ('m1mg2x12', '720°', '720', 'https://www.speedrun.com/720'),
#  ('kdkzgrgd',
#   '7554',
#   '7554_glorious_memories_revived',
#   'https://www.speedrun.com/7554_glorious_memories_revived'),
#  ('76r3wgq6',
#   '7: Molmorth no Kiheitai',
#   '7_molmorth_no_kiheitai',
#   'https://www.speedrun.com/7_molmorth_no_kiheitai'),
#  ('3dx2mkg1', '7Days', '7days', 'https://www.speedrun.com/7days'),
#  ('w6jl3q4d',
#   '7th Dragon',
#   '7th_dragon',
#   'https://www.speedrun.com/7th_dragon'),
#  ('lde3pwe6',
#   '7th Dragon 2020',
#   '7th_dragon_2020',
#   'https://www.speedrun.com/7th_dragon_2020'),
#  ('yd490w1e',
#   '7th Street',
#   '7th_street',
#   'https://www.speedrun.com/7th_street'),
#  ('j1n8glw1', '8 Ball Pool', '8ball', 'https://www.speedrun.com/8ball'),
#  ('3dxkkvp1',
#   '8 Bit Space',
#   '8bitspace',
#   'https://www.speedrun.com/8bitspace'),
#  ('9d38je1l', '8 Eyes', '8_eyes', 'https://www.speedrun.com/8_eyes'),
#  ('o1y973o6',
#   '8 Trials Await',
#   '8_trials_await',
#   'https://www.speedrun.com/8_trials_await'),
#  ('9d3pwe6l',
#   '8-Bit Armies',
#   '8bitarmies',
#   'https://www.speedrun.com/8bitarmies'),
#  ('m1mkk3d2',
#   '8-Bit Bayonetta',
#   '8-bit_bayonetta',
#   'https://www.speedrun.com/8-bit_bayonetta'),
#  ('268e8596',
#   '8-Bit Commando',
#   '8-bit_commando',
#   'https://www.speedrun.com/8-bit_commando'),
#  ('ldeq7xd3',
#   '8-Bit Hordes',
#   '8bithordes',
#   'https://www.speedrun.com/8bithordes'),
#  ('kdk4lx1m',
#   '8-Bit Invaders!',
#   '8bitinvaders',
#   'https://www.speedrun.com/8bitinvaders'),
#  ('9d38o2w1', '80 Days', '80_days', 'https://www.speedrun.com/80_days'),
#  ('nd28xlvd',
#   '80 Days (2014)',
#   '80_days_2014',
#   'https://www.speedrun.com/80_days_2014'),
#  ('kdkm74l1',
#   '800 Fathoms ',
#   '800_fathoms_',
#   'https://www.speedrun.com/800_fathoms_'),
#  ('o1y9jx46', '868-HACK', '868-hack', 'https://www.speedrun.com/868-hack'),
#  ('w6jl2g7d',
#   '87 Aftermath: A Rolling Ball Game',
#   '87aftermath',
#   'https://www.speedrun.com/87aftermath'),
#  ('j1llymv1',
#   '88 Heroes / 88 Heroes 98 Heroes Edition',
#   '88_heroes__88_heroes_98_heroes_edition',
#   'https://www.speedrun.com/88_heroes__88_heroes_98_heroes_edition'),
#  ('k6qxm91g',
#   '88 Madness',
#   '88_madness',
#   'https://www.speedrun.com/88_madness'),
#  ('kdkz5kgd', '8b8t.xyz', '8b8t', 'https://www.speedrun.com/8b8t'),
#  ('4d79jrr1',
#   '8Bit Fiesta',
#   '8bit_fiesta',
#   'https://www.speedrun.com/8bit_fiesta'),
#  ('9d3r440d',
#   '8Bit Killer',
#   '8bit_killer',
#   'https://www.speedrun.com/8bit_killer'),
#  ('v1p02868', '8BitBoy', '8bitboy', 'https://www.speedrun.com/8bitboy'),
#  ('j1lqlpe6',
#   "8Doors: Arum's Afterlife Adventure",
#   '8doors',
#   'https://www.speedrun.com/8doors'),
#  ('268wekk6',
#   '8th Wonder of the World',
#   '8th_wonder_of_the_world',
#   'https://www.speedrun.com/8th_wonder_of_the_world'),
#  ('kdkmnkg1',
#   '9 Childs Street',
#   '9_childs_street',
#   'https://www.speedrun.com/9_childs_street'),
#  ('j1lqg76g',
#   '9 Hours, 9 Persons, 9 Doors',
#   '999',
#   'https://www.speedrun.com/999'),
#  ('k6qw5x96',
#   '9 Monkeys of Shaolin',
#   '9_monkeys_of_shaolin',
#   'https://www.speedrun.com/9_monkeys_of_shaolin'),
#  ('pdv2yyk6',
#   '9 Years of Shadows',
#   '9_years_of_shadows',
#   'https://www.speedrun.com/9_years_of_shadows'),
#  ('369p4k01',
#   '911 Fire Rescue',
#   '911_fire_rescue',
#   'https://www.speedrun.com/911_fire_rescue'),
#  ('3dx2n7g1',
#   '911 Operator',
#   '911_operator',
#   'https://www.speedrun.com/911_operator'),
#  ('m1zk9q21',
#   '911: Cannibal (Horror Escape)',
#   '911_cannibal',
#   'https://www.speedrun.com/911_cannibal'),
#  ('pdv93xk1',
#   '911: Prey (Mobile)',
#   '911_Prey',
#   'https://www.speedrun.com/911_Prey'),
#  ('pd0qm421',
#   '99 Fails Lite',
#   '99_fails_lite',
#   'https://www.speedrun.com/99_fails_lite'),
#  ('o1yj97o1',
#   '99 Quest ～Elementary School Mathematics App: Pocket Monsters Version～',
#   '99_quest_elementary_school_mathematics_app_pocket_monsters_version',
#   'https://www.speedrun.com/99_quest_elementary_school_mathematics_app_pocket_monsters_version'),
#  ('w6j77m56',
#   '99 Spirits',
#   '99_spirits',
#   'https://www.speedrun.com/99_spirits'),
#  ('76r3jm56', '99 Vidas', '99_vidas', 'https://www.speedrun.com/99_vidas'),
#  ('3dx29qg1', '9b9t', '9b9t', 'https://www.speedrun.com/9b9t'),
#  ('pdvz8wo6', '9MM', '9mm', 'https://www.speedrun.com/9mm'),
#  ('nd28rnvd',
#   '9th Dawn III',
#   '9th_dawn_iii',
#   'https://www.speedrun.com/9th_dawn_iii'),
#  ('v1pzgpd8', ':The Game:', 'tg', 'https://www.speedrun.com/tg'),
#  ('yd4kqqg6',
#   ':THE LONGING:',
#   'the_longing',
#   'https://www.speedrun.com/the_longing'),
#  ('o1ylr26q', '>OBSERVER_', 'observer', 'https://www.speedrun.com/observer'),
#  ('ldejy8e1', 'a', 'a', 'https://www.speedrun.com/a'),
#  ('lde3qxe6',
#   'A Bewitching Revolution',
#   'abr',
#   'https://www.speedrun.com/abr'),
#  ('kdk7k21m',
#   'A Bird Story',
#   'a_bird_story',
#   'https://www.speedrun.com/a_bird_story'),
#  ('ldewnxd3',
#   'A Boy and His Blob (2009)',
#   'blob09',
#   'https://www.speedrun.com/blob09'),
#  ('3dxk9ry1',
#   "A Brickbattler's Journey",
#   'a_brickbattlers_journey',
#   'https://www.speedrun.com/a_brickbattlers_journey'),
#  ('y65re01e', "A Bug's Life", 'abl', 'https://www.speedrun.com/abl'),
#  ('k6qwywo6',
#   "A Bug's Life (Bootleg)",
#   'a_bugs_life_bootleg',
#   'https://www.speedrun.com/a_bugs_life_bootleg'),
#  ('9dowxr31',
#   "A Bug's Life (GBC)",
#   'ablgbc',
#   'https://www.speedrun.com/ablgbc'),
#  ('268wo456',
#   'A Building Full of Cats',
#   'a_building_full_of_cats',
#   'https://www.speedrun.com/a_building_full_of_cats'),
#  ('v1pxrk76',
#   'A Castle Full of Cats',
#   'a_castle_full_of_cats',
#   'https://www.speedrun.com/a_castle_full_of_cats'),
#  ('pdv2nk46',
#   'A Christmas Gift',
#   'a_christmas_gift',
#   'https://www.speedrun.com/a_christmas_gift'),
#  ('v1px9wm6',
#   'A Clockmaker’s Tale',
#   'a_clockmakers_tale',
#   'https://www.speedrun.com/a_clockmakers_tale'),
#  ('9d38g3w1',
#   'A Craft Of Mine',
#   'a_craft_of_mine',
#   'https://www.speedrun.com/a_craft_of_mine'),
#  ('76rxmvl6',
#   'A Dance of Fire and Ice',
#   'adofai',
#   'https://www.speedrun.com/adofai'),
#  ('kdkmo321',
#   'A Dance of Fire and Ice - Neo Cosmos',
#   'neocosmos',
#   'https://www.speedrun.com/neocosmos'),
#  ('9domk76p',
#   'A Dark Room',
#   'a_dark_room',
#   'https://www.speedrun.com/a_dark_room'),
#  ('76rx80l6',
#   'A Date in the Park',
#   'a_date_in_the_park',
#   'https://www.speedrun.com/a_date_in_the_park'),
#  ('yd4k2m56',
#   'A day in East Europe',
#   'a_day_in_east_europe',
#   'https://www.speedrun.com/a_day_in_east_europe'),
#  ('pdvzv2r6',
#   'A Day In The Future',
#   'a_day_in_the_future',
#   'https://www.speedrun.com/a_day_in_the_future'),
#  ('4d797j31',
#   'A Day in the Life',
#   'a_day_in_the_life',
#   'https://www.speedrun.com/a_day_in_the_life'),
#  ('j1lnlgz6', 'A Day Out', 'A_Day_Out', 'https://www.speedrun.com/A_Day_Out'),
#  ('yd4k45x6',
#   "A Dinosaur's Tale",
#   'a_dinosaurs_tale',
#   'https://www.speedrun.com/a_dinosaurs_tale'),
#  ('y6554o46',
#   'A Door in the Basement',
#   'a_door_in_the_basement',
#   'https://www.speedrun.com/a_door_in_the_basement'),
#  ('pd0q4r01',
#   'A Firm Handshake',
#   'a_firm_handshake',
#   'https://www.speedrun.com/a_firm_handshake'),
#  ('268e49k6', "A Fisherman's Tale", 'aft', 'https://www.speedrun.com/aft'),
#  ('w6j7pk56',
#   "A Frog's Job",
#   'a_frogs_job',
#   'https://www.speedrun.com/a_frogs_job'),
#  ('pdv2nl96',
#   'A Game Of Concentration',
#   'a_game_of_concentration',
#   'https://www.speedrun.com/a_game_of_concentration'),
#  ('4d7nqel6',
#   'A game that saves the muscles caught in the ceiling of the gymnasium',
#   'a_game_that_saves_the_muscles_caught_in_the_ceiling_of_the_gymnasium',
#   'https://www.speedrun.com/a_game_that_saves_the_muscles_caught_in_the_ceiling_of_the_gymnasium'),
#  ('76rxze46',
#   'A Ghostly Journey',
#   'a_ghostly_journey',
#   'https://www.speedrun.com/a_ghostly_journey'),
# ...
#  ('v1px5976',
#   'AFTERGRINDER',
#   'aftergrinder',
#   'https://www.speedrun.com/aftergrinder'),
#  ('76r3y2e6',
#   'AfterHours',
#   'afterhours',
#   'https://www.speedrun.com/afterhours'),
#  ('j1n80ol1',
#   'Afterimage',
#   'afterimage',
#   'https://www.speedrun.com/afterimage'),
#  ('j1l3gz1g', 'Afterlife: The Game', 'altg', 'https://www.speedrun.com/altg'),
#  ('o1yjpx21', 'Aftermoor', 'aftermoor', 'https://www.speedrun.com/aftermoor'),
#  ('m1mnoq4d',
#   'Afterthought',
#   'afterthought',
#   'https://www.speedrun.com/afterthought'),
#  ('j1n47jl6',
#   'Against The Ants (Chống Lại Bầy Kiến)',
#   'ATAs',
#   'https://www.speedrun.com/ATAs'),
#  ('j1nejmx1',
#   'Against The Elements',
#   'against_the_elements',
#   'https://www.speedrun.com/against_the_elements'),
#  ('9do8gv71',
#   'Against the Storm',
#   'against_the_storm',
#   'https://www.speedrun.com/against_the_storm'),
#  ('9d3lrydl', 'Agar.io', 'agario', 'https://www.speedrun.com/agario'),
#  ('kdkzwxxd',
#   'Agatha Christie: Murder on the Orient Express',
#   'agatha_christie_murder_on_the_orient_express',
#   'https://www.speedrun.com/agatha_christie_murder_on_the_orient_express'),
#  ('268er396',
#   'Agatha Christie: The ABC Murders (2016)',
#   'agatha_christie_the_abc_murders_2016',
#   'https://www.speedrun.com/agatha_christie_the_abc_murders_2016'),
#  ('ldejv5j1',
#   'Agatha Christie: The ABC Murders (DS)',
#   'agatha_christie_the_abc_murders_ds',
#   'https://www.speedrun.com/agatha_christie_the_abc_murders_ds'),
#  ('j1ne7zy1',
#   'Age Of Civilizations',
#   'age_of_civilizations',
#   'https://www.speedrun.com/age_of_civilizations'),
#  ('76rx8y56', 'Age of Conquest IV', 'aociv', 'https://www.speedrun.com/aociv'),
#  ('4d7nnpg6', 'Age of Conquest Lite', 'aocl', 'https://www.speedrun.com/aocl'),
#  ('v1px7yp6',
#   'Age of Darkness Final Stand',
#   'age_of_darkness_final_stand',
#   'https://www.speedrun.com/age_of_darkness_final_stand'),
#  ('nj1nowdp', 'Age of Empires', 'aoe1', 'https://www.speedrun.com/aoe1'),
#  ('xldev513', 'Age of Empires II', 'aoe2', 'https://www.speedrun.com/aoe2'),
#  ('j1lx5j1g',
#   'Age of Empires II HD: Rise of the Rajas',
#   'aoe2rotr',
#   'https://www.speedrun.com/aoe2rotr'),
#  ('268nwo6p',
#   'Age of Empires II HD: The African Kingdoms',
#   'aoe2ak',
#   'https://www.speedrun.com/aoe2ak'),
#  ('3dxvly6y',
#   'Age of Empires II HD: The Forgotten',
#   'aoe2fe',
#   'https://www.speedrun.com/aoe2fe'),
#  ('kdkzo5qd',
#   'Age of Empires II: Definitive Edition',
#   'aoe2de',
#   'https://www.speedrun.com/aoe2de'),
#  ('vo6gmx62', 'Age of Empires III', 'aoe3', 'https://www.speedrun.com/aoe3'),
#  ('j1ll0rz1',
#   'Age of Empires III: Definitive Edition',
#   'aoe3de',
#   'https://www.speedrun.com/aoe3de'),
#  ('76r3g3l6', 'Age of Empires IV', 'aoe4', 'https://www.speedrun.com/aoe4'),
#  ('pd0wgrl1',
#   'Age of Empires Online',
#   'aoeo',
#   'https://www.speedrun.com/aoeo'),
#  ('j1ne4vw1',
#   'Age of Empires: Definitive Edition',
#   'aoede',
#   'https://www.speedrun.com/aoede'),
#  ('76r3p246',
#   'Age of Empires: Mythologies',
#   'age_of_empires_mythologies',
#   'https://www.speedrun.com/age_of_empires_mythologies'),
#  ('nd289med',
#   'Age of Empires: The Age of Kings',
#   'aoe2ds',
#   'https://www.speedrun.com/aoe2ds'),
#  ('m1mnlk4d',
#   'Age of Heroes - Silkroad 2',
#   'age_of_heroes_silkroad_2',
#   'https://www.speedrun.com/age_of_heroes_silkroad_2'),
#  ('3dx2lw41', 'Age of History 2', 'aoh2', 'https://www.speedrun.com/aoh2'),
#  ('v1povpm6',
#   'Age of History 2 Category Extension',
#   'aoh2_ce',
#   'https://www.speedrun.com/aoh2_ce'),
#  ('nj1noldp', 'Age of Mythology', 'aom', 'https://www.speedrun.com/aom'),
#  ('w6j78e6j',
#   'Age of War',
#   'age_of_war',
#   'https://www.speedrun.com/age_of_war'),
#  ('kdkmoe1m',
#   'Age of War 2',
#   'age_of_war_2',
#   'https://www.speedrun.com/age_of_war_2'),
#  ('v1pow986',
#   'Age of Wonders',
#   'age_of_wonders',
#   'https://www.speedrun.com/age_of_wonders'),
#  ('268wzz96',
#   'Age of Wonders: Shadow Magic',
#   'age_of_wonders_shadow_magic',
#   'https://www.speedrun.com/age_of_wonders_shadow_magic'),
#  ('j1lqmo76',
#   'Agent 64: Spies Never Die',
#   'agent_64_spies_never_die',
#   'https://www.speedrun.com/agent_64_spies_never_die'),
#  ('ldejp4x1', 'Agent 9', 'agent9', 'https://www.speedrun.com/agent9'),
#  ('y6548j7d',
#   'Agent A: A Puzzle in Disguise',
#   'agent_a',
#   'https://www.speedrun.com/agent_a'),
#  ('m1m8y3d2',
#   'Agent Hugo',
#   'agent_hugo',
#   'https://www.speedrun.com/agent_hugo'),
#  ('m1zjz9z6',
#   'Agent Hugo: Hula Holiday',
#   'agent_hugo_hula_holiday',
#   'https://www.speedrun.com/agent_hugo_hula_holiday'),
#  ('j1lln7j1',
#   'Agent Hugo: Lemoon Twist',
#   'agent_hugo_lemoon_twist',
#   'https://www.speedrun.com/agent_hugo_lemoon_twist'),
#  ('kdkzp2ld',
#   'Agent Hugo: RoboRumble',
#   'ahrr',
#   'https://www.speedrun.com/ahrr'),
#  ('46w3yyl1', 'Agent P: Rebel Spy', 'aprs', 'https://www.speedrun.com/aprs'),
#  ('y654k53d',
#   'Agent P: Return of the Platypus',
#   'aprotp',
#   'https://www.speedrun.com/aprotp'),
#  ('j1ne2ly1',
#   'Agent P: Strikes Back',
#   'apsb',
#   'https://www.speedrun.com/apsb'),
#  ('3dxnn51y', 'Agent Platformer', 'agpl', 'https://www.speedrun.com/agpl'),
#  ('369vwg1l',
#   'Agent Smith',
#   'agent_smith',
#   'https://www.speedrun.com/agent_smith'),
#  ('kdkxvq6m', 'Agents of Mayhem', 'sraom', 'https://www.speedrun.com/sraom'),
#  ('m1mxmxx6', 'Aggelos', 'aggelos', 'https://www.speedrun.com/aggelos'),
#  ('9d3x00dl',
#   'Aggressive Inline',
#   'aggressive_inline',
#   'https://www.speedrun.com/aggressive_inline'),
#  ('o6g42o62',
#   'Aggressors of Dark Kombat',
#   'aggressors_of_dark_kombat',
#   'https://www.speedrun.com/aggressors_of_dark_kombat'),
#  ('w6jglr56',
#   'Agnosthesia',
#   'Agnosthesia',
#   'https://www.speedrun.com/Agnosthesia'),
#  ('o6gn4po1', 'Agony', 'agony', 'https://www.speedrun.com/agony'),
#  ('yd4ox9k1', 'Aground', 'aground', 'https://www.speedrun.com/aground'),
#  ('4d7nver6',
#   'AGRYOS: Recovering Eden',
#   'agryos_recovering_eden',
#   'https://www.speedrun.com/agryos_recovering_eden'),
#  ('pdvz5zr6',
#   'Ahlman Arcade 2018',
#   'ahlman_arcade_2018',
#   'https://www.speedrun.com/ahlman_arcade_2018'),
#  ('4d797wl1',
#   'Ahlman Mansion 2020',
#   'ahlman_mansion_2020',
#   'https://www.speedrun.com/ahlman_mansion_2020'),
#  ('nd282zqd',
#   'Ahri and Bear',
#   'ahri_and_bear',
#   'https://www.speedrun.com/ahri_and_bear'),
#  ('pd0q5rw1',
#   "Ahriman's Prophecy",
#   'ahrimans_prophecy',
#   'https://www.speedrun.com/ahrimans_prophecy'),
#  ('nd2ekv3d',
#   'Ai Cho Aniki (PC Engine)',
#   'ai_cho_aniki_pc_engine',
#   'https://www.speedrun.com/ai_cho_aniki_pc_engine'),
#  ('kdkm7y21', 'AI Gotta Go', 'aigg', 'https://www.speedrun.com/aigg'),
#  ('46wn3n6r',
#   'Ai Senshi Nicol',
#   'aisenshinicol',
#   'https://www.speedrun.com/aisenshinicol'),
#  ('pd0w3331',
#   'AI: THE SOMNIUM FILES',
#   'aitsf',
#   'https://www.speedrun.com/aitsf'),
#  ('36983z8d',
#   'AI: THE SOMNIUM FILES - nirvanA Initiative',
#   'aitsfni',
#   'https://www.speedrun.com/aitsfni'),
#  ('369qyldl',
#   'Aidyn Chronicles: The First Mage',
#   'aidyn',
#   'https://www.speedrun.com/aidyn'),
#  ('o6gnqwn1', 'Aierlon', 'aierlon', 'https://www.speedrun.com/aierlon'),
#  ('9dowr4k1',
#   'Aighina no Yogen: From the Legend of Balubalouk',
#   'aighina_no_yogen_from_the_legend_of_balubalouk',
#   'https://www.speedrun.com/aighina_no_yogen_from_the_legend_of_balubalouk'),
#  ('4d7nkj36',
#   'Aikatsu-stars! First appral',
#   'aikatsustars_first_appral',
#   'https://www.speedrun.com/aikatsustars_first_appral'),
#  ('m1mex2pd',
#   'aikatsu-stars! my special appeal',
#   'aikatsustars_my_special_appeal',
#   'https://www.speedrun.com/aikatsustars_my_special_appeal'),
#  ('pdv2pmo6', 'Aim Climb', 'aim_climb', 'https://www.speedrun.com/aim_climb'),
#  ('369pyz21',
#   'Aim Course 2 by uLLeticaL',
#   'aim_course_2_by_ulletical',
#   'https://www.speedrun.com/aim_course_2_by_ulletical'),
#  ('j1njwl6p',
#   'Aim Course by uLLeticaL',
#   'aim_course_by_ulletical',
#   'https://www.speedrun.com/aim_course_by_ulletical'),
#  ('yd4o70g1',
#   'Aim GAMERZ by uLLeticaL',
#   'aim_gamerz_by_ulletical',
#   'https://www.speedrun.com/aim_gamerz_by_ulletical'),
#  ('3dx2z351',
#   'Aim Time Trial by uLLeticaL',
#   'aim_time_trial_by_ulletical',
#   'https://www.speedrun.com/aim_time_trial_by_ulletical'),
#  ('9d380001',
#   'Aim training',
#   'aimtraining',
#   'https://www.speedrun.com/aimtraining'),
#  ('j1nele91', 'Aimi', 'aimi', 'https://www.speedrun.com/aimi'),
#  ('y655rk06', 'Ain Dodo', 'ain_dodo', 'https://www.speedrun.com/ain_dodo'),
#  ('lde3zpe6',
#   'Aion Free-to-Play',
#   'aion_free-to-play',
#   'https://www.speedrun.com/aion_free-to-play'),
#  ('4d7q5l67', 'Aion: Ascension', 'aion', 'https://www.speedrun.com/aion'),
#  ('m1mnw4d2', 'Air', 'smb1-air', 'https://www.speedrun.com/smb1-air'),
#  ('m1zk0ex1',
#   'Air Assault',
#   'air_assault',
#   'https://www.speedrun.com/air_assault'),
#  ('w6j70q76',
#   'Air Attack',
#   'air_attack',
#   'https://www.speedrun.com/air_attack'),
#  ('o1y94jo6',
#   'Air Boarder 64',
#   'air_boarder_64',
#   'https://www.speedrun.com/air_boarder_64'),
#  ('o1y9gyo6',
#   "Air Bounce - The Jump 'n' Run Challenge",
#   'air_bounce',
#   'https://www.speedrun.com/air_bounce'),
#  ('yd4keyk6',
#   'Air Buster: Trouble Speciality Raid Unit',
#   'air_buster_trouble_speciality_raid_unit',
#   'https://www.speedrun.com/air_buster_trouble_speciality_raid_unit'),
#  ('pd0exv1e', 'Air Combat', 'aircombat', 'https://www.speedrun.com/aircombat'),
#  ('46wv0ndr',
#   'Air Control',
#   'aircontrol',
#   'https://www.speedrun.com/aircontrol'),
#  ('9d385791', 'Air Dribble Challenge', 'adc', 'https://www.speedrun.com/adc'),
#  ('3dxk8vv1',
#   'Air Dribble Hoops',
#   'adhoops',
#   'https://www.speedrun.com/adhoops'),
#  ('pd0qz2l1',
#   'Air Dribble Melee',
#   'airdribblemelee',
#   'https://www.speedrun.com/airdribblemelee'),
#  ('m1mnp2xd', 'Air Duel', 'air_duel', 'https://www.speedrun.com/air_duel'),
#  ('m1zww010',
#   'Air Fortress',
#   'air_fortress',
#   'https://www.speedrun.com/air_fortress'),
#  ('pdv2wpv6',
#   'Air Gallet',
#   'air_gallet',
#   'https://www.speedrun.com/air_gallet'),
#  ('kdkm89e1',
#   'Air Hockey',
#   'air_hockey',
#   'https://www.speedrun.com/air_hockey'),
#  ('369prm21', 'Air Nomad', 'air_nomad', 'https://www.speedrun.com/air_nomad'),
#  ('4d7n8436',
#   'Air Rescue',
#   'air_rescue',
#   'https://www.speedrun.com/air_rescue'),
#  ('9dowky31', 'Air Zonk', 'air_zonk', 'https://www.speedrun.com/air_zonk'),
#  ('m1zr8xd0', 'Air-Sea Battle', 'asb', 'https://www.speedrun.com/asb'),
#  ('76rj2e18', 'AiRace Speed', 'airspeed', 'https://www.speedrun.com/airspeed'),
#  ('j1l9jv1g', 'AiRace Xeno', 'airxeno', 'https://www.speedrun.com/airxeno'),
#  ('o6g30od2',
#   'AiRace: Tunnel',
#   'airtunnel',
#   'https://www.speedrun.com/airtunnel'),
#  ('46w94n1r', 'AirBlade', 'airblade', 'https://www.speedrun.com/airblade'),
#  ('kdkmyle1',
#   'Airborne Troops: Countdown to D-Day',
#   'airborne_troops',
#   'https://www.speedrun.com/airborne_troops'),
#  ('76rx7ve6',
#   'Airfix Dogfighter',
#   'airfix_dogfighter',
#   'https://www.speedrun.com/airfix_dogfighter'),
#  ('o1y39846',
#   'AirForce Delta Storm (GBA)',
#   'AirForce_Delta_Storm_GBA',
#   'https://www.speedrun.com/AirForce_Delta_Storm_GBA'),
#  ('369wzp0d',
#   'Airforce Delta Strike',
#   'airforce_delta_strike',
#   'https://www.speedrun.com/airforce_delta_strike'),
#  ('w6jlym4d', 'AirGrave', 'airgrave', 'https://www.speedrun.com/airgrave'),
#  ('46w2omn6', 'Airhead', 'airhead', 'https://www.speedrun.com/airhead'),
#  ('j1neg5w1',
#   'AIRHEART - Tales of broken Wings',
#   'airheart_-_tales_of_broken_wings',
#   'https://www.speedrun.com/airheart_-_tales_of_broken_wings'),
#  ('lde7q513', 'Airlock', 'airlock', 'https://www.speedrun.com/airlock'),
#  ('pd0weq01',
#   'Airplane Mode',
#   'airplane_mode',
#   'https://www.speedrun.com/airplane_mode'),
#  ('y6555o46',
#   'Airport CEO',
#   'airport_ceo',
#   'https://www.speedrun.com/airport_ceo'),
#  ('46w3q891',
#   'Airport Madness 3D',
#   'airport_madness_3d',
#   'https://www.speedrun.com/airport_madness_3d'),
#  ('o6gnn2n1',
#   'Airport Madness 3D: Volume 2',
#   'airport_madness_3d_volume_2',
#   'https://www.speedrun.com/airport_madness_3d_volume_2'),
#  ('w6j7jx76',
#   'Airs Adventure',
#   'airs_adventure',
#   'https://www.speedrun.com/airs_adventure'),
#  ('4d7rzz17',
#   'Airscape: The Fall of Gravity',
#   'airscape',
#   'https://www.speedrun.com/airscape'),
#  ('46w3k5n1',
#   'Airships: Conquer the Skies',
#   'airships_conquer_the_skies',
#   'https://www.speedrun.com/airships_conquer_the_skies'),
#  ('46w297n6',
#   'Airu De Puzzle',
#   'airu_de_puzzle',
#   'https://www.speedrun.com/airu_de_puzzle'),
#  ('j1ner2l1',
#   'Airwolf (Arcade)',
#   'airwolf_arcade',
#   'https://www.speedrun.com/airwolf_arcade'),
#  ('k6q50o6g',
#   'Airwolf (Japan)',
#   'airwolfjp',
#   'https://www.speedrun.com/airwolfjp'),
#  ('w6jl7w4d',
#   'Airwolf (US/EU)',
#   'airwolf_useu',
#   'https://www.speedrun.com/airwolf_useu'),
#  ('268evyo6', 'AirXonix', 'airxonix', 'https://www.speedrun.com/airxonix'),
#  ('76r32zq6', 'AK-xolotl', 'akxolotl', 'https://www.speedrun.com/akxolotl'),
#  ('lde3qwe6',
#   'Aka Manto | 赤マント',
#   'aka_manto',
#   'https://www.speedrun.com/aka_manto'),
#  ('ldej80e1',
#   'Akai Katana',
#   'akai_katana',
#   'https://www.speedrun.com/akai_katana'),
#  ('k6q4mr9d',
#   'Akalabeth: World of Doom',
#   'akalabeth',
#   'https://www.speedrun.com/akalabeth'),
#  ('9do8r4k1', 'Akane', 'akane', 'https://www.speedrun.com/akane'),
#  ('m1zxx0d0',
#   'Akane the Kunoichi',
#   'akane_the_kunoichi',
#   'https://www.speedrun.com/akane_the_kunoichi'),
#  ('369p0k21',
#   'Akatsuki Blitzkampf',
#   'akatsuki_blitzkampf',
#   'https://www.speedrun.com/akatsuki_blitzkampf'),
#  ('3dxk3xp1',
#   'Akatsuki Blitzkampf Ausf. Achse',
#   'akatsuki_blitzkampf_ausf_achse',
#   'https://www.speedrun.com/akatsuki_blitzkampf_ausf_achse'),
#  ('9d384091',
#   'Akazukin Chacha',
#   'akazukin_chacha',
#   'https://www.speedrun.com/akazukin_chacha'),
#  ('nd2eoged', 'Akemi Tan', 'akemi_tan', 'https://www.speedrun.com/akemi_tan'),
#  ('kdkmjwg1',
#   "AKIBA'S BEAT",
#   'akibas_beat',
#   'https://www.speedrun.com/akibas_beat'),
#  ('y6555m76',
#   "Akiba's Trip: Hellbound and Debriefed",
#   'akibas_trip_hellbound_and_debriefed',
#   'https://www.speedrun.com/akibas_trip_hellbound_and_debriefed'),
#  ('m1zekm10',
#   "Akiba's Trip: Undead & Undressed",
#   'akibas_trip_undead_and_undressed',
#   'https://www.speedrun.com/akibas_trip_undead_and_undressed'),
#  ('m1zkg921',
#   'Akimbo: Kung-Fu Hero',
#   'akimbo',
#   'https://www.speedrun.com/akimbo'),
#  ('3dxkv7v1',
#   'Akirry Roll',
#   'akirry_roll',
#   'https://www.speedrun.com/akirry_roll'),
#  ('9do8q7m1',
#   'Akkanvader',
#   'akkanvader',
#   'https://www.speedrun.com/akkanvader'),
#  ('268w32k6', 'Akogare 2', 'akogare_2', 'https://www.speedrun.com/akogare_2'),
#  ('369po721',
#   'Akogare Mario World',
#   'akogaremarioworld',
#   'https://www.speedrun.com/akogaremarioworld'),
#  ('268wrpk6',
#   'Akuji the Demon',
#   'akuji_the_demon',
#   'https://www.speedrun.com/akuji_the_demon'),
#  ('w6j8021j',
#   'Akuji: The Heartless',
#   'akuji_the_heartless',
#   'https://www.speedrun.com/akuji_the_heartless'),
#  ('j1n4z96p',
#   'Akumajou Special Boku Dracula-kun',
#   'akumajou_special_boku_dracula_kun',
#   'https://www.speedrun.com/akumajou_special_boku_dracula_kun'),
#  ('nd28ne3d',
#   'Akumajyo Dracula Peke',
#   'peke',
#   'https://www.speedrun.com/peke'),
#  ('nd28375d', 'Akumu', 'akumu', 'https://www.speedrun.com/akumu'),
#  ('k6q4o7md',
#   "Al Unser Jr's Road To The Top",
#   'al_unser_jrs_road_to_the_top',
#   'https://www.speedrun.com/al_unser_jrs_road_to_the_top'),
#  ('4d79q5r1',
#   'Al Unser Jr. Turbo Racing',
#   'al_unser_jr._turbo_racing',
#   'https://www.speedrun.com/al_unser_jr._turbo_racing'),
#  ('k6qw7lm6',
#   'Alabaras Shells',
#   'alabaras_shells',
#   'https://www.speedrun.com/alabaras_shells'),
#  ('9d3roywd',
#   'Aladdin (Hummer Team)',
#   'aladdin_hummer_team',
#   'https://www.speedrun.com/aladdin_hummer_team'),
#  ('268exq76',
#   'Aladdin (Super Game)',
#   'aladdin_super_game',
#   'https://www.speedrun.com/aladdin_super_game'),
#  ('y6543g4d',
#   'Aladdin 2000 (SNES Bootleg)',
#   'aladdin_2000_snes_bootleg',
#   'https://www.speedrun.com/aladdin_2000_snes_bootleg'),
#  ('m1zkw0z1',
#   'Aladdin and Magic skull',
#   'aladdin_and_magic_skull',
#   'https://www.speedrun.com/aladdin_and_magic_skull'),
#  ('76rxnrv6',
#   'Aladdin II',
#   'aladdin_ii',
#   'https://www.speedrun.com/aladdin_ii')]

# %%
game_data = pd.DataFrame(page_data_to_list(first_page_data), columns =['Identifier', 'Name', 'Abbreviation', 'Link'])

# %%
game_data
# Out:
#     Identifier                              Name  \
# 0     o1y32j26                  Bike Unchained 2
# 1     y65rm041   BIRDIE WING -Golf Girls' Story-
# 2     kdkqz3xd                  DYNAMITE BOMB!!
# 3     3698qwld         Great Dungeon In The Sky
# 4     ldej48j1               House of Da Vinci 2
# ..         ...                               ...
# 995   9d3roywd             Aladdin (Hummer Team)
# 996   268exq76              Aladdin (Super Game)
# 997   y6543g4d       Aladdin 2000 (SNES Bootleg)
# 998   m1zkw0z1           Aladdin and Magic skull
# 999   76rxnrv6                        Aladdin II
#
#                       Abbreviation  \
# 0                _bike_unchained_2
# 1    _birdie_wing_golf_girls_story
# 2                  _DYNAMITE_BOMB_
# 3       _great_dungeon_in_the_sky_
# 4          the_house_of_da_vinci_2
# ..                             ...
# 995            aladdin_hummer_team
# 996             aladdin_super_game
# 997      aladdin_2000_snes_bootleg
# 998        aladdin_and_magic_skull
# 999                     aladdin_ii
#
#                                                   Link
# 0           https://www.speedrun.com/_bike_unchained_2
# 1    https://www.speedrun.com/_birdie_wing_golf_gir...
# 2             https://www.speedrun.com/_DYNAMITE_BOMB_
# 3    https://www.speedrun.com/_great_dungeon_in_the...
# 4     https://www.speedrun.com/the_house_of_da_vinci_2
# ..                                                 ...
# 995       https://www.speedrun.com/aladdin_hummer_team
# 996        https://www.speedrun.com/aladdin_super_game
# 997  https://www.speedrun.com/aladdin_2000_snes_boo...
# 998   https://www.speedrun.com/aladdin_and_magic_skull
# 999                https://www.speedrun.com/aladdin_ii
#
# [1000 rows x 4 columns]

# %% [markdown]
# ### Pagination

# %%
first_page_pagination = first_page_json['pagination']
first_page_pagination
# Out:
# {'offset': 0,
#  'max': 1000,
#  'size': 1000,
#  'links': [{'rel': 'next',
#    'uri': 'https://www.speedrun.com/api/v1/games?_bulk=yes&max=1000&offset=1000'}]}

# %%
first_page_pagination['links']
# Out:
# [{'rel': 'next',
#   'uri': 'https://www.speedrun.com/api/v1/games?_bulk=yes&max=1000&offset=1000'}]

# %%
next_request = first_page_pagination['links'][0]['uri']

# %%
next_page = requests.get(next_request)

# %%
next_page.json()
# Out:
# {'data': [{'id': 'j1llxxj1',
#    'names': {'international': 'Aladdin Magic Racer', 'japanese': None},
#    'abbreviation': 'aladdin_magic_racer',
#    'weblink': 'https://www.speedrun.com/aladdin_magic_racer'},
#   {'id': 'y655ex06',
#    'names': {'international': "Aladdin's Wonders of the World",
#     'japanese': None},
#    'abbreviation': 'aladdins_wonders_of_the_world',
#    'weblink': 'https://www.speedrun.com/aladdins_wonders_of_the_world'},
#   {'id': 'v1plox76',
#    'names': {'international': 'Alan Pest Control', 'japanese': None},
#    'abbreviation': 'Alan_Pest_Control',
#    'weblink': 'https://www.speedrun.com/Alan_Pest_Control'},
#   {'id': 'w6jlpxdj',
#    'names': {'international': 'Alan Wake', 'japanese': None},
#    'abbreviation': 'aw',
#    'weblink': 'https://www.speedrun.com/aw'},
#   {'id': 'j1n89nx1',
#    'names': {'international': 'Alan Wake Remastered', 'japanese': None},
#    'abbreviation': 'alan_wake_remastered',
#    'weblink': 'https://www.speedrun.com/alan_wake_remastered'},
#   {'id': '268kyk6p',
#    'names': {'international': "Alan Wake's American Nightmare",
#     'japanese': None},
#    'abbreviation': 'awan',
#    'weblink': 'https://www.speedrun.com/awan'},
#   {'id': '4d79vlg1',
#    'names': {'international': 'Alarm for Cobra 11: Nitro', 'japanese': None},
#    'abbreviation': 'alarm_for_cobra_11_nitro',
#    'weblink': 'https://www.speedrun.com/alarm_for_cobra_11_nitro'},
#   {'id': 'ldej2ml1',
#    'names': {'international': 'Alarm for Cobra 11: Undercover',
#     'japanese': None},
#    'abbreviation': 'alarm_for_cobra_11_undercover',
#    'weblink': 'https://www.speedrun.com/alarm_for_cobra_11_undercover'},
#   {'id': 'j1ne5le1',
#    'names': {'international': 'Alaska', 'japanese': None},
#    'abbreviation': 'alaska',
#    'weblink': 'https://www.speedrun.com/alaska'},
#   {'id': '9d3rzled',
#    'names': {'international': 'Alba: A Wildlife Adventure', 'japanese': None},
#    'abbreviation': 'alba',
#    'weblink': 'https://www.speedrun.com/alba'},
#   {'id': 'j1l2ge6g',
#    'names': {'international': 'Albert & Otto', 'japanese': None},
#    'abbreviation': 'aao',
#    'weblink': 'https://www.speedrun.com/aao'},
#   {'id': '268w5x96',
#    'names': {'international': "Albert and Camille's Little Lille Adventure",
#     'japanese': None},
#    'abbreviation': 'albert_and_camilles_little_lille_adventure',
#    'weblink': 'https://www.speedrun.com/albert_and_camilles_little_lille_adventure'},
#   {'id': 'w6j73x76',
#    'names': {'international': 'Albert Odyssey', 'japanese': None},
#    'abbreviation': 'albert_odyssey',
#    'weblink': 'https://www.speedrun.com/albert_odyssey'},
#   {'id': '9do3medp',
#    'names': {'international': 'Albert Odyssey: Legend of Eldean',
#     'japanese': 'Albert Odyssey Gaiden ~Legend of Eldean~'},
#    'abbreviation': 'albert_odyssey_legend_of_eldean',
#    'weblink': 'https://www.speedrun.com/albert_odyssey_legend_of_eldean'},
#   {'id': '9d32y01l',
#    'names': {'international': 'Albino Lullaby', 'japanese': None},
#    'abbreviation': 'albino_lullaby',
#    'weblink': 'https://www.speedrun.com/albino_lullaby'},
#   {'id': '268emm96',
#    'names': {'international': 'Albion', 'japanese': None},
#    'abbreviation': 'albion',
#    'weblink': 'https://www.speedrun.com/albion'},
#   {'id': 'pd0wy521',
#    'names': {'international': 'Albion Online', 'japanese': None},
#    'abbreviation': 'albion_online',
#    'weblink': 'https://www.speedrun.com/albion_online'},
#   {'id': '76rxxvq6',
#    'names': {'international': 'Alcahest', 'japanese': 'アルカエスト'},
#    'abbreviation': 'alcahest',
#    'weblink': 'https://www.speedrun.com/alcahest'},
#   {'id': 'nd284jqd',
#    'names': {'international': 'Alcatraz', 'japanese': None},
#    'abbreviation': 'alcatraz',
#    'weblink': 'https://www.speedrun.com/alcatraz'},
#   {'id': 'yd4oonp1',
#    'names': {'international': 'Alcatraz: Prison Escape', 'japanese': None},
#    'abbreviation': 'alcatraz_prison_escape',
#    'weblink': 'https://www.speedrun.com/alcatraz_prison_escape'},
#   {'id': 'o1y394o6',
#    'names': {'international': 'Alcazar: The Forgotten Fortress',
#     'japanese': None},
#    'abbreviation': 'Alcazar',
#    'weblink': 'https://www.speedrun.com/Alcazar'},
#   {'id': 'ldejnj51',
#    'names': {'international': 'Alchemilla Mod', 'japanese': None},
#    'abbreviation': 'alchemilla_mod',
#    'weblink': 'https://www.speedrun.com/alchemilla_mod'},
#   {'id': '268wml56',
#    'names': {'international': 'Alchemist Adventure', 'japanese': None},
#    'abbreviation': 'alchemist_adventure',
#    'weblink': 'https://www.speedrun.com/alchemist_adventure'},
#   {'id': '46w3wnn1',
#    'names': {'international': "Alchemist's Castle", 'japanese': None},
#    'abbreviation': 'alchemists_castle',
#    'weblink': 'https://www.speedrun.com/alchemists_castle'},
#   {'id': 'j1llpjj1',
#    'names': {'international': 'Alchemy Deluxe', 'japanese': None},
#    'abbreviation': 'alchemy',
#    'weblink': 'https://www.speedrun.com/alchemy'},
#   {'id': 'o6gnqj91',
#    'names': {'international': 'Alcina', 'japanese': None},
#    'abbreviation': 'alcina',
#    'weblink': 'https://www.speedrun.com/alcina'},
#   {'id': '3dxkv9p1',
#    'names': {'international': 'Alcrush', 'japanese': None},
#    'abbreviation': 'alcrush',
#    'weblink': 'https://www.speedrun.com/alcrush'},
#   {'id': 'nd28qz5d',
#    'names': {'international': "Aldo's Adventure", 'japanese': None},
#    'abbreviation': 'aldos_adventure',
#    'weblink': 'https://www.speedrun.com/aldos_adventure'},
#   {'id': 'o1y9eno6',
#    'names': {'international': 'Aldred Knight', 'japanese': None},
#    'abbreviation': 'ak',
#    'weblink': 'https://www.speedrun.com/ak'},
#   {'id': 'kdkm8xg1',
#    'names': {'international': 'Aldynes: The Misson Code for Rage Crisis',
#     'japanese': None},
#    'abbreviation': 'aldynes_the_misson_code_for_rage_crisis',
#    'weblink': 'https://www.speedrun.com/aldynes_the_misson_code_for_rage_crisis'},
#   {'id': 'yd4krlk6',
#    'names': {'international': "Alec's survival", 'japanese': None},
#    'abbreviation': 'alecs_survival',
#    'weblink': 'https://www.speedrun.com/alecs_survival'},
#   {'id': 'w6jlv75d',
#    'names': {'international': "Alekhine's Gun", 'japanese': None},
#    'abbreviation': 'ag',
#    'weblink': 'https://www.speedrun.com/ag'},
#   {'id': 'yd4o4jk1',
#    'names': {'international': 'Alex Gordon', 'japanese': None},
#    'abbreviation': 'alex_gordon',
#    'weblink': 'https://www.speedrun.com/alex_gordon'},
#   {'id': 'pdvzzm96',
#    'names': {'international': 'Alex Kidd BMX Trial',
#     'japanese': 'アレックスキッドBMXトライアル'},
#    'abbreviation': 'alexkiddbmx',
#    'weblink': 'https://www.speedrun.com/alexkiddbmx'},
#   {'id': 'm9do7e6p',
#    'names': {'international': 'Alex Kidd in Miracle World', 'japanese': None},
#    'abbreviation': 'akimw',
#    'weblink': 'https://www.speedrun.com/akimw'},
#   {'id': 'j1llx0j1',
#    'names': {'international': 'Alex Kidd in Miracle World 2',
#     'japanese': None},
#    'abbreviation': 'alex_kidd_in_miracle_world_2',
#    'weblink': 'https://www.speedrun.com/alex_kidd_in_miracle_world_2'},
#   {'id': 'm1zkjpm1',
#    'names': {'international': 'Alex Kidd in Miracle World DX',
#     'japanese': None},
#    'abbreviation': 'alex_kidd_in_miracle_world_dx',
#    'weblink': 'https://www.speedrun.com/alex_kidd_in_miracle_world_dx'},
#   {'id': 'om1m0p62',
#    'names': {'international': 'Alex Kidd in Shinobi World', 'japanese': None},
#    'abbreviation': 'akisw',
#    'weblink': 'https://www.speedrun.com/akisw'},
#   {'id': '946woq1r',
#    'names': {'international': 'Alex Kidd in the Enchanted Castle',
#     'japanese': 'Arekkusu Kiddo Tenkū Majō'},
#    'abbreviation': 'alex_kidd_in_the_enchanted_castle',
#    'weblink': 'https://www.speedrun.com/alex_kidd_in_the_enchanted_castle'},
#   {'id': 'kyd43p1e',
#    'names': {'international': 'Alex Kidd The Lost Stars', 'japanese': None},
#    'abbreviation': 'alex_kidd_the_lost_stars',
#    'weblink': 'https://www.speedrun.com/alex_kidd_the_lost_stars'},
#   {'id': 'xv1p7418',
#    'names': {'international': 'Alex Kidd: High-Tech World', 'japanese': None},
#    'abbreviation': 'alex_kidd_hightech_world',
#    'weblink': 'https://www.speedrun.com/alex_kidd_hightech_world'},
#   {'id': 'lde30rx6',
#    'names': {'international': 'Alex Rider: Stormbreaker', 'japanese': None},
#    'abbreviation': 'arsb',
#    'weblink': 'https://www.speedrun.com/arsb'},
#   {'id': 'kdkggx1m',
#    'names': {'international': 'Alex the Allegator 4', 'japanese': None},
#    'abbreviation': 'alex_the_allegator_4',
#    'weblink': 'https://www.speedrun.com/alex_the_allegator_4'},
#   {'id': '369p0321',
#    'names': {'international': 'Alexandra Ledermann 4 : Aventures au Haras',
#     'japanese': None},
#    'abbreviation': 'alexandra_ledermann_4__aventures_au_haras',
#    'weblink': 'https://www.speedrun.com/alexandra_ledermann_4__aventures_au_haras'},
#   {'id': 'w6j73n26',
#    'names': {'international': "Alexey's Compound Alpha", 'japanese': None},
#    'abbreviation': 'alexey',
#    'weblink': 'https://www.speedrun.com/alexey'},
#   {'id': 'w6j782e6',
#    'names': {'international': 'Alexis Almighty: Daughter of Hercules',
#     'japanese': None},
#    'abbreviation': 'alexis_almighty_daughter_of_hercules',
#    'weblink': 'https://www.speedrun.com/alexis_almighty_daughter_of_hercules'},
#   {'id': 'j1lyrvdg',
#    'names': {'international': 'ALF', 'japanese': None},
#    'abbreviation': 'alf',
#    'weblink': 'https://www.speedrun.com/alf'},
#   {'id': '268wpyy6',
#    'names': {'international': 'Alfag3ah', 'japanese': None},
#    'abbreviation': 'alfag3ah',
#    'weblink': 'https://www.speedrun.com/alfag3ah'},
#   {'id': '3dxyo46y',
#    'names': {'international': 'Alfred Chicken (GB)', 'japanese': None},
#    'abbreviation': 'alfredchickengb',
#    'weblink': 'https://www.speedrun.com/alfredchickengb'},
#   {'id': 'm1me5pd2',
#    'names': {'international': 'Alfred Chicken (NES)', 'japanese': None},
#    'abbreviation': 'alfredchickennes',
#    'weblink': 'https://www.speedrun.com/alfredchickennes'},
#   {'id': 'v1po0ep6',
#    'names': {'international': 'Alfred Chicken (PSX)', 'japanese': None},
#    'abbreviation': 'alfred_chicken_psx',
#    'weblink': 'https://www.speedrun.com/alfred_chicken_psx'},
#   {'id': 'w6j7yq46',
#    'names': {'international': "Alfred's Adventure", 'japanese': None},
#    'abbreviation': 'alfreda',
#    'weblink': 'https://www.speedrun.com/alfreda'},
#   {'id': 'm1mnm44d',
#    'names': {'international': 'Alfredo Lamberra', 'japanese': None},
#    'abbreviation': 'silvereye',
#    'weblink': 'https://www.speedrun.com/silvereye'},
#   {'id': 'ldej5xe1',
#    'names': {'international': "Algo's Mario Sunshine Parkour",
#     'japanese': None},
#    'abbreviation': 'algomsp',
#    'weblink': 'https://www.speedrun.com/algomsp'},
#   {'id': 'nd248e10',
#    'names': {'international': 'Alias', 'japanese': None},
#    'abbreviation': 'alias',
#    'weblink': 'https://www.speedrun.com/alias'},
#   {'id': 'yd4k9jk6',
#    'names': {'international': 'Alice Escaped! ', 'japanese': None},
#    'abbreviation': 'alice_escaped_',
#    'weblink': 'https://www.speedrun.com/alice_escaped_'},
#   {'id': '268wlv76',
#    'names': {'international': 'Alice Gear Aegis CS: Concerto of Simulatrix',
#     'japanese': None},
#    'abbreviation': 'alice_gear',
#    'weblink': 'https://www.speedrun.com/alice_gear'},
#   {'id': 'pd0kw01e',
#    'names': {'international': 'Alice in Wonderland', 'japanese': None},
#    'abbreviation': 'alice2010',
#    'weblink': 'https://www.speedrun.com/alice2010'},
#   {'id': 'nd28wp3d',
#    'names': {'international': 'Alice in Wonderland (DS)', 'japanese': None},
#    'abbreviation': 'alice_in_wonderland_ds',
#    'weblink': 'https://www.speedrun.com/alice_in_wonderland_ds'},
#   {'id': 'yd4omwp1',
#    'names': {'international': 'Alice is Dead', 'japanese': None},
#    'abbreviation': 'alice_is_dead',
#    'weblink': 'https://www.speedrun.com/alice_is_dead'},
#   {'id': '3dx2jx41',
#    'names': {'international': 'Alice is Dead 2', 'japanese': None},
#    'abbreviation': 'alice_is_dead_2',
#    'weblink': 'https://www.speedrun.com/alice_is_dead_2'},
#   {'id': 'v1pom046',
#    'names': {'international': 'Alice is Dead 3', 'japanese': None},
#    'abbreviation': 'alice_is_dead_3',
#    'weblink': 'https://www.speedrun.com/alice_is_dead_3'},
#   {'id': 'y654w87d',
#    'names': {'international': 'Alice Trapped in Wonderland', 'japanese': None},
#    'abbreviation': 'alice_trapped_in_wonderland',
#    'weblink': 'https://www.speedrun.com/alice_trapped_in_wonderland'},
#   {'id': '36988qgd',
#    'names': {'international': 'Alice 愛莉澄 ', 'japanese': None},
#    'abbreviation': 'alice__',
#    'weblink': 'https://www.speedrun.com/alice__'},
#   {'id': 'v1pog768',
#    'names': {'international': 'Alice: Madness Returns', 'japanese': None},
#    'abbreviation': 'amr',
#    'weblink': 'https://www.speedrun.com/amr'},
#   {'id': 'y6554476',
#    'names': {'international': 'Alicemare', 'japanese': None},
#    'abbreviation': 'alicemare',
#    'weblink': 'https://www.speedrun.com/alicemare'},
#   {'id': 'm1zjy9x6',
#    'names': {'international': 'Alien', 'japanese': None},
#    'abbreviation': 'atarialien',
#    'weblink': 'https://www.speedrun.com/atarialien'},
#   {'id': '4d723z67',
#    'names': {'international': 'Alien 3 (GB)', 'japanese': None},
#    'abbreviation': 'alien_3_gb',
#    'weblink': 'https://www.speedrun.com/alien_3_gb'},
#   {'id': 'y65zn06e',
#    'names': {'international': 'Alien 3 (Genesis)', 'japanese': None},
#    'abbreviation': 'alien_3_genesis',
#    'weblink': 'https://www.speedrun.com/alien_3_genesis'},
#   {'id': '9d3py96l',
#    'names': {'international': 'Alien 3 (NES)', 'japanese': None},
#    'abbreviation': 'alien_3_nes',
#    'weblink': 'https://www.speedrun.com/alien_3_nes'},
#   {'id': 'w6jw271j',
#    'names': {'international': 'Alien 3 (SMS)', 'japanese': None},
#    'abbreviation': 'alien_3_sms',
#    'weblink': 'https://www.speedrun.com/alien_3_sms'},
#   {'id': 'v1pkm7d8',
#    'names': {'international': 'Alien 3 (SNES)', 'japanese': None},
#    'abbreviation': 'a3s',
#    'weblink': 'https://www.speedrun.com/a3s'},
#   {'id': 'w6jro7dj',
#    'names': {'international': 'Alien 3: The Gun', 'japanese': None},
#    'abbreviation': 'alien_3_the_gun',
#    'weblink': 'https://www.speedrun.com/alien_3_the_gun'},
#   {'id': '9do5o31p',
#    'names': {'international': 'Alien Breed', 'japanese': None},
#    'abbreviation': 'alienbreed',
#    'weblink': 'https://www.speedrun.com/alienbreed'},
#   {'id': 'lde38ql6',
#    'names': {'international': 'Alien Breed 2: Assault', 'japanese': None},
#    'abbreviation': 'alien_breed_2_assault',
#    'weblink': 'https://www.speedrun.com/alien_breed_2_assault'},
#   {'id': '268eq4y6',
#    'names': {'international': 'Alien Breed 3: Descent', 'japanese': None},
#    'abbreviation': 'alien_breed_3_descent',
#    'weblink': 'https://www.speedrun.com/alien_breed_3_descent'},
#   {'id': '3dxojvdy',
#    'names': {'international': 'Alien Breed 3D', 'japanese': None},
#    'abbreviation': 'alienbreed3d',
#    'weblink': 'https://www.speedrun.com/alienbreed3d'},
#   {'id': 'j1l5ne6g',
#    'names': {'international': 'Alien Breed 3d II: The Killing Grounds',
#     'japanese': None},
#    'abbreviation': 'alienbreed3d2',
#    'weblink': 'https://www.speedrun.com/alienbreed3d2'},
#   {'id': 'm1m5vjd2',
#    'names': {'international': 'Alien Breed II: The Horror Continues',
#     'japanese': None},
#    'abbreviation': 'alienbreed2',
#    'weblink': 'https://www.speedrun.com/alienbreed2'},
#   {'id': 'k6q4vlxd',
#    'names': {'international': 'Alien Breed: Evolution', 'japanese': None},
#    'abbreviation': 'alien_breed_evolution',
#    'weblink': 'https://www.speedrun.com/alien_breed_evolution'},
#   {'id': 'j1nelwl1',
#    'names': {'international': 'Alien Breed: Impact', 'japanese': None},
#    'abbreviation': 'alien_breed_impact',
#    'weblink': 'https://www.speedrun.com/alien_breed_impact'},
#   {'id': 'yd4pm5de',
#    'names': {'international': 'Alien Breed: Tower Assault', 'japanese': None},
#    'abbreviation': 'alienbreedtower',
#    'weblink': 'https://www.speedrun.com/alienbreedtower'},
#   {'id': 'm1zjjw36',
#    'names': {'international': 'Alien Cabal', 'japanese': None},
#    'abbreviation': 'alien_cabal',
#    'weblink': 'https://www.speedrun.com/alien_cabal'},
#   {'id': 'k6q4ek0d',
#    'names': {'international': 'Alien Cat', 'japanese': None},
#    'abbreviation': 'alien_cat',
#    'weblink': 'https://www.speedrun.com/alien_cat'},
#   {'id': '4d79ypn1',
#    'names': {'international': 'Alien Cat 2', 'japanese': None},
#    'abbreviation': 'alien_cat_2',
#    'weblink': 'https://www.speedrun.com/alien_cat_2'},
#   {'id': 'w6jlwmed',
#    'names': {'international': 'Alien Challenge', 'japanese': None},
#    'abbreviation': 'alien_challenge',
#    'weblink': 'https://www.speedrun.com/alien_challenge'},
#   {'id': '4d795kz1',
#    'names': {'international': 'Alien Crush', 'japanese': None},
#    'abbreviation': 'alien_crush',
#    'weblink': 'https://www.speedrun.com/alien_crush'},
#   {'id': '4d7nop36',
#    'names': {'international': 'Alien Crush Returns', 'japanese': None},
#    'abbreviation': 'alien_crush_returns',
#    'weblink': 'https://www.speedrun.com/alien_crush_returns'},
#   {'id': 'k6qwj506',
#    'names': {'international': 'Alien Destroyer', 'japanese': None},
#    'abbreviation': 'alien_destroyer',
#    'weblink': 'https://www.speedrun.com/alien_destroyer'},
#   {'id': '9d38oew1',
#    'names': {'international': 'Alien DS', 'japanese': None},
#    'abbreviation': 'alien_ds',
#    'weblink': 'https://www.speedrun.com/alien_ds'},
#   {'id': '4d79qnz1',
#    'names': {'international': 'Alien Escape', 'japanese': None},
#    'abbreviation': 'alien_escape',
#    'weblink': 'https://www.speedrun.com/alien_escape'},
#   {'id': 'w6j72zx6',
#    'names': {'international': 'Alien Front', 'japanese': None},
#    'abbreviation': 'alien_front',
#    'weblink': 'https://www.speedrun.com/alien_front'},
#   {'id': '268e94o6',
#    'names': {'international': 'Alien Harvest', 'japanese': None},
#    'abbreviation': 'alien_harvest',
#    'weblink': 'https://www.speedrun.com/alien_harvest'},
#   {'id': 'yd40lx1e',
#    'names': {'international': 'Alien Hominid', 'japanese': None},
#    'abbreviation': 'ah',
#    'weblink': 'https://www.speedrun.com/ah'},
#   {'id': 'yd4k4zp6',
#    'names': {'international': 'Alien Hominid (Flash)', 'japanese': None},
#    'abbreviation': 'ahflash',
#    'weblink': 'https://www.speedrun.com/ahflash'},
#   {'id': 'y655ln06',
#    'names': {'international': 'Alien Hominid Invasion Beta Build',
#     'japanese': None},
#    'abbreviation': 'alien_hominid_invasion_beta_build',
#    'weblink': 'https://www.speedrun.com/alien_hominid_invasion_beta_build'},
#   {'id': '46w2jxq6',
#    'names': {'international': 'Alien Invasion', 'japanese': None},
#    'abbreviation': 'alien_invasion',
#    'weblink': 'https://www.speedrun.com/alien_invasion'},
#   {'id': '76r3eev6',
#    'names': {'international': 'Alien Olympics 2044 AD', 'japanese': None},
#    'abbreviation': 'alien_olympics_2044_ad',
#    'weblink': 'https://www.speedrun.com/alien_olympics_2044_ad'},
#   {'id': 'v1pr8p68',
#    'names': {'international': 'Alien Rage', 'japanese': None},
#    'abbreviation': 'alienrage',
#    'weblink': 'https://www.speedrun.com/alienrage'},
#   {'id': 'm1zj5z36',
#    'names': {'international': 'Alien Shooter', 'japanese': None},
#    'abbreviation': 'alien_shooter',
#    'weblink': 'https://www.speedrun.com/alien_shooter'},
#   {'id': '9d3rke0d',
#    'names': {'international': 'Alien Shooter 2: Reloaded', 'japanese': None},
#    'abbreviation': 'alien_shooter_2_reloaded',
#    'weblink': 'https://www.speedrun.com/alien_shooter_2_reloaded'},
#   {'id': 'pd0w4ew1',
#    'names': {'international': 'Alien Shooter: Fight for Life',
#     'japanese': None},
#    'abbreviation': 'alien_shooter_fight_for_life',
#    'weblink': 'https://www.speedrun.com/alien_shooter_fight_for_life'},
#   {'id': '369p5r81',
#    'names': {'international': 'Alien Shooter: Revisited', 'japanese': None},
#    'abbreviation': 'alien_shooter_revisited',
#    'weblink': 'https://www.speedrun.com/alien_shooter_revisited'},
#   {'id': 'j1ll8e41',
#    'names': {'international': 'Alien Shooter: The Experiment',
#     'japanese': None},
#    'abbreviation': 'alien_shooter_the_experiment',
#    'weblink': 'https://www.speedrun.com/alien_shooter_the_experiment'},
#   {'id': 'o1y9pm26',
#    'names': {'international': 'Alien Sky', 'japanese': None},
#    'abbreviation': 'alien_sky',
#    'weblink': 'https://www.speedrun.com/alien_sky'},
#   {'id': 'kdklpg6m',
#    'names': {'international': 'Alien Soldier', 'japanese': 'エイリアンソルジャー'},
#    'abbreviation': 'alien_soldier',
#    'weblink': 'https://www.speedrun.com/alien_soldier'},
#   {'id': '268eoq56',
#    'names': {'international': 'Alien Spidy', 'japanese': None},
#    'abbreviation': 'alien_spidy',
#    'weblink': 'https://www.speedrun.com/alien_spidy'},
#   {'id': 'kdkxjq6m',
#    'names': {'international': 'Alien Splatter Redux', 'japanese': None},
#    'abbreviation': 'alien_splatter_redux',
#    'weblink': 'https://www.speedrun.com/alien_splatter_redux'},
#   {'id': 'j1nep8l1',
#    'names': {'international': 'Alien Storm', 'japanese': None},
#    'abbreviation': 'alien_storm',
#    'weblink': 'https://www.speedrun.com/alien_storm'},
#   {'id': 'w6j775x6',
#    'names': {'international': 'Alien Storm (Genesis/Mega Drive)',
#     'japanese': None},
#    'abbreviation': 'alien_storm_genesismega_drive',
#    'weblink': 'https://www.speedrun.com/alien_storm_genesismega_drive'},
#   {'id': 'j1lqqze6',
#    'names': {'international': 'Alien Storm (Master System)', 'japanese': None},
#    'abbreviation': 'alien_storm_master_system',
#    'weblink': 'https://www.speedrun.com/alien_storm_master_system'},
#   {'id': '9d37jw6l',
#    'names': {'international': 'Alien Swarm', 'japanese': None},
#    'abbreviation': 'alienswarm',
#    'weblink': 'https://www.speedrun.com/alienswarm'},
#   {'id': '9dommk6p',
#    'names': {'international': 'Alien Swarm: Reactive Drop', 'japanese': None},
#    'abbreviation': 'alien_swarm_reactive_drop',
#    'weblink': 'https://www.speedrun.com/alien_swarm_reactive_drop'},
#   {'id': 'nd28qn5d',
#    'names': {'international': 'ALIEN SYNDROME', 'japanese': None},
#    'abbreviation': 'alien_syndrome',
#    'weblink': 'https://www.speedrun.com/alien_syndrome'},
#   {'id': 'yd4vxpde',
#    'names': {'international': 'Alien Syndrome (NES)', 'japanese': None},
#    'abbreviation': 'aliensyndrome',
#    'weblink': 'https://www.speedrun.com/aliensyndrome'},
#   {'id': 'm1zo7xd0',
#    'names': {'international': 'Alien Syndrome (PS2)',
#     'japanese': 'エイリアンシンドローム (PS2)'},
#    'abbreviation': 'alien_syndrome_ps2',
#    'weblink': 'https://www.speedrun.com/alien_syndrome_ps2'},
#   {'id': 'pd05021e',
#    'names': {'international': 'Alien Syndrome (SMS)', 'japanese': None},
#    'abbreviation': 'alien_syndrome_sms',
#    'weblink': 'https://www.speedrun.com/alien_syndrome_sms'},
#   {'id': 'j1l9me1g',
#    'names': {'international': 'Alien Trilogy', 'japanese': None},
#    'abbreviation': 'alien_trilogy',
#    'weblink': 'https://www.speedrun.com/alien_trilogy'},
#   {'id': '46wjw7dr',
#    'names': {'international': 'Alien Vs Predator (Arcade)', 'japanese': None},
#    'abbreviation': 'avparcade',
#    'weblink': 'https://www.speedrun.com/avparcade'},
#   {'id': 'k6q7m9dg',
#    'names': {'international': 'Alien vs Predator (Jaguar)', 'japanese': None},
#    'abbreviation': 'alien_vs_predator_jaguar',
#    'weblink': 'https://www.speedrun.com/alien_vs_predator_jaguar'},
#   {'id': 'kdkl3q6m',
#    'names': {'international': 'Alien vs Predator: The Last of His Clan',
#     'japanese': None},
#    'abbreviation': 'alien_vs_predator_the_last_of_his_clan',
#    'weblink': 'https://www.speedrun.com/alien_vs_predator_the_last_of_his_clan'},
#   {'id': 'o1y99526',
#    'names': {'international': 'Alien vs. Predator (SNES)', 'japanese': None},
#    'abbreviation': 'alien_vs_predator_snes',
#    'weblink': 'https://www.speedrun.com/alien_vs_predator_snes'},
#   {'id': 'yd49m51e',
#    'names': {'international': 'Alien vs. Predator 2 2D: Requiem',
#     'japanese': None},
#    'abbreviation': 'alien_vs._predator_2_2d_requiem',
#    'weblink': 'https://www.speedrun.com/alien_vs._predator_2_2d_requiem'},
#   {'id': 'j1nv2w6p',
#    'names': {'international': 'Alien vs. Predator 2 Arcade (PS2/Fangame)',
#     'japanese': None},
#    'abbreviation': 'avp2aps2',
#    'weblink': 'https://www.speedrun.com/avp2aps2'},
#   {'id': '3dx4jv6y',
#    'names': {'international': 'Alien vs. Predator 3D', 'japanese': None},
#    'abbreviation': 'alien_vs._predator_3d',
#    'weblink': 'https://www.speedrun.com/alien_vs._predator_3d'},
#   {'id': '76r3yp56',
#    'names': {'international': "Alien's Return", 'japanese': None},
#    'abbreviation': 'aliens_return',
#    'weblink': 'https://www.speedrun.com/aliens_return'},
#   {'id': 'kdkqxgdm',
#    'names': {'international': 'Alien: Isolation',
#     'japanese': 'エイリアン アイソレーション'},
#    'abbreviation': 'ai',
#    'weblink': 'https://www.speedrun.com/ai'},
#   {'id': '3dx2rr51',
#    'names': {'international': 'Alien: Isolation Category Extensions',
#     'japanese': None},
#    'abbreviation': 'aimeme',
#    'weblink': 'https://www.speedrun.com/aimeme'},
#   {'id': 'o1yx226q',
#    'names': {'international': 'Alien: Resurrection', 'japanese': None},
#    'abbreviation': 'alien_resurrection',
#    'weblink': 'https://www.speedrun.com/alien_resurrection'},
#   {'id': 'm1zjxz26',
#    'names': {'international': 'Alienation', 'japanese': None},
#    'abbreviation': 'alienation',
#    'weblink': 'https://www.speedrun.com/alienation'},
#   {'id': 'pdvzm0r6',
#    'names': {'international': 'Alienators: Evolution Continues',
#     'japanese': None},
#    'abbreviation': 'alienators_evolution_continues',
#    'weblink': 'https://www.speedrun.com/alienators_evolution_continues'},
#   {'id': 'm1zj0g06',
#    'names': {'international': 'Aliens (1990 Arcade)', 'japanese': None},
#    'abbreviation': 'aliens_konami',
#    'weblink': 'https://www.speedrun.com/aliens_konami'},
#   {'id': '4d7n2wr6',
#    'names': {'international': 'Aliens After Ava', 'japanese': None},
#    'abbreviation': 'aliens_after_ava',
#    'weblink': 'https://www.speedrun.com/aliens_after_ava'},
#   {'id': 'k6qw8x06',
#    'names': {'international': 'Aliens in the Attic', 'japanese': None},
#    'abbreviation': 'aliens',
#    'weblink': 'https://www.speedrun.com/aliens'},
#   {'id': '9do8poe1',
#    'names': {'international': 'Aliens in the Attic (DS)', 'japanese': None},
#    'abbreviation': 'aliens_in_the_attic_ds',
#    'weblink': 'https://www.speedrun.com/aliens_in_the_attic_ds'},
#   {'id': 'xkdkngdm',
#    'names': {'international': 'Aliens versus Predator', 'japanese': None},
#    'abbreviation': 'avp',
#    'weblink': 'https://www.speedrun.com/avp'},
#   {'id': 'o1y4541q',
#    'names': {'international': 'Aliens versus Predator 2', 'japanese': None},
#    'abbreviation': 'avp2',
#    'weblink': 'https://www.speedrun.com/avp2'},
#   {'id': 'yd4kjgx6',
#    'names': {'international': 'Aliens versus Predator 2 Custom Maps',
#     'japanese': None},
#    'abbreviation': 'aliens_versus_predator_2_custom_maps',
#    'weblink': 'https://www.speedrun.com/aliens_versus_predator_2_custom_maps'},
#   {'id': '9dozo31p',
#    'names': {'international': 'Aliens versus Predator 2: Primal Hunt',
#     'japanese': None},
#    'abbreviation': 'aliens_versus_predator_2_primal_hunt',
#    'weblink': 'https://www.speedrun.com/aliens_versus_predator_2_primal_hunt'},
#   {'id': 'k6qyq9dg',
#    'names': {'international': 'Aliens Versus Predator: Extinction',
#     'japanese': None},
#    'abbreviation': 'avpe',
#    'weblink': 'https://www.speedrun.com/avpe'},
#   {'id': '3698geld',
#    'names': {'international': 'Aliens vs Ghosts', 'japanese': None},
#    'abbreviation': 'aliens_vs_ghosts',
#    'weblink': 'https://www.speedrun.com/aliens_vs_ghosts'},
#   {'id': 'w6jl04dj',
#    'names': {'international': 'Aliens Vs. Predator (2010)', 'japanese': None},
#    'abbreviation': 'avp2010',
#    'weblink': 'https://www.speedrun.com/avp2010'},
#   {'id': '9do5go1p',
#    'names': {'international': 'Aliens vs. Predator: Requiem',
#     'japanese': 'プレデターレクイエム対エイリアン'},
#    'abbreviation': 'avpr',
#    'weblink': 'https://www.speedrun.com/avpr'},
#   {'id': '9d3rp5yd',
#    'names': {'international': 'Aliens: Alien 2 (FDS)', 'japanese': None},
#    'abbreviation': 'aliens_fds',
#    'weblink': 'https://www.speedrun.com/aliens_fds'},
#   {'id': '3698qvgd',
#    'names': {'international': 'Aliens: Alien 2 (MSX)', 'japanese': None},
#    'abbreviation': 'aliens_alien_2_msx',
#    'weblink': 'https://www.speedrun.com/aliens_alien_2_msx'},
#   {'id': 'y65r4r41',
#    'names': {'international': 'Aliens: Armageddon', 'japanese': None},
#    'abbreviation': 'Aliens_Armageddon',
#    'weblink': 'https://www.speedrun.com/Aliens_Armageddon'},
#   {'id': 'pd0l2lde',
#    'names': {'international': 'Aliens: Colonial Marines', 'japanese': None},
#    'abbreviation': 'acm',
#    'weblink': 'https://www.speedrun.com/acm'},
#   {'id': '76r4xv51',
#    'names': {'international': 'Aliens: Dark Descent', 'japanese': None},
#    'abbreviation': 'Aliens_Dark_Descent',
#    'weblink': 'https://www.speedrun.com/Aliens_Dark_Descent'},
#   {'id': '3dxyj9y6',
#    'names': {'international': 'Aliens: Extermination', 'japanese': None},
#    'abbreviation': 'Aliens_Extermination',
#    'weblink': 'https://www.speedrun.com/Aliens_Extermination'},
#   {'id': '9d3879e1',
#    'names': {'international': 'Aliens: Fireteam Elite', 'japanese': None},
#    'abbreviation': 'aliens_fireteam_elite',
#    'weblink': 'https://www.speedrun.com/aliens_fireteam_elite'},
#   {'id': '4d79qqr1',
#    'names': {'international': 'Aliens: Neoplasma', 'japanese': None},
#    'abbreviation': 'aliens_neoplasma',
#    'weblink': 'https://www.speedrun.com/aliens_neoplasma'},
#   {'id': 'j1n8wgx1',
#    'names': {'international': 'Alina of the Arena', 'japanese': None},
#    'abbreviation': 'alina_of_the_arena',
#    'weblink': 'https://www.speedrun.com/alina_of_the_arena'},
#   {'id': 'pdvzm996',
#    'names': {'international': 'ALINE', 'japanese': None},
#    'abbreviation': 'aline',
#    'weblink': 'https://www.speedrun.com/aline'},
#   {'id': 'y655m306',
#    'names': {'international': 'Alipache in Wonderworld', 'japanese': None},
#    'abbreviation': 'alipache_in_wonderworld',
#    'weblink': 'https://www.speedrun.com/alipache_in_wonderworld'},
#   {'id': '3dxk02y1',
#    'names': {'international': 'Alisa', 'japanese': None},
#    'abbreviation': 'alisa',
#    'weblink': 'https://www.speedrun.com/alisa'},
#   {'id': '2682056p',
#    'names': {'international': 'Alisia Dragoon', 'japanese': 'アリシアドラグーン'},
#    'abbreviation': 'alisia_dragoon',
#    'weblink': 'https://www.speedrun.com/alisia_dragoon'},
#   {'id': 'j1lq7nj6',
#    'names': {'international': 'Alkali', 'japanese': None},
#    'abbreviation': 'alkali',
#    'weblink': 'https://www.speedrun.com/alkali'},
#   {'id': 'k6q4rymd',
#    'names': {'international': 'All Grown Up!: Express Yourself',
#     'japanese': None},
#    'abbreviation': 'rugrats_all_grown_up_express_yourself',
#    'weblink': 'https://www.speedrun.com/rugrats_all_grown_up_express_yourself'},
#   {'id': '76r3l546',
#    'names': {'international': 'All is Dust', 'japanese': None},
#    'abbreviation': 'all_is_dust',
#    'weblink': 'https://www.speedrun.com/all_is_dust'},
#   {'id': 'v1px5rz6',
#    'names': {'international': 'All Kamen Rider: Rider Generation',
#     'japanese': None},
#    'abbreviation': 'akrrg',
#    'weblink': 'https://www.speedrun.com/akrrg'},
#   {'id': 'k6qnkx6g',
#    'names': {'international': 'All Kamen Rider: Rider Generation 2',
#     'japanese': None},
#    'abbreviation': 'all_kamen_rider_rider_generation_2',
#    'weblink': 'https://www.speedrun.com/all_kamen_rider_rider_generation_2'},
#   {'id': 'm1z49z60',
#    'names': {'international': 'All Night Nippon Super Mario Bros.',
#     'japanese': 'オールナイトニッポン スーパーマリオブラザーズ'},
#    'abbreviation': 'annsmb',
#    'weblink': 'https://www.speedrun.com/annsmb'},
#   {'id': 'o1y98kv6',
#    'names': {'international': 'All Our Asias', 'japanese': None},
#    'abbreviation': 'all_our_asias',
#    'weblink': 'https://www.speedrun.com/all_our_asias'},
#   {'id': 'ldejvmn1',
#    'names': {'international': 'All She Wants For Christmas Is You',
#     'japanese': None},
#    'abbreviation': 'all_she_wants_for_christmas_is_you',
#    'weblink': 'https://www.speedrun.com/all_she_wants_for_christmas_is_you'},
#   {'id': 'nd2e2mrd',
#    'names': {'international': 'All Star Adventure', 'japanese': None},
#    'abbreviation': 'all_star_adventure',
#    'weblink': 'https://www.speedrun.com/all_star_adventure'},
#   {'id': 'nd287rvd',
#    'names': {'international': 'All Star Tennis 99', 'japanese': None},
#    'abbreviation': 'all_star_tennis_99',
#    'weblink': 'https://www.speedrun.com/all_star_tennis_99'},
#   {'id': 'k6q4lp0d',
#    'names': {'international': "All That's Left", 'japanese': None},
#    'abbreviation': 'all_thats_left',
#    'weblink': 'https://www.speedrun.com/all_thats_left'},
#   {'id': '3dxkegp1',
#    'names': {'international': 'All-Pro Basketball', 'japanese': None},
#    'abbreviation': 'all_pro_basketball',
#    'weblink': 'https://www.speedrun.com/all_pro_basketball'},
#   {'id': 'kdkmqvx1',
#    'names': {'international': 'All-Star Baseball 2000', 'japanese': None},
#    'abbreviation': 'allstar_baseball_2000',
#    'weblink': 'https://www.speedrun.com/allstar_baseball_2000'},
#   {'id': '369p0581',
#    'names': {'international': 'All-Star Fighters', 'japanese': None},
#    'abbreviation': 'all-star_fighters',
#    'weblink': 'https://www.speedrun.com/all-star_fighters'},
#   {'id': '46w35mq1',
#    'names': {'international': 'All-Star Fruit Racing', 'japanese': None},
#    'abbreviation': 'all-star_fruit_racing',
#    'weblink': 'https://www.speedrun.com/all-star_fruit_racing'},
#   {'id': 'ldevye13',
#    'names': {'international': 'Alley Cat', 'japanese': None},
#    'abbreviation': 'alleycat',
#    'weblink': 'https://www.speedrun.com/alleycat'},
#   {'id': 'm1mxn9k6',
#    'names': {'international': 'Alleyway', 'japanese': None},
#    'abbreviation': 'alleyway',
#    'weblink': 'https://www.speedrun.com/alleyway'},
#   {'id': 'ldejo8x1',
#    'names': {'international': 'Alligator Hunt', 'japanese': None},
#    'abbreviation': 'alligator_hunt',
#    'weblink': 'https://www.speedrun.com/alligator_hunt'},
#   {'id': 'o1yjrv41',
#    'names': {'international': 'allocation ', 'japanese': None},
#    'abbreviation': 'allocation',
#    'weblink': 'https://www.speedrun.com/allocation'},
#   {'id': 'm1zkmo21',
#    'names': {'international': 'Allrams höjdarspel', 'japanese': None},
#    'abbreviation': 'allrams_hojdarspel',
#    'weblink': 'https://www.speedrun.com/allrams_hojdarspel'},
#   {'id': 'nd2829vd',
#    'names': {'international': 'ALLTYNEX Second', 'japanese': None},
#    'abbreviation': 'alltynex_second',
#    'weblink': 'https://www.speedrun.com/alltynex_second'},
#   {'id': 'm1zj7w06',
#    'names': {'international': 'Alluris', 'japanese': None},
#    'abbreviation': 'alluris',
#    'weblink': 'https://www.speedrun.com/alluris'},
#   {'id': 'nd27k3r1',
#    'names': {'international': 'ALMOST', 'japanese': None},
#    'abbreviation': 'almost',
#    'weblink': 'https://www.speedrun.com/almost'},
#   {'id': '268e2ro6',
#    'names': {'international': 'Almost a Hero', 'japanese': None},
#    'abbreviation': 'almost_a_hero',
#    'weblink': 'https://www.speedrun.com/almost_a_hero'},
#   {'id': 'w6jlqged',
#    'names': {'international': 'Almost There: The Platformer',
#     'japanese': None},
#    'abbreviation': 'almost_there',
#    'weblink': 'https://www.speedrun.com/almost_there'},
#   {'id': 'm1zklqx1',
#    'names': {'international': 'Aloft', 'japanese': None},
#    'abbreviation': 'aloft',
#    'weblink': 'https://www.speedrun.com/aloft'},
#   {'id': 'pd0q0831',
#    'names': {'international': 'Aloft (Astrolabe)', 'japanese': None},
#    'abbreviation': 'aloftdemo',
#    'weblink': 'https://www.speedrun.com/aloftdemo'},
#   {'id': 'pd0w7wl1',
#    'names': {'international': 'Alone (PC)', 'japanese': None},
#    'abbreviation': 'alone_pc',
#    'weblink': 'https://www.speedrun.com/alone_pc'},
#   {'id': '46w2go96',
#    'names': {'international': 'Alone in Pico', 'japanese': None},
#    'abbreviation': 'alone_in_pico',
#    'weblink': 'https://www.speedrun.com/alone_in_pico'},
#   {'id': 'kdkex2dm',
#    'names': {'international': 'Alone In The Dark', 'japanese': None},
#    'abbreviation': 'aitd1',
#    'weblink': 'https://www.speedrun.com/aitd1'},
#   {'id': 'j1nm0x6p',
#    'names': {'international': 'Alone In The Dark (2008)', 'japanese': None},
#    'abbreviation': 'aitd2008',
#    'weblink': 'https://www.speedrun.com/aitd2008'},
#   {'id': 'k6qr301g',
#    'names': {'international': 'Alone In The Dark 2', 'japanese': None},
#    'abbreviation': 'aitd2',
#    'weblink': 'https://www.speedrun.com/aitd2'},
#   {'id': 'kdkepqdm',
#    'names': {'international': 'Alone In The Dark 3 / Alone In The Dark: Ghosts In Town',
#     'japanese': None},
#    'abbreviation': 'aitd3',
#    'weblink': 'https://www.speedrun.com/aitd3'},
#   {'id': 'w6jnm41j',
#    'names': {'international': 'Alone In The Dark: The New Nightmare',
#     'japanese': None},
#    'abbreviation': 'aitdtnn',
#    'weblink': 'https://www.speedrun.com/aitdtnn'},
#   {'id': 'j1lql7v6',
#    'names': {'international': 'ALONE?', 'japanese': None},
#    'abbreviation': 'alone',
#    'weblink': 'https://www.speedrun.com/alone'},
#   {'id': '3dxkr41y',
#    'names': {'international': "Along with Kochiya Sanae's Kamikaze",
#     'japanese': '東風谷早苗の神風とともに'},
#    'abbreviation': 'along_with_kochiya_sanaes_kamikaze',
#    'weblink': 'https://www.speedrun.com/along_with_kochiya_sanaes_kamikaze'},
#   {'id': 'kdkz50gd',
#    'names': {'international': 'Alosha Popovich i Tugarin Zmey',
#     'japanese': None},
#    'abbreviation': 'alyosha_popovich_i_tugarin_zmey',
#    'weblink': 'https://www.speedrun.com/alyosha_popovich_i_tugarin_zmey'},
#   {'id': '76r34p46',
#    'names': {'international': 'Alpaca Stacka', 'japanese': None},
#    'abbreviation': 'alpaca_stacka',
#    'weblink': 'https://www.speedrun.com/alpaca_stacka'},
#   {'id': 'ldejvlj1',
#    'names': {'international': 'Alpacalypse', 'japanese': None},
#    'abbreviation': 'alpacalypse',
#    'weblink': 'https://www.speedrun.com/alpacalypse'},
#   {'id': '3698n8ld',
#    'names': {'international': 'Alpen Ghoul', 'japanese': None},
#    'abbreviation': 'alpen_ghoul',
#    'weblink': 'https://www.speedrun.com/alpen_ghoul'},
#   {'id': 'ldejoqj1',
#    'names': {'international': 'Alpha Ace', 'japanese': None},
#    'abbreviation': 'alpha_ace',
#    'weblink': 'https://www.speedrun.com/alpha_ace'},
#   {'id': '9d3w8o01',
#    'names': {'international': 'Alpha Beam with Ernie', 'japanese': None},
#    'abbreviation': 'Alpha_Beam_with_Ernie',
#    'weblink': 'https://www.speedrun.com/Alpha_Beam_with_Ernie'},
#   {'id': '9doe3m1p',
#    'names': {'international': 'Alpha Force', 'japanese': None},
#    'abbreviation': 'alpha_force',
#    'weblink': 'https://www.speedrun.com/alpha_force'},
#   {'id': 'k6qpmood',
#    'names': {'international': 'Alpha Mission (NES)', 'japanese': None},
#    'abbreviation': 'alpha_mission_nes',
#    'weblink': 'https://www.speedrun.com/alpha_mission_nes'},
#   {'id': 'yd4k43x6',
#    'names': {'international': 'Alpha Mission 2', 'japanese': None},
#    'abbreviation': 'alpha_mission_2',
#    'weblink': 'https://www.speedrun.com/alpha_mission_2'},
#   {'id': 'kdkg0l1m',
#    'names': {'international': 'Alpha Prime', 'japanese': None},
#    'abbreviation': 'alpha_prime',
#    'weblink': 'https://www.speedrun.com/alpha_prime'},
#   {'id': '9domqk6p',
#    'names': {'international': 'Alpha Protocol', 'japanese': None},
#    'abbreviation': 'alpha_protocol',
#    'weblink': 'https://www.speedrun.com/alpha_protocol'},
#   {'id': 'nd28x3qd',
#    'names': {'international': 'Alpha Twist', 'japanese': None},
#    'abbreviation': 'at',
#    'weblink': 'https://www.speedrun.com/at'},
#   {'id': 'pd08o31e',
#    'names': {'international': 'Alpha Zylon', 'japanese': None},
#    'abbreviation': 'az',
#    'weblink': 'https://www.speedrun.com/az'},
#   {'id': 'y654py3d',
#    'names': {'international': 'Alphabet Park Adventure', 'japanese': None},
#    'abbreviation': 'alphabet_park_adventure',
#    'weblink': 'https://www.speedrun.com/alphabet_park_adventure'},
#   {'id': 'ldejyyj1',
#    'names': {'international': 'Alphabet Zoo', 'japanese': None},
#    'abbreviation': 'alphabet_zoo',
#    'weblink': 'https://www.speedrun.com/alphabet_zoo'},
#   {'id': '3698ex0d',
#    'names': {'international': 'Alphape', 'japanese': None},
#    'abbreviation': 'alphape',
#    'weblink': 'https://www.speedrun.com/alphape'},
#   {'id': '76r355v6',
#    'names': {'international': 'Alpine Ascent', 'japanese': None},
#    'abbreviation': 'alpine_ascent',
#    'weblink': 'https://www.speedrun.com/alpine_ascent'},
#   {'id': 'j1n87891',
#    'names': {'international': 'Alpine Racer 3', 'japanese': None},
#    'abbreviation': 'alpine_racer_3',
#    'weblink': 'https://www.speedrun.com/alpine_racer_3'},
#   {'id': 'j1neg8l1',
#    'names': {'international': 'Alpiner', 'japanese': None},
#    'abbreviation': 'alpiner',
#    'weblink': 'https://www.speedrun.com/alpiner'},
#   {'id': 'o6glmqnd',
#    'names': {'international': 'Alshark', 'japanese': None},
#    'abbreviation': 'alshark',
#    'weblink': 'https://www.speedrun.com/alshark'},
#   {'id': '369p4z81',
#    'names': {'international': 'Alter', 'japanese': None},
#    'abbreviation': 'alter',
#    'weblink': 'https://www.speedrun.com/alter'},
#   {'id': 'm1zrq2d0',
#    'names': {'international': 'Alter Ego', 'japanese': None},
#    'abbreviation': 'alter_ego',
#    'weblink': 'https://www.speedrun.com/alter_ego'},
#   {'id': 'yd437x1e',
#    'names': {'international': 'Altered Beast', 'japanese': None},
#    'abbreviation': 'altered_beast',
#    'weblink': 'https://www.speedrun.com/altered_beast'},
#   {'id': 'v1pkvmd8',
#    'names': {'international': 'Altered Space', 'japanese': None},
#    'abbreviation': 'altered_space',
#    'weblink': 'https://www.speedrun.com/altered_space'},
#   {'id': '9d383lg1',
#    'names': {'international': 'AltF4', 'japanese': None},
#    'abbreviation': 'altf4',
#    'weblink': 'https://www.speedrun.com/altf4'},
#   {'id': 'pdv2oyo6',
#    'names': {'international': 'ALTF42', 'japanese': None},
#    'abbreviation': 'altf42',
#    'weblink': 'https://www.speedrun.com/altf42'},
#   {'id': 'lde3yve6',
#    'names': {'international': 'AltF4Space', 'japanese': None},
#    'abbreviation': 'altf4space',
#    'weblink': 'https://www.speedrun.com/altf4space'},
#   {'id': 'j1n4eyy6',
#    'names': {'international': 'Altitorture', 'japanese': None},
#    'abbreviation': 'Altitorture',
#    'weblink': 'https://www.speedrun.com/Altitorture'},
#   {'id': 'm1zj3w26',
#    'names': {'international': "Alto's Adventure", 'japanese': None},
#    'abbreviation': 'alto',
#    'weblink': 'https://www.speedrun.com/alto'},
#   {'id': 'lde3men6',
#    'names': {'international': 'Alto’s Odyssey', 'japanese': None},
#    'abbreviation': 'altos_odyssey',
#    'weblink': 'https://www.speedrun.com/altos_odyssey'},
#   {'id': 'j1neo0e1',
#    'names': {'international': 'Alucinod', 'japanese': None},
#    'abbreviation': 'alucinod',
#    'weblink': 'https://www.speedrun.com/alucinod'},
#   {'id': 'y655g386',
#    'names': {'international': 'ALUMNI - Escape Room Adventure',
#     'japanese': None},
#    'abbreviation': 'alumni',
#    'weblink': 'https://www.speedrun.com/alumni'},
#   {'id': 'o6gw4512',
#    'names': {'international': 'Alundra', 'japanese': None},
#    'abbreviation': 'alundra',
#    'weblink': 'https://www.speedrun.com/alundra'},
#   {'id': 'pd02j01e',
#    'names': {'international': 'Alundra 2', 'japanese': None},
#    'abbreviation': 'alundra2',
#    'weblink': 'https://www.speedrun.com/alundra2'},
#   {'id': '9d3rmpyd',
#    'names': {'international': 'Alvin and the Chipmunks', 'japanese': None},
#    'abbreviation': 'aatc',
#    'weblink': 'https://www.speedrun.com/aatc'},
#   {'id': 'k6q4x39d',
#    'names': {'international': 'Alvin and the Chipmunks: Chipwrecked',
#     'japanese': None},
#    'abbreviation': 'aatc3',
#    'weblink': 'https://www.speedrun.com/aatc3'},
#   {'id': 'pdvzlyk6',
#    'names': {'international': 'Alvin and the Chipmunks: The Squeakquel',
#     'japanese': None},
#    'abbreviation': 'aatc2',
#    'weblink': 'https://www.speedrun.com/aatc2'},
#   {'id': '4d7x9m31',
#    'names': {'international': 'Alvin and the DEATHMUNKS', 'japanese': None},
#    'abbreviation': 'Alvin_and_the_DEATHMUNKS',
#    'weblink': 'https://www.speedrun.com/Alvin_and_the_DEATHMUNKS'},
#   {'id': 'pd0kk31e',
#    'names': {'international': "Alwa's Awakening", 'japanese': None},
#    'abbreviation': 'alwa',
#    'weblink': 'https://www.speedrun.com/alwa'},
#   {'id': 'yd4kn2w6',
#    'names': {'international': "Alwa's Awakening (NES)", 'japanese': None},
#    'abbreviation': 'alwas_awakening_nes',
#    'weblink': 'https://www.speedrun.com/alwas_awakening_nes'},
#   {'id': 'pdvzwxo6',
#    'names': {'international': "Alwa's Legacy", 'japanese': None},
#    'abbreviation': 'alwas_legacy',
#    'weblink': 'https://www.speedrun.com/alwas_legacy'},
#   {'id': '4d79l031',
#    'names': {'international': "Alyssa's Unlikely Trap", 'japanese': None},
#    'abbreviation': 'aut',
#    'weblink': 'https://www.speedrun.com/aut'},
#   {'id': 'kdkmqng1',
#    'names': {'international': 'Am Universe: Art Death', 'japanese': None},
#    'abbreviation': 'am_universe_art_death',
#    'weblink': 'https://www.speedrun.com/am_universe_art_death'},
#   {'id': 'nd2elpvd',
#    'names': {'international': 'AM2R Category Extensions', 'japanese': None},
#    'abbreviation': 'am2r_category_extensions',
#    'weblink': 'https://www.speedrun.com/am2r_category_extensions'},
#   {'id': 'nd28jrd0',
#    'names': {'international': 'Amagon', 'japanese': None},
#    'abbreviation': 'amagon',
#    'weblink': 'https://www.speedrun.com/amagon'},
#   {'id': 'o6gnyy81',
#    'names': {'international': 'Amanda the Adventurer', 'japanese': None},
#    'abbreviation': 'amanda_the_adventurer',
#    'weblink': 'https://www.speedrun.com/amanda_the_adventurer'},
#   {'id': '46w2qyq6',
#    'names': {'international': 'Amanda: the adventure 2.0.0', 'japanese': None},
#    'abbreviation': 'amanda_the_adventure',
#    'weblink': 'https://www.speedrun.com/amanda_the_adventure'},
#   {'id': '369572dl',
#    'names': {'international': 'Amapani!', 'japanese': 'あまぱに！'},
#    'abbreviation': 'amapani',
#    'weblink': 'https://www.speedrun.com/amapani'},
#   {'id': 'm1zkzp01',
#    'names': {'international': 'Amateur Surgeon', 'japanese': None},
#    'abbreviation': 'amateur_surgeon',
#    'weblink': 'https://www.speedrun.com/amateur_surgeon'},
#   {'id': '3698rj0d',
#    'names': {'international': 'Amateur Surgeon 2', 'japanese': None},
#    'abbreviation': 'amateur_surgeon_2',
#    'weblink': 'https://www.speedrun.com/amateur_surgeon_2'},
#   {'id': 'j1nepvw1',
#    'names': {'international': 'aMAZE', 'japanese': None},
#    'abbreviation': 'amaze',
#    'weblink': 'https://www.speedrun.com/amaze'},
#   {'id': '3dx2z4g1',
#    'names': {'international': 'aMAZE 2', 'japanese': None},
#    'abbreviation': 'amaze2',
#    'weblink': 'https://www.speedrun.com/amaze2'},
#   {'id': 'v1pop4m6',
#    'names': {'international': 'aMAZE 3D', 'japanese': None},
#    'abbreviation': 'amaze3d',
#    'weblink': 'https://www.speedrun.com/amaze3d'},
#   {'id': '3dx2l2g1',
#    'names': {'international': 'aMAZE ABC', 'japanese': None},
#    'abbreviation': 'amaze_abc',
#    'weblink': 'https://www.speedrun.com/amaze_abc'},
#   {'id': 'm1mx0036',
#    'names': {'international': 'aMAZE Christmas', 'japanese': None},
#    'abbreviation': 'amazexmas',
#    'weblink': 'https://www.speedrun.com/amazexmas'},
#   {'id': '9d3r74yd',
#    'names': {'international': 'aMAZE Classic', 'japanese': None},
#    'abbreviation': 'amaze_classic',
#    'weblink': 'https://www.speedrun.com/amaze_classic'},
#   {'id': 'v1poyxm6',
#    'names': {'international': 'aMAZE Classic: Inverted', 'japanese': None},
#    'abbreviation': 'amaze_classic_inverted',
#    'weblink': 'https://www.speedrun.com/amaze_classic_inverted'},
#   {'id': '46w3j031',
#    'names': {'international': 'aMAZE Dark Times', 'japanese': None},
#    'abbreviation': 'amazedt',
#    'weblink': 'https://www.speedrun.com/amazedt'},
#   {'id': 'o6glw2nd',
#    'names': {'international': 'aMAZE Double', 'japanese': None},
#    'abbreviation': 'amazedbl',
#    'weblink': 'https://www.speedrun.com/amazedbl'},
#   {'id': '268enn96',
#    'names': {'international': 'aMAZE Easter', 'japanese': None},
#    'abbreviation': 'amaze_easter',
#    'weblink': 'https://www.speedrun.com/amaze_easter'},
#   {'id': '76rx9p46',
#    'names': {'international': 'aMAZE Frozen', 'japanese': None},
#    'abbreviation': 'amaze_frozen',
#    'weblink': 'https://www.speedrun.com/amaze_frozen'},
#   {'id': 'j1ll7e71',
#    'names': {'international': 'aMAZE Gears', 'japanese': None},
#    'abbreviation': 'amazegear',
#    'weblink': 'https://www.speedrun.com/amazegear'},
#   {'id': '46w3gv91',
# ...
#   {'id': 'j1n84ee1',
#    'names': {'international': 'Asphalt 4: Elite racing', 'japanese': None},
#    'abbreviation': 'asphalt_4_elite_racing',
#    'weblink': 'https://www.speedrun.com/asphalt_4_elite_racing'},
#   {'id': 'ldejx5e1',
#    'names': {'international': 'Asphalt 5', 'japanese': None},
#    'abbreviation': 'asphalt_5',
#    'weblink': 'https://www.speedrun.com/asphalt_5'},
#   {'id': '46w227q6',
#    'names': {'international': 'Asphalt 6: Adrenaline', 'japanese': None},
#    'abbreviation': 'asphalt_6_adrenaline',
#    'weblink': 'https://www.speedrun.com/asphalt_6_adrenaline'},
#   {'id': 'o6gn3w81',
#    'names': {'international': 'Asphalt 7: Heat', 'japanese': None},
#    'abbreviation': 'asphalt_7_heat',
#    'weblink': 'https://www.speedrun.com/asphalt_7_heat'},
#   {'id': '76rx9jv6',
#    'names': {'international': 'Asphalt 8: Airborne', 'japanese': None},
#    'abbreviation': 'asphalt_8_airborne',
#    'weblink': 'https://www.speedrun.com/asphalt_8_airborne'},
#   {'id': 'kdkz8l2d',
#    'names': {'international': 'Asphalt 9: Legends', 'japanese': None},
#    'abbreviation': 'a9l',
#    'weblink': 'https://www.speedrun.com/a9l'},
#   {'id': 'm1mnmppd',
#    'names': {'international': 'Asphalt nitro', 'japanese': None},
#    'abbreviation': 'asphalt_nitro',
#    'weblink': 'https://www.speedrun.com/asphalt_nitro'},
#   {'id': 'w6j7ewe6',
#    'names': {'international': 'Asphalt nitro 2', 'japanese': None},
#    'abbreviation': 'asphalt_nitro_2',
#    'weblink': 'https://www.speedrun.com/asphalt_nitro_2'},
#   {'id': 'pdv20o96',
#    'names': {'international': 'Asphalt: Injection', 'japanese': None},
#    'abbreviation': 'asphalt_injection',
#    'weblink': 'https://www.speedrun.com/asphalt_injection'},
#   {'id': 'lde308e6',
#    'names': {'international': 'Asphalt: Urban GT 2', 'japanese': None},
#    'abbreviation': 'asphalt_urban_gt_2',
#    'weblink': 'https://www.speedrun.com/asphalt_urban_gt_2'},
#   {'id': 'o6gn7o51',
#    'names': {'international': "Aspire: Ina's Tale", 'japanese': None},
#    'abbreviation': 'aspire_inas_tale',
#    'weblink': 'https://www.speedrun.com/aspire_inas_tale'},
#   {'id': 'v1pxw868',
#    'names': {'international': "Assassin's Creed", 'japanese': None},
#    'abbreviation': 'ac1',
#    'weblink': 'https://www.speedrun.com/ac1'},
#   {'id': 'ldeyw513',
#    'names': {'international': "Assassin's Creed Bloodlines", 'japanese': None},
#    'abbreviation': 'assassins_creed_bloodlines',
#    'weblink': 'https://www.speedrun.com/assassins_creed_bloodlines'},
#   {'id': '46w55l6r',
#    'names': {'international': "Assassin's Creed Chronicles: China",
#     'japanese': None},
#    'abbreviation': 'assassins_creed_chronicles_china',
#    'weblink': 'https://www.speedrun.com/assassins_creed_chronicles_china'},
#   {'id': 'nd29w560',
#    'names': {'international': "Assassin's Creed Chronicles: India",
#     'japanese': None},
#    'abbreviation': 'assassins_creed_chronicles_india',
#    'weblink': 'https://www.speedrun.com/assassins_creed_chronicles_india'},
#   {'id': 'm1zxozd0',
#    'names': {'international': "Assassin's Creed Chronicles: Russia",
#     'japanese': None},
#    'abbreviation': 'assassins_creed_chronicles_russia',
#    'weblink': 'https://www.speedrun.com/assassins_creed_chronicles_russia'},
#   {'id': 'j1n8rx1p',
#    'names': {'international': "Assassin's Creed II", 'japanese': None},
#    'abbreviation': 'ac2',
#    'weblink': 'https://www.speedrun.com/ac2'},
#   {'id': '9do8le1p',
#    'names': {'international': "Assassin's Creed III", 'japanese': None},
#    'abbreviation': 'ac3',
#    'weblink': 'https://www.speedrun.com/ac3'},
#   {'id': '9down571',
#    'names': {'international': "Assassin's Creed III Remastered",
#     'japanese': None},
#    'abbreviation': 'ac3r',
#    'weblink': 'https://www.speedrun.com/ac3r'},
#   {'id': 'm1mngpd2',
#    'names': {'international': "Assassin's Creed IV: Black Flag",
#     'japanese': None},
#    'abbreviation': 'ac4',
#    'weblink': 'https://www.speedrun.com/ac4'},
#   {'id': 'kdk2xedm',
#    'names': {'international': "Assassin's Creed Liberation HD",
#     'japanese': None},
#    'abbreviation': 'assassins_creed_liberation_hd',
#    'weblink': 'https://www.speedrun.com/assassins_creed_liberation_hd'},
#   {'id': '46w3yo71',
#    'names': {'international': "Assassin's Creed Odyssey", 'japanese': None},
#    'abbreviation': 'acodyssey',
#    'weblink': 'https://www.speedrun.com/acodyssey'},
#   {'id': '268e3oo6',
#    'names': {'international': "Assassin's Creed Origins", 'japanese': None},
#    'abbreviation': 'acorigins',
#    'weblink': 'https://www.speedrun.com/acorigins'},
#   {'id': 'v1pvpm18',
#    'names': {'international': "Assassin's Creed Syndicate", 'japanese': None},
#    'abbreviation': 'acs',
#    'weblink': 'https://www.speedrun.com/acs'},
#   {'id': '46w3mp71',
#    'names': {'international': "Assassin's Creed Valhalla", 'japanese': None},
#    'abbreviation': 'acvalhalla',
#    'weblink': 'https://www.speedrun.com/acvalhalla'},
#   {'id': 'pdvzwwk6',
#    'names': {'international': "Assassin's Creed: Altair Chronicles",
#     'japanese': None},
#    'abbreviation': 'assassins_creed_altair_chronicles',
#    'weblink': 'https://www.speedrun.com/assassins_creed_altair_chronicles'},
#   {'id': 'ldejee13',
#    'names': {'international': "Assassin's Creed: Brotherhood",
#     'japanese': 'アサシンクリードブラザーフッド'},
#    'abbreviation': 'acb',
#    'weblink': 'https://www.speedrun.com/acb'},
#   {'id': '268w0o6p',
#    'names': {'international': "Assassin's Creed: Revelations",
#     'japanese': None},
#    'abbreviation': 'acr',
#    'weblink': 'https://www.speedrun.com/acr'},
#   {'id': '9d35391l',
#    'names': {'international': "Assassin's Creed: Rogue", 'japanese': None},
#    'abbreviation': 'acrogue',
#    'weblink': 'https://www.speedrun.com/acrogue'},
#   {'id': 'v1px0468',
#    'names': {'international': "Assassin's Creed: Unity", 'japanese': None},
#    'abbreviation': 'acu',
#    'weblink': 'https://www.speedrun.com/acu'},
#   {'id': 'nd27em31',
#    'names': {'international': 'Assault', 'japanese': None},
#    'abbreviation': 'Assault',
#    'weblink': 'https://www.speedrun.com/Assault'},
#   {'id': 'k6q0jo1g',
#    'names': {'international': 'Assault Android Cactus', 'japanese': None},
#    'abbreviation': 'aac',
#    'weblink': 'https://www.speedrun.com/aac'},
#   {'id': 'o6gegx12',
#    'names': {'international': 'Assault Android Cactus EX', 'japanese': None},
#    'abbreviation': 'aacex',
#    'weblink': 'https://www.speedrun.com/aacex'},
#   {'id': 'y654xm4d',
#    'names': {'international': 'Assault ChaingunS KM Switch', 'japanese': None},
#    'abbreviation': 'assault_chaingun_km_switch',
#    'weblink': 'https://www.speedrun.com/assault_chaingun_km_switch'},
#   {'id': 'pd0wp8w1',
#    'names': {'international': 'Assault Heroes', 'japanese': None},
#    'abbreviation': 'assault_heroes',
#    'weblink': 'https://www.speedrun.com/assault_heroes'},
#   {'id': '369pgp21',
#    'names': {'international': 'Assault Spy', 'japanese': None},
#    'abbreviation': 'assaultspy',
#    'weblink': 'https://www.speedrun.com/assaultspy'},
#   {'id': 'nd287yed',
#    'names': {'international': 'Assault Trooper', 'japanese': None},
#    'abbreviation': 'assault_trooper',
#    'weblink': 'https://www.speedrun.com/assault_trooper'},
#   {'id': 'y6553x36',
#    'names': {'international': 'Assault!! On Planet Beezlbub',
#     'japanese': None},
#    'abbreviation': 'assault_on_planet_beezlbub',
#    'weblink': 'https://www.speedrun.com/assault_on_planet_beezlbub'},
#   {'id': 'w6jlyj2d',
#    'names': {'international': 'Assault: Retribution', 'japanese': None},
#    'abbreviation': 'assault_retribution',
#    'weblink': 'https://www.speedrun.com/assault_retribution'},
#   {'id': 'm1ze3m10',
#    'names': {'international': 'AssaultCube', 'japanese': None},
#    'abbreviation': 'assaultcube',
#    'weblink': 'https://www.speedrun.com/assaultcube'},
#   {'id': '4d798ol1',
#    'names': {'international': 'Assemble with Care', 'japanese': None},
#    'abbreviation': 'awc',
#    'weblink': 'https://www.speedrun.com/awc'},
#   {'id': 'm1mnjl4d',
#    'names': {'international': 'Assembloid: Lose your head', 'japanese': None},
#    'abbreviation': 'assembloid_lose_your_head',
#    'weblink': 'https://www.speedrun.com/assembloid_lose_your_head'},
#   {'id': '3dxkmv51',
#    'names': {'international': 'Assessment Examination', 'japanese': None},
#    'abbreviation': 'assessment_examination',
#    'weblink': 'https://www.speedrun.com/assessment_examination'},
#   {'id': 'pd0wn901',
#    'names': {'international': 'Assetto Corsa', 'japanese': None},
#    'abbreviation': 'assetto_corsa',
#    'weblink': 'https://www.speedrun.com/assetto_corsa'},
#   {'id': 'j1lqppj6',
#    'names': {'international': 'Assimilate', 'japanese': None},
#    'abbreviation': 'assimilate',
#    'weblink': 'https://www.speedrun.com/assimilate'},
#   {'id': '76r34ge6',
#    'names': {'international': 'Assoluto Racing: Real Grip Racing & Drifting',
#     'japanese': None},
#    'abbreviation': 'ar',
#    'weblink': 'https://www.speedrun.com/ar'},
#   {'id': 'o1yyq41q',
#    'names': {'international': 'Astal', 'japanese': None},
#    'abbreviation': 'astal',
#    'weblink': 'https://www.speedrun.com/astal'},
#   {'id': 'm1zkkv21',
#    'names': {'international': 'Astalon: Tears of the Earth', 'japanese': None},
#    'abbreviation': 'astalon_tears_of_the_earth',
#    'weblink': 'https://www.speedrun.com/astalon_tears_of_the_earth'},
#   {'id': 'm1zjn2x6',
#    'names': {'international': 'Astebreed: Definitive Edition',
#     'japanese': None},
#    'abbreviation': 'astebreed_definitive_edition',
#    'weblink': 'https://www.speedrun.com/astebreed_definitive_edition'},
#   {'id': 'y655j906',
#    'names': {'international': 'Asterigos: Curse of the Stars',
#     'japanese': None},
#    'abbreviation': 'acots',
#    'weblink': 'https://www.speedrun.com/acots'},
#   {'id': 'ldevzn13',
#    'names': {'international': 'Astérix & Obélix', 'japanese': None},
#    'abbreviation': 'aando',
#    'weblink': 'https://www.speedrun.com/aando'},
#   {'id': 'j1ne7nw1',
#    'names': {'international': 'Astérix & Obélix (GB)', 'japanese': None},
#    'abbreviation': 'asterix_and_obelix_gb',
#    'weblink': 'https://www.speedrun.com/asterix_and_obelix_gb'},
#   {'id': 'w6jlgrxd',
#    'names': {'international': 'Asterix & Obelix Take On Caesar',
#     'japanese': None},
#    'abbreviation': 'asterix_and_obelix_take_on_caesar',
#    'weblink': 'https://www.speedrun.com/asterix_and_obelix_take_on_caesar'},
#   {'id': 'pd0wryl1',
#    'names': {'international': 'Asterix & Obelix Take On Caesar (GBC)',
#     'japanese': None},
#    'abbreviation': 'aaotoccbc',
#    'weblink': 'https://www.speedrun.com/aaotoccbc'},
#   {'id': 'pdv0o91w',
#    'names': {'international': 'Asterix & Obelix XXL', 'japanese': None},
#    'abbreviation': 'aoxxl',
#    'weblink': 'https://www.speedrun.com/aoxxl'},
#   {'id': 'o6glz75d',
#    'names': {'international': 'Asterix & Obelix XXL (GBA)', 'japanese': None},
#    'abbreviation': 'aandoxxlgba',
#    'weblink': 'https://www.speedrun.com/aandoxxlgba'},
#   {'id': 'lde302x6',
#    'names': {'international': 'Astérix & Obélix XXL 2', 'japanese': None},
#    'abbreviation': 'aoxxl2hd',
#    'weblink': 'https://www.speedrun.com/aoxxl2hd'},
#   {'id': 'lde8pld3',
#    'names': {'international': 'Astérix & Obélix XXL 2 : Mission Ouifix (DS)',
#     'japanese': None},
#    'abbreviation': 'aandoxxl2mods',
#    'weblink': 'https://www.speedrun.com/aandoxxl2mods'},
#   {'id': 'm1z7ex60',
#    'names': {'international': 'Astérix & Obélix XXL 2 : Mission Ouifix (PSP)',
#     'japanese': None},
#    'abbreviation': 'aandoxxl2mo',
#    'weblink': 'https://www.speedrun.com/aandoxxl2mo'},
#   {'id': '76rlne68',
#    'names': {'international': 'Astérix & Obélix XXL 2: Mission: Las Vegum',
#     'japanese': None},
#    'abbreviation': 'aandomlv',
#    'weblink': 'https://www.speedrun.com/aandomlv'},
#   {'id': 'o1y94gr6',
#    'names': {'international': 'Astérix & Obélix XXL 3 : The Crystal Menhir',
#     'japanese': None},
#    'abbreviation': 'aoxxl3tcm',
#    'weblink': 'https://www.speedrun.com/aoxxl3tcm'},
#   {'id': '76rxq9q6',
#    'names': {'international': 'Astérix & Obélix XXL Romastered',
#     'japanese': None},
#    'abbreviation': 'aaoxxlr',
#    'weblink': 'https://www.speedrun.com/aaoxxlr'},
#   {'id': 'pdvzzn46',
#    'names': {'international': 'Astérix & Obélix XXL Trifecta',
#     'japanese': None},
#    'abbreviation': 'aandoxxlt',
#    'weblink': 'https://www.speedrun.com/aandoxxlt'},
#   {'id': '76r3kxq6',
#    'names': {'international': 'Asterix & Obelix XXXL: The Ram From Hibernia',
#     'japanese': None},
#    'abbreviation': 'aorfh',
#    'weblink': 'https://www.speedrun.com/aorfh'},
#   {'id': '36989l8d',
#    'names': {'international': 'Asterix & Obelix: Slap Them All!',
#     'japanese': None},
#    'abbreviation': 'aosta',
#    'weblink': 'https://www.speedrun.com/aosta'},
#   {'id': '3dx2l4p1',
#    'names': {'international': 'Asterix (GB)', 'japanese': None},
#    'abbreviation': 'agb',
#    'weblink': 'https://www.speedrun.com/agb'},
#   {'id': 'yd4o4x1e',
#    'names': {'international': 'Astérix (NES)', 'japanese': None},
#    'abbreviation': 'asterix',
#    'weblink': 'https://www.speedrun.com/asterix'},
#   {'id': '268qo76p',
#    'names': {'international': 'Astérix (SMS)', 'japanese': None},
#    'abbreviation': 'asterix_sms',
#    'weblink': 'https://www.speedrun.com/asterix_sms'},
#   {'id': '9dowrwo1',
#    'names': {'international': 'Astérix (SNES)', 'japanese': None},
#    'abbreviation': 'asterix_snes',
#    'weblink': 'https://www.speedrun.com/asterix_snes'},
#   {'id': 'pd0wlp31',
#    'names': {'international': 'Astérix and the Great Rescue',
#     'japanese': None},
#    'abbreviation': 'aatgr',
#    'weblink': 'https://www.speedrun.com/aatgr'},
#   {'id': '76r3wv56',
#    'names': {'international': 'Asterix and the Magic Cauldron',
#     'japanese': None},
#    'abbreviation': 'aatmc',
#    'weblink': 'https://www.speedrun.com/aatmc'},
#   {'id': 'k6q79zdg',
#    'names': {'international': 'Asterix and the Power of the Gods',
#     'japanese': None},
#    'abbreviation': 'aatpotg',
#    'weblink': 'https://www.speedrun.com/aatpotg'},
#   {'id': 'lde4n513',
#    'names': {'international': 'Asterix and the Secret Mission',
#     'japanese': None},
#    'abbreviation': 'asterix_and_the_secret_mission',
#    'weblink': 'https://www.speedrun.com/asterix_and_the_secret_mission'},
#   {'id': 'j1llypj1',
#    'names': {'international': 'Astérix Arcade', 'japanese': None},
#    'abbreviation': 'aa',
#    'weblink': 'https://www.speedrun.com/aa'},
#   {'id': 'yd432w1e',
#    'names': {'international': 'Asterix at the Olympic Games',
#     'japanese': None},
#    'abbreviation': 'aaog',
#    'weblink': 'https://www.speedrun.com/aaog'},
#   {'id': '76rekvd8',
#    'names': {'international': 'Asterix: Mega Madness', 'japanese': None},
#    'abbreviation': 'asterix_mm',
#    'weblink': 'https://www.speedrun.com/asterix_mm'},
#   {'id': '268ye9dp',
#    'names': {'international': 'Asterix: Search for Dogmatix',
#     'japanese': None},
#    'abbreviation': 'asterixsfd',
#    'weblink': 'https://www.speedrun.com/asterixsfd'},
#   {'id': '3dx984dy',
#    'names': {'international': 'Astérix: The Gallic War', 'japanese': None},
#    'abbreviation': 'asterix_the_gallic_war',
#    'weblink': 'https://www.speedrun.com/asterix_the_gallic_war'},
#   {'id': '369pv231',
#    'names': {'international': 'Asterix: The Mansions of the Gods',
#     'japanese': None},
#    'abbreviation': 'atmofg',
#    'weblink': 'https://www.speedrun.com/atmofg'},
#   {'id': '3dxklop1',
#    'names': {'international': 'Asteroids', 'japanese': None},
#    'abbreviation': 'asteroids',
#    'weblink': 'https://www.speedrun.com/asteroids'},
#   {'id': 'm1mnwvkd',
#    'names': {'international': 'Asteroids (1998) (GBC)', 'japanese': None},
#    'abbreviation': 'asteroids_1998_gbc',
#    'weblink': 'https://www.speedrun.com/asteroids_1998_gbc'},
#   {'id': 'o1yjn241',
#    'names': {'international': 'Asteroids (Atari2600)', 'japanese': None},
#    'abbreviation': 'asteroids_atari2600',
#    'weblink': 'https://www.speedrun.com/asteroids_atari2600'}],
#  'pagination': {'offset': 1000,
#   'max': 1000,
#   'size': 1000,
#   'links': [{'rel': 'prev',
#     'uri': 'https://www.speedrun.com/api/v1/games?_bulk=yes&max=1000'},
#    {'rel': 'next',
#     'uri': 'https://www.speedrun.com/api/v1/games?_bulk=yes&max=1000&offset=2000'}]}}

# %%
# returns whether the page links to a next page
def has_next_page(page):
    links = page['pagination']['links']
    rels = [link['rel'] for link in links]
    return 'next' in rels

# %%
has_next_page(next_page.json())
# Out:
# True

# %%
def get_next_page_uri(page):
    links = page['pagination']['links']
    
    # rels describe the relationship between this page and linked pages
    rels = [link['rel'] for link in links]
    
    # check whether this is the final page
    if 'next' in rels:
        # if the 'next' rel exists, there's only 1 next rel,
        # so just grab the one dict that matches
        link = [link for link in links if 'next' in link.keys()][0]
        uri = link['uri']
    else:
        uri = None
    return uri

# %% [markdown]
# ### Process Automation

# %% [markdown]
# Workflow:
# 0. Use initial link to get 1st page (first iteration only)
# 1. Send get request
# 2. Parse response as JSON
# 3. Extract game data & flatten to tuples
# 4. Convert tuples into a dataframe
# 5. Get next page URL
# 6. Repeat
#
# Finally: Concatenate all dataframes and write to file

# %%
# Be advised, I have not run this yet

def page_to_df(page):
    page_data = page.json()['data']
    
    # helper function for extracting game data fields
    def game_data_to_tuple(game):
        identifier = game['id']
        name = game['names']['international']
        abbreviation = game['abbreviation']
        weblink = game['weblink']
        return (identifier, name, abbreviation, weblink)
    
    page_games_data = [game_data_to_tuple(game) for game in page_data]
    col_names = ['Identifier', 'Name', 'Abbreviation', 'Link']
    df = pd.DataFrame(page_data_to_list(page_games_data, columns = col_names))
    return df

def get_next_page_uri(page):
    links = page.json()['pagination']['links']
    
    # rels describe the relationship between this page and linked pages
    rels = [link['rel'] for link in links]
    
    # check whether this is the final page
    if 'next' in rels:
        # if the 'next' rel exists, there's only 1 next rel,
        # so just grab the one dict that matches
        link = [link for link in links if 'next' in link.keys()][0]
        uri = link['uri']
    else:
        uri = None
    return uri

# TODO okay but how do you pass the retrieved URI to the next call?
def process_page(uri):
    # This method needs to:
    # 1. Send get request
    # 2. Parse response as JSON
    # 3. Extract game data & flatten to tuples
    # 4. Convert tuples into a dataframe
    # 5. Get next page URL
    # 6. return both the df and the next uri
    
    page = requests.get(uri)
    df = page_to_df(page)
    uri = get_next_page_uri(page)
    
    return(df, uri)

# request for 1st page is always the same
first_page_request = "https://www.speedrun.com/api/v1/games?_bulk=yes&max=1000"
page = requests.get(first_page_request)

# pulling everything together
data = []

while get_next_page(page) is not None:
    df = page_to_df(page)
    data.append(df)
    # there's gotta be a less circular way to do this
    uri = get_next_page(page)
    page = requests.get(uri)
